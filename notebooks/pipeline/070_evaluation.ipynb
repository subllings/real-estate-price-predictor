# %%
# === [0. Imports] ===
import os, sys


# Add the project root to the Python path
project_root = os.path.abspath("../..")
sys.path.append(project_root)

from pathlib import Path
import pandas as pd
from utils.model_evaluator import ModelEvaluator

# === [1. Detect project root robustly (supports nbclient + script + notebook)] ===
def get_project_root(marker_file=".git", fallback_name="real-estate-price-predictor"):
    """
    Traverse upward from the current working directory to find the project root.
    Looks for a marker (like .git) or fallback folder name.
    """
    current = Path.cwd().resolve()
    for parent in [current] + list(current.parents):
        if (parent / marker_file).exists() or fallback_name.lower() in parent.name.lower():
            return parent
    raise RuntimeError(f"❌ Could not find project root using marker '{marker_file}' or fallback '{fallback_name}'")

# === [2. Add project root to sys.path for local imports] ===
project_root = get_project_root()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print(f"Using detected project root: {project_root}")

# === [3. Local imports from utils] ===
from utils.experiment_tracker import ExperimentTracker
from utils.constants import METRICS_DB_PATH, CLEANED_DIR
from utils.model_evaluator import ModelEvaluator
from utils.model_table import ModelComparativeTable

# === [4. Load pre-study model metrics (CSV)] ===
model_pre_study_path = project_root / "data" / "ml_pre_study_metrics" / "model_metrics.csv"
if not model_pre_study_path.exists():
    raise FileNotFoundError(f"❌ File not found: {model_pre_study_path}")
print(f"✅ Found file: {model_pre_study_path}")

# === [5. Create model comparison object] ===
mcp = ModelComparativeTable()

# === [6. Display pre-study summary (from CSV)] ===
try:
    df_csv = pd.read_csv(model_pre_study_path)
    if df_csv.empty or "r2" not in df_csv.columns or df_csv["r2"].dropna().empty:
        raise ValueError("⚠️ CSV file is empty or missing valid 'r2' values.")
    mcp.display_model_summary_pre_study(model_pre_study_path)
except Exception as e:
    print("⚠️ Failed to display pre-study summary:", e)

# === [7. Display live summary (from SQLite)] ===
try:
    if not mcp.df_all_evals.empty:
        mcp.display_model_summary()
    else:
        print("⚠️ No experiment logs found in SQLite tracker.")
except Exception as e:
    print("⚠️ Failed to display model summary:", e)
# Out:
# Using detected project root: E:\_SoftEng\_BeCode\real-estate-price-predictor
# ✅ Found file: E:\_SoftEng\_BeCode\real-estate-price-predictor\data\ml_pre_study_metrics\model_metrics.csv
# === Model Evaluation Summary ===
# <style type="text/css">
# #T_b7f38_row14_col0, #T_b7f38_row14_col1, #T_b7f38_row14_col2, #T_b7f38_row14_col3, #T_b7f38_row14_col4, #T_b7f38_row14_col5, #T_b7f38_row14_col6, #T_b7f38_row14_col7 {
#   background-color: #e6f5d0;
# }
# #T_b7f38_row15_col0, #T_b7f38_row15_col1, #T_b7f38_row15_col2, #T_b7f38_row15_col3, #T_b7f38_row15_col4, #T_b7f38_row15_col5, #T_b7f38_row15_col6, #T_b7f38_row15_col7 {
#   background-color: #d0f0c0;
# }
# #T_b7f38_row23_col0, #T_b7f38_row23_col1, #T_b7f38_row23_col2, #T_b7f38_row23_col3, #T_b7f38_row23_col4, #T_b7f38_row23_col5, #T_b7f38_row23_col6, #T_b7f38_row23_col7 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b7f38">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7f38_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_b7f38_level0_col1" class="col_heading level0 col1" >mae</th>
#       <th id="T_b7f38_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_b7f38_level0_col3" class="col_heading level0 col3" >r2</th>
#       <th id="T_b7f38_level0_col4" class="col_heading level0 col4" >best</th>
#       <th id="T_b7f38_level0_col5" class="col_heading level0 col5" >type</th>
#       <th id="T_b7f38_level0_col6" class="col_heading level0 col6" >rank_r2</th>
#       <th id="T_b7f38_level0_col7" class="col_heading level0 col7" >rmse/mae</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7f38_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b7f38_row0_col0" class="data row0 col0" >Linear Regression (All Features)</td>
#       <td id="T_b7f38_row0_col1" class="data row0 col1" >85 510.11 €</td>
#       <td id="T_b7f38_row0_col2" class="data row0 col2" >121 149.58 €</td>
#       <td id="T_b7f38_row0_col3" class="data row0 col3" >0.636600</td>
#       <td id="T_b7f38_row0_col4" class="data row0 col4" ></td>
#       <td id="T_b7f38_row0_col5" class="data row0 col5" >Linear</td>
#       <td id="T_b7f38_row0_col6" class="data row0 col6" >29</td>
#       <td id="T_b7f38_row0_col7" class="data row0 col7" >1.420000</td>
#     </tr>
#     <tr>
#       <th id="T_b7f38_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b7f38_row1_col0" class="data row1 col0" >Random Forest (All Features)</td>
#       <td id="T_b7f38_row1_col1" class="data row1 col1" >65 705.67 €</td>
#       <td id="T_b7f38_row1_col2" class="data row1 col2" >98 940.13 €</td>
#       <td id="T_b7f38_row1_col3" class="data row1 col3" >0.757600</td>
#       <td id="T_b7f38_row1_col4" class="data row1 col4" ></td>
#       <td id="T_b7f38_row1_col5" class="data row1 col5" >Tree</td>
#       <td id="T_b7f38_row1_col6" class="data row1 col6" >24</td>
#       <td id="T_b7f38_row1_col7" class="data row1 col7" >1.510000</td>
#     </tr>
#     <tr>
#       <th id="T_b7f38_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b7f38_row2_col0" class="data row2 col0" >Linear Regression (Top Features)</td>
#       <td id="T_b7f38_row2_col1" class="data row2 col1" >96 534.10 €</td>
#       <td id="T_b7f38_row2_col2" class="data row2 col2" >136 104.16 €</td>
#       <td id="T_b7f38_row2_col3" class="data row2 col3" >0.541300</td>
#       <td id="T_b7f38_row2_col4" class="data row2 col4" ></td>
#       <td id="T_b7f38_row2_col5" class="data row2 col5" >Linear</td>
#       <td id="T_b7f38_row2_col6" class="data row2 col6" >30</td>
#       <td id="T_b7f38_row2_col7" class="data row2 col7" >1.410000</td>
#     </tr>
#     <tr>
#       <th id="T_b7f38_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b7f38_row3_col0" class="data row3 col0" >Random Forest (Top Features)</td>
#       <td id="T_b7f38_row3_col1" class="data row3 col1" >67 309.43 €</td>
#       <td id="T_b7f38_row3_col2" class="data row3 col2" >101 408.12 €</td>
#       <td id="T_b7f38_row3_col3" class="data row3 col3" >0.745400</td>
#       <td id="T_b7f38_row3_col4" class="data row3 col4" ></td>
#       <td id="T_b7f38_row3_col5" class="data row3 col5" >Tree</td>
#       <td id="T_b7f38_row3_col6" class="data row3 col6" >26</td>
#       <td id="T_b7f38_row3_col7" class="data row3 col7" >1.510000</td>
#     </tr>
#     <tr>
#       <th id="T_b7f38_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b7f38_row4_col0" class="data row4 col0" >XGBoost (All Features)</td>
#       <td id="T_b7f38_row4_col1" class="data row4 col1" >66 302.09 €</td>
#       <td id="T_b7f38_row4_col2" class="data row4 col2" >97 431.35 €</td>
#       <td id="T_b7f38_row4_col3" class="data row4 col3" >0.764900</td>
#       <td id="T_b7f38_row4_col4" class="data row4 col4" ></td>
#       <td id="T_b7f38_row4_col5" class="data row4 col5" >Boosting</td>
#       <td id="T_b7f38_row4_col6" class="data row4 col6" >22</td>
#       <td id="T_b7f38_row4_col7" class="data row4 col7" >1.470000</td>
#     </tr>
#     <tr>
#       <th id="T_b7f38_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b7f38_row5_col0" class="data row5 col0" >XGBoost (Top RF Features)</td>
#       <td id="T_b7f38_row5_col1" class="data row5 col1" >65 661.18 €</td>
#       <td id="T_b7f38_row5_col2" class="data row5 col2" >97 742.14 €</td>
#       <td id="T_b7f38_row5_col3" class="data row5 col3" >0.763400</td>
#       <td id="T_b7f38_row5_col4" class="data row5 col4" ></td>
#       <td id="T_b7f38_row5_col5" class="data row5 col5" >Boosting</td>
#       <td id="T_b7f38_row5_col6" class="data row5 col6" >23</td>
#       <td id="T_b7f38_row5_col7" class="data row5 col7" >1.490000</td>
#     </tr>
#     <tr>
#       <th id="T_b7f38_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b7f38_row6_col0" class="data row6 col0" >GradientBoosting (All Features)</td>
#       <td id="T_b7f38_row6_col1" class="data row6 col1" >76 999.33 €</td>
#       <td id="T_b7f38_row6_col2" class="data row6 col2" >110 878.68 €</td>
#       <td id="T_b7f38_row6_col3" class="data row6 col3" >0.695600</td>
#       <td id="T_b7f38_row6_col4" class="data row6 col4" ></td>
#       <td id="T_b7f38_row6_col5" class="data row6 col5" >Other</td>
#       <td id="T_b7f38_row6_col6" class="data row6 col6" >28</td>
#       <td id="T_b7f38_row6_col7" class="data row6 col7" >1.440000</td>
#     </tr>
#     <tr>
#       <th id="T_b7f38_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b7f38_row7_col0" class="data row7 col0" >GradientBoosting (Top RF Features)</td>
#       <td id="T_b7f38_row7_col1" class="data row7 col1" >76 517.08 €</td>
#       <td id="T_b7f38_row7_col2" class="data row7 col2" >110 878.68 €</td>
#       <td id="T_b7f38_row7_col3" class="data row7 col3" >0.696300</td>
#       <td id="T_b7f38_row7_col4" class="data row7 col4" ></td>
#       <td id="T_b7f38_row7_col5" class="data row7 col5" >Other</td>
#       <td id="T_b7f38_row7_col6" class="data row7 col6" >27</td>
#       <td id="T_b7f38_row7_col7" class="data row7 col7" >1.450000</td>
#     </tr>
#     <tr>
#       <th id="T_b7f38_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b7f38_row8_col0" class="data row8 col0" >LightGBM (All Features)</td>
#       <td id="T_b7f38_row8_col1" class="data row8 col1" >65 548.48 €</td>
#       <td id="T_b7f38_row8_col2" class="data row8 col2" >97 417.23 €</td>
#       <td id="T_b7f38_row8_col3" class="data row8 col3" >0.765000</td>
#       <td id="T_b7f38_row8_col4" class="data row8 col4" ></td>
#       <td id="T_b7f38_row8_col5" class="data row8 col5" >Boosting</td>
#       <td id="T_b7f38_row8_col6" class="data row8 col6" >21</td>
#       <td id="T_b7f38_row8_col7" class="data row8 col7" >1.490000</td>
#     </tr>
#     <tr>
#       <th id="T_b7f38_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b7f38_row9_col0" class="data row9 col0" >LightGBM (Top RF Features)</td>
#       <td id="T_b7f38_row9_col1" class="data row9 col1" >67 205.03 €</td>
#       <td id="T_b7f38_row9_col2" class="data row9 col2" >99 709.18 €</td>
#       <td id="T_b7f38_row9_col3" class="data row9 col3" >0.753800</td>
#       <td id="T_b7f38_row9_col4" class="data row9 col4" ></td>
#       <td id="T_b7f38_row9_col5" class="data row9 col5" >Boosting</td>
#       <td id="T_b7f38_row9_col6" class
# 👉 Best model based on 'r2': CatBoost + Optuna CV (Top RF Features) – optimized ✓
# === Model Evaluation Summary ===
# <style type="text/css">
# #T_7ed84_row5_col0, #T_7ed84_row5_col1, #T_7ed84_row5_col2, #T_7ed84_row5_col3, #T_7ed84_row5_col4, #T_7ed84_row5_col5, #T_7ed84_row5_col6, #T_7ed84_row5_col7, #T_7ed84_row5_col8, #T_7ed84_row5_col9, #T_7ed84_row5_col10, #T_7ed84_row5_col11, #T_7ed84_row5_col12 {
#   background-color: #d0f0c0;
# }
# #T_7ed84_row6_col0, #T_7ed84_row6_col1, #T_7ed84_row6_col2, #T_7ed84_row6_col3, #T_7ed84_row6_col4, #T_7ed84_row6_col5, #T_7ed84_row6_col6, #T_7ed84_row6_col7, #T_7ed84_row6_col8, #T_7ed84_row6_col9, #T_7ed84_row6_col10, #T_7ed84_row6_col11, #T_7ed84_row6_col12 {
#   background-color: #e6f5d0;
# }
# #T_7ed84_row9_col0, #T_7ed84_row9_col1, #T_7ed84_row9_col2, #T_7ed84_row9_col3, #T_7ed84_row9_col4, #T_7ed84_row9_col5, #T_7ed84_row9_col6, #T_7ed84_row9_col7, #T_7ed84_row9_col8, #T_7ed84_row9_col9, #T_7ed84_row9_col10, #T_7ed84_row9_col11, #T_7ed84_row9_col12 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7ed84">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ed84_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_7ed84_level0_col1" class="col_heading level0 col1" >timestamp</th>
#       <th id="T_7ed84_level0_col2" class="col_heading level0 col2" >model</th>
#       <th id="T_7ed84_level0_col3" class="col_heading level0 col3" >dataset</th>
#       <th id="T_7ed84_level0_col4" class="col_heading level0 col4" >experiment</th>
#       <th id="T_7ed84_level0_col5" class="col_heading level0 col5" >cleaning_version_id</th>
#       <th id="T_7ed84_level0_col6" class="col_heading level0 col6" >mae</th>
#       <th id="T_7ed84_level0_col7" class="col_heading level0 col7" >rmse</th>
#       <th id="T_7ed84_level0_col8" class="col_heading level0 col8" >r2</th>
#       <th id="T_7ed84_level0_col9" class="col_heading level0 col9" >type</th>
#       <th id="T_7ed84_level0_col10" class="col_heading level0 col10" >rank_r2</th>
#       <th id="T_7ed84_level0_col11" class="col_heading level0 col11" >rmse/mae</th>
#       <th id="T_7ed84_level0_col12" class="col_heading level0 col12" >best</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ed84_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ed84_row0_col0" class="data row0 col0" >43</td>
#       <td id="T_7ed84_row0_col1" class="data row0 col1" >2025-06-29 18:34:55</td>
#       <td id="T_7ed84_row0_col2" class="data row0 col2" >Linear Regression (All Features)</td>
#       <td id="T_7ed84_row0_col3" class="data row0 col3" >immoweb_real_estate_cleaned_for_ml_20250629_1834.csv</td>
#       <td id="T_7ed84_row0_col4" class="data row0 col4" >Linear Regression (All Features)</td>
#       <td id="T_7ed84_row0_col5" class="data row0 col5" >202506291834</td>
#       <td id="T_7ed84_row0_col6" class="data row0 col6" >N/A</td>
#       <td id="T_7ed84_row0_col7" class="data row0 col7" >N/A</td>
#       <td id="T_7ed84_row0_col8" class="data row0 col8" >0.723000</td>
#       <td id="T_7ed84_row0_col9" class="data row0 col9" >Linear</td>
#       <td id="T_7ed84_row0_col10" class="data row0 col10" >11</td>
#       <td id="T_7ed84_row0_col11" class="data row0 col11" >None</td>
#       <td id="T_7ed84_row0_col12" class="data row0 col12" ></td>
#     </tr>
#     <tr>
#       <th id="T_7ed84_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7ed84_row1_col0" class="data row1 col0" >44</td>
#       <td id="T_7ed84_row1_col1" class="data row1 col1" >2025-06-29 18:35:20</td>
#       <td id="T_7ed84_row1_col2" class="data row1 col2" >Random Forest (All Features)</td>
#       <td id="T_7ed84_row1_col3" class="data row1 col3" >immoweb_real_estate_cleaned_for_ml_20250629_1834.csv</td>
#       <td id="T_7ed84_row1_col4" class="data row1 col4" >Random Forest (All Features)</td>
#       <td id="T_7ed84_row1_col5" class="data row1 col5" >202506291834</td>
#       <td id="T_7ed84_row1_col6" class="data row1 col6" >N/A</td>
#       <td id="T_7ed84_row1_col7" class="data row1 col7" >N/A</td>
#       <td id="T_7ed84_row1_col8" class="data row1 col8" >0.764200</td>
#       <td id="T_7ed84_row1_col9" class="data row1 col9" >Tree</td>
#       <td id="T_7ed84_row1_col10" class="data row1 col10" >7</td>
#       <td id="T_7ed84_row1_col11" class="data row1 col11" >None</td>
#       <td id="T_7ed84_row1_col12" class="data row1 col12" ></td>
#     </tr>
#     <tr>
#       <th id="T_7ed84_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7ed84_row2_col0" class="data row2 col0" >45</td>
#       <td id="T_7ed84_row2_col1" class="data row2 col1" >2025-06-29 18:35:28</td>
#       <td id="T_7ed84_row2_col2" class="data row2 col2" >Random Forest (Top 10 Features)</td>
#       <td id="T_7ed84_row2_col3" class="data row2 col3" >immoweb_real_estate_cleaned_for_ml_20250629_1834.csv</td>
#       <td id="T_7ed84_row2_col4" class="data row2 col4" >Random Forest (Top 10 Features)</td>
#       <td id="T_7ed84_row2_col5" class="data row2 col5" >202506291834</td>
#       <td id="T_7ed84_row2_col6" class="data row2 col6" >N/A</td>
#       <td id="T_7ed84_row2_col7" class="data row2 col7" >N/A</td>
#       <td id="T_7ed84_row2_col8" class="data row2 col8" >0.741800</td>
#       <td id="T_7ed84_row2_col9" class="data row2 col9" >Tree</td>
#       <td id="T_7ed84_row2_col10" class="data row2 col10" >8</td>
#       <td id="T_7ed84_row2_col11" class="data row2 col11" >None</td>
#       <td id="T_7ed84_row2_col12" class="data row2 col12" ></td>
#     </tr>
#     <tr>
#       <th id="T_7ed84_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7ed84_row3_col0" class="data row3 col0" >46</td>
#       <td id="T_7ed84_row3_col1" class="data row3 col1" >2025-06-29 18:35:41</td>
#       <td id="T_7ed84_row3_col2" class="data row3 col2" >XGBoost CV (All Features) [TEST]</td>
#       <td id="T_7ed84_row3_col3" class="data row3 col3" >immoweb_real_estate_cleaned_for_ml_20250629_1834.csv</td>
#       <td id="T_7ed84_row3_col4" class="data row3 col4" >XGBoost Untuned (All Features) [TEST]</td>
#       <td id="T_7ed84_row3_col5" class="data row3 col5" >202506291834</td>
#       <td id="T_7ed84_row3_col6" class="data row3 col6" >N/A</td>
#       <td id="T_7ed84_row3_col7" class="data row3 col7" >N/A</td>
#       <td id="T_7ed84_row3_col8" class="data row3 col8" >0.906300</td>
#       <td id="T_7ed84_row3_col9" class="data row3 col9" >Boosting</td>
#       <td id="T_7ed84_row3_col10" class="data row3 col10" >4</td>
#       <td id="T_7ed84_row3_col11" class="data row3 col11" >None</td>
#       <td id="T_7ed84_row3_col12" class="data row3 col12" ></td>
#     </tr>
#     <tr>
#       <th id="T_7ed84_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7ed84_row4_col0" class="data row4 col0" >47</td>
#       <td id="T_7ed84_row4_col1" class="data row4 col1" >2025-06-29 18:35:41</td>
#       <td id="T_7ed84_row4_col2" class="data row4 col2" >XGBoost CV (Top RF Features) [TEST]</td>
#       <td id="T_7ed84_row4_col3" class="data row4 col3" >immoweb_real_estate_cleaned_for_ml_20250629_1834.csv</td>
#       <td id="T_7ed84_row4_col4" class="data row4 col4" >XGBoost Untuned (Top RF Features) [TEST]</td>
#       <td id="T_7ed84_row4_col5" class="data row4 col5" >202506291834</td>
#       <td id="T_7ed84_row4_col6" class="data row4 col6" >N/A</td>
#       <td id="T_7ed84_row4_col7" class="data row4 col7" >N/A</td>
#       <td id="T_7ed84_row4_col8" class="data row4 col8" >0.899800</td>
#       <td id="T_7ed84_row4_col9" class="data row4 col9" >Boosting</td>
#       <td id="T_7ed84_row4_col10" class="data row4 col10" >6</td>
#       <td id="T_7ed84_row4_col11" class="data row4 col11" >None</td>
#       <td id="T_7ed84_row4_col12" class="data row4 col12" ></td>
#     </tr>
#     <tr>
#       <th id="T_7ed84_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7ed84_row5_col0" class="data row5 col0" >48</td>
#       <td id="T_7ed84_row5_col1" class="data row5 col1" >2025-06-29 18:36:29</td>
#       <td id="T_7ed84_row5_col2" class="data row5 col2" >XGBoost + Optuna CV (All Features) [TEST]</td>
#       <td id="T_7ed84_row5_col3" class="data row5 col3" >immoweb_real_estate_cleaned_for_ml_20250629_1834
# 👉 Best model based on R²: CatBoost + Optuna CV (All Features) ✓

# %%
import os
import sqlite3
import pandas as pd

# Trouver le chemin absolu de la base où qu’on soit
current_dir = os.getcwd()
project_root = current_dir
while not os.path.exists(os.path.join(project_root, "database", "metrics.db")):
    parent = os.path.dirname(project_root)
    if parent == project_root:
        raise FileNotFoundError("Impossible de trouver database/metrics.db dans les dossiers parents.")
    project_root = parent

db_path = os.path.join(project_root, "database", "metrics.db")
print("Base trouvée ici :", db_path)

# Lecture
conn = sqlite3.connect(db_path)
df = pd.read_sql_query("SELECT * FROM model_evaluations", conn)
conn.close()

# Ajoute la colonne is_test (modèles de test tout en bas)
df["is_test"] = df["model"].str.contains("TEST|test", case=False, na=False)
# Trie par: d’abord is_test==False (prod), puis r2 décroissant
df = df.sort_values(by=["is_test", "r2"], ascending=[True, False]).reset_index(drop=True)

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
print(df)

# Lecture brute de la base
#conn = sqlite3.connect(db_path)
#df = pd.read_sql_query("SELECT * FROM model_evaluations", conn)
#conn.close()

# Ajouter une colonne 'is_test' pour le tri
df["is_test"] = df["model"].str.contains("TEST|test", case=False, na=False)

# D'abord les modèles sans 'TEST', triés par R² décroissant, puis les modèles test, triés aussi par R² décroissant
df = df.sort_values(by=["is_test", "r2"], ascending=[True, False]).reset_index(drop=True)

# Options d’affichage : tout voir
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 200)
pd.set_option('display.max_colwidth', None)

# AFFICHAGE complet (toutes les colonnes, tout trié comme tu veux)
print("=== TABLEAU COMPLET (TRI PAR R², TEST EN BAS) ===")
display(df)  # ou print(df) selon ton environnement
# Out:
# Base trouvée ici : e:\_SoftEng\_BeCode\real-estate-price-predictor\database\metrics.db
#     id            timestamp                                         model                                               dataset                                    experiment  cleaning_version_id  \
# 0   41  2025-06-29 18:30:56           CatBoost + Optuna CV (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv           CatBoost with Optuna (All Features)         202506291826
# 1   52  2025-06-29 18:39:31           CatBoost + Optuna CV (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv           CatBoost with Optuna (All Features)         202506291834
# 2   22  2025-06-29 17:49:29        CatBoost + Optuna CV (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv        CatBoost with Optuna (Top RF Features)         202506291742
# 3   21  2025-06-29 17:49:29           CatBoost + Optuna CV (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv           CatBoost with Optuna (All Features)         202506291742
# 4   10  2025-06-29 16:44:52           CatBoost + Optuna CV (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv           CatBoost with Optuna (All Features)         202506291641
# 5   42  2025-06-29 18:30:56        CatBoost + Optuna CV (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv        CatBoost with Optuna (Top RF Features)         202506291826
# 6   53  2025-06-29 18:39:31        CatBoost + Optuna CV (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv        CatBoost with Optuna (Top RF Features)         202506291834
# 7   11  2025-06-29 16:44:52        CatBoost + Optuna CV (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv        CatBoost with Optuna (Top RF Features)         202506291641
# 8    2  2025-06-29 16:42:13                  Random Forest (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv                  Random Forest (All Features)         202506291641
# 9   13  2025-06-29 17:43:58                  Random Forest (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv                  Random Forest (All Features)         202506291742
# 10  24  2025-06-29 18:22:58                  Random Forest (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv                  Random Forest (All Features)         202506291821
# 11  33  2025-06-29 18:28:02                  Random Forest (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv                  Random Forest (All Features)         202506291826
# 12  44  2025-06-29 18:35:20                  Random Forest (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv                  Random Forest (All Features)         202506291834
# 13   3  2025-06-29 16:42:22               Random Forest (Top 10 Features)  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv               Random Forest (Top 10 Features)         202506291641
# 14  14  2025-06-29 17:44:06               Random Forest (Top 10 Features)  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv               Random Forest (Top 10 Features)         202506291742
# 15  25  2025-06-29 18:23:07               Random Forest (Top 10 Features)  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv               Random Forest (Top 10 Features)         202506291821
# 16  34  2025-06-29 18:28:10               Random Forest (Top 10 Features)  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv               Random Forest (Top 10 Features)         202506291826
# 17  45  2025-06-29 18:35:28               Random Forest (Top 10 Features)  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv               Random Forest (Top 10 Features)         202506291834
# 18   9  2025-06-29 16:43:43                    CatBoost (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv           CatBoost Baseline (Top RF Features)         202506291641
# 19  20  2025-06-29 17:45:48                    CatBoost (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv           CatBoost Baseline (Top RF Features)         202506291742
# 20  31  2025-06-29 18:24:31                    CatBoost (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv           CatBoost Baseline (Top RF Features)         202506291821
# 21  40  2025-06-29 18:29:21                    CatBoost (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv           CatBoost Baseline (Top RF Features)         202506291826
# 22  51  2025-06-29 18:36:43                    CatBoost (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv           CatBoost Baseline (Top RF Features)         202506291834
# 23   8  2025-06-29 16:43:43                       CatBoost (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv              CatBoost Baseline (All Features)         202506291641
# 24  19  2025-06-29 17:45:48                       CatBoost (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv              CatBoost Baseline (All Features)         202506291742
# 25  30  2025-06-29 18:24:31                       CatBoost (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv              CatBoost Baseline (All Features)         202506291821
# 26  39  2025-06-29 18:29:21                       CatBoost (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv              CatBoost Baseline (All Features)         202506291826
# 27  50  2025-06-29 18:36:43                       CatBoost (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv              CatBoost Baseline (All Features)         202506291834
# 28   1  2025-06-29 16:41:46              Linear Regression (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv              Linear Regression (All Features)         202506291641
# 29  12  2025-06-29 17:43:33              Linear Regression (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv              Linear Regression (All Features)         202506291742
# 30  23  2025-06-29 18:22:33              Linear Regression (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv              Linear Regression (All Features)         202506291821
# 31  32  2025-06-29 18:27:37              Linear Regression (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv              Linear Regression (All Features)         202506291826
# 32  43  2025-06-29 18:34:55              Linear Regression (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv              Linear Regression (All Features)         202506291834
# 33  17  2025-06-29 17:45:32     XGBoost + Optuna CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv     XGBoost with Optuna (All Features) [TEST]         202506291742
# 34  28  2025-06-29 18:24:15     XGBoost + Optuna CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv     XGBoost with Optuna (All Features) [TEST]         202506291821
# 35   7  2025-06-29 16:43:26  XGBoost + Optuna CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv  XGBoost with Optuna (Top RF Features) [TEST]         202506291641
# 36   6  2025-06-29 16:43:26     XGBoost + Optuna CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv     XGBoost with Optuna (All Features) [TEST]         202506291641
# 37  48  2025-06-29 18:36:29     XGBoost + Optuna CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv     XGBoost with Optuna (All Features) [TEST]         202506291834
# 38  49  2025-06-29 18:36:29  XGBoost + Optuna CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv  XGBoost with Optuna (Top RF Features) [TEST]         202506291834
# 39  37  2025-06-29 18:29:07     XGBoost + Optuna CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv     XGBoost with Optuna (All Features) [TEST]         202506291826
# 40   4  2025-06-29 16:42:35              XGBoost CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv         XGBoost Untuned (All Features) [TEST]         202506291641
# 41  15  2025-06-29 17:44:19              XGBoost CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv         XGBoost Untuned (All Features) [TEST]         202506291742
# 42  26  2025-06-29 18:23:20              XGBoost CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv         XGBoost Untuned (All Features) [TEST]         202506291821
# 43  35  2025-06-29 18:28:23              XGBoost CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv         XGBoost Untuned (All Features) [TEST]         202506291826
# 44  46  2025-06-29 18:35:41              XGBoost CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv         XGBoost Untuned (All Features) [TEST]         202506291834
# 45   5  2025-06-29 16:42:35           XGBoost CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv      XGBoost Untuned (Top RF Features) [TEST]         202506291641
# 46  16  2025-06-29 17:44:19           XGBoost CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv      XGBoost Untuned (Top RF Features) [TEST]         202506291742
# 47  27  2025-06-29 18:23:20           XGBoost CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv      XGBoost Untuned (Top RF Features) [TEST]         202506291821
# 48  36  2025-06-29 18:28:23           XGBoost CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv      XGBoost Untuned (Top RF Features) [TEST]         202506291826
# 49  47  2025-06-29 18:35:41           XGBoost CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv      XGBoost Untuned (Top RF Features) [TEST]         202506291834
# 50  29  2025-06-29 18:24:15  XGBoost + Optuna CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv  XGBoost with Optuna (Top RF Features) [TEST]         202506291821
# 51  18  2025-06-29 17:45:32  XGBoost + Optuna CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv  XGBoost with Optuna (Top RF Features) [TEST]         202506291742
# 52  38  2025-06-29 18:29:07  XGBoost + Optuna CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv  XGBoost with Optuna (Top RF Features) [TEST]         202506291826
#
#              mae           rmse        r2  is_test
# 0   20867.176266   28876.028355  0.980897    False
# 1   21701.841801   30148.209880  0.979177    False
# 2   28785.609199   40088.000130  0.963182    False
# 3   35438.389057   49381.156058  0.944133    False
# 4   45214.335325   62794.750156  0.909661    False
# 5   44879.789454   63089.664714  0.908810    False
# 6   46390.435268   65021.643925  0.903140    False
# 7   46839.046978   65280.540746  0.902367    False
# 8   68324.023924  101428.245931  0.764228    False
# 9   68324.023924  101428.245931  0.764228    False
# 10  68324.023924  101428.245931  0.764228    False
# 11  68324.023924  101428.245931  0.764228    False
# 12  68324.023924  101428.245931  0.764228    False
# 13  71734.605568  106140.032744  0.741814    False
# 14  71734.605568  106140.032744  0.741814    False
# 15  71734.605568  106140.032744  0.741814    False
# 16  71734.605568  106140.032744  0.741814    False
# 17  71734.605568  106140.032744  0.741814    False
# 18  76318.952048  109084.883620  0.727379    False
# 19  76318.952048  109084.883620  0.727379    False
# 20  76318.952048  109084.883620  0.727379    False
# 21  76318.952048  109084.883620  0.727379    False
# 22  76318.952048  109084.883620  0.727379    False
# 23  76301.817532  109286.492979  0.726370    False
# 24  76301.817532  109286.492979  0.726370    False
# 25  76301.817532  109286.492979  0.726370    False
# 26  76301.817532  109286.492979  0.726370    False
# 27  76301.817532  109286.492979  0.726370    False
# 28  76898.762921  109935.457472  0.723019    False
# 29  76898.762921  109935.457472  0.723019    False
# 30  76898.762921  109935.457472  0.723019    False
# 31  76898.762921  109935.457472  0.723019    False
# 32  76898.762921  109935.457472  0.723019    False
# 33   5516.079624    9465.412383  0.997947     True
# 34  23900.783801   33763.858329  0.973882     True
# 35  26776.860489   37902.896511  0.967086     True
# 36  32267.833655   45190.139140  0.953214     True
# 37  37982.961081   53409.219298  0.934647     True
# 38  39383.223916   55373.837262  0.929751     True
# 39  42312.215077   59938.488200  0.917692     True
# 40  45377.908242   63950.861332  0.906304     True
# 41  45377.908242   63950.861332  0.906304     True
# 42  45377.908242   63950.861332  0.906304     True
# 43  45377.908242   63950.861332  0.906304     True
# 44  45377.908242   63950.861332  0.906304     True
# 45  46946.026506   66134.783111  0.899795     True
# 46  46946.026506   66134.783111  0.899795     True
# 47  46946.026506   66134.783111  0.899795     True
# 48  46946.026506   66134.783111  0.899795     True
# 49  46946.026506   66134.783111  0.899795     True
# 50  53960.244989   77117.824457  0.863749     True
# 51  59343.238821   85277.193532  0.833392     True
# 52  59671.681680   85668.350609  0.831860     True
# === TABLEAU COMPLET (TRI PAR R², TEST EN BAS) ===
#     id            timestamp                                         model                                               dataset                                    experiment  cleaning_version_id  \
# 0   41  2025-06-29 18:30:56           CatBoost + Optuna CV (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv           CatBoost with Optuna (All Features)         202506291826
# 1   52  2025-06-29 18:39:31           CatBoost + Optuna CV (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv           CatBoost with Optuna (All Features)         202506291834
# 2   22  2025-06-29 17:49:29        CatBoost + Optuna CV (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv        CatBoost with Optuna (Top RF Features)         202506291742
# 3   21  2025-06-29 17:49:29           CatBoost + Optuna CV (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv           CatBoost with Optuna (All Features)         202506291742
# 4   10  2025-06-29 16:44:52           CatBoost + Optuna CV (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv           CatBoost with Optuna (All Features)         202506291641
# 5   42  2025-06-29 18:30:56        CatBoost + Optuna CV (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv        CatBoost with Optuna (Top RF Features)         202506291826
# 6   53  2025-06-29 18:39:31        CatBoost + Optuna CV (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv        CatBoost with Optuna (Top RF Features)         202506291834
# 7   11  2025-06-29 16:44:52        CatBoost + Optuna CV (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv        CatBoost with Optuna (Top RF Features)         202506291641
# 8    2  2025-06-29 16:42:13                  Random Forest (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv                  Random Forest (All Features)         202506291641
# 9   13  2025-06-29 17:43:58                  Random Forest (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv                  Random Forest (All Features)         202506291742
# 10  24  2025-06-29 18:22:58                  Random Forest (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv                  Random Forest (All Features)         202506291821
# 11  33  2025-06-29 18:28:02                  Random Forest (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv                  Random Forest (All Features)         202506291826
# 12  44  2025-06-29 18:35:20                  Random Forest (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv                  Random Forest (All Features)         202506291834
# 13   3  2025-06-29 16:42:22               Random Forest (Top 10 Features)  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv               Random Forest (Top 10 Features)         202506291641
# 14  14  2025-06-29 17:44:06               Random Forest (Top 10 Features)  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv               Random Forest (Top 10 Features)         202506291742
# 15  25  2025-06-29 18:23:07               Random Forest (Top 10 Features)  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv               Random Forest (Top 10 Features)         202506291821
# 16  34  2025-06-29 18:28:10               Random Forest (Top 10 Features)  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv               Random Forest (Top 10 Features)         202506291826
# 17  45  2025-06-29 18:35:28               Random Forest (Top 10 Features)  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv               Random Forest (Top 10 Features)         202506291834
# 18   9  2025-06-29 16:43:43                    CatBoost (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv           CatBoost Baseline (Top RF Features)         202506291641
# 19  20  2025-06-29 17:45:48                    CatBoost (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv           CatBoost Baseline (Top RF Features)         202506291742
# 20  31  2025-06-29 18:24:31                    CatBoost (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv           CatBoost Baseline (Top RF Features)         202506291821
# 21  40  2025-06-29 18:29:21                    CatBoost (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv           CatBoost Baseline (Top RF Features)         202506291826
# 22  51  2025-06-29 18:36:43                    CatBoost (Top RF Features)  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv           CatBoost Baseline (Top RF Features)         202506291834
# 23   8  2025-06-29 16:43:43                       CatBoost (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv              CatBoost Baseline (All Features)         202506291641
# 24  19  2025-06-29 17:45:48                       CatBoost (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv              CatBoost Baseline (All Features)         202506291742
# 25  30  2025-06-29 18:24:31                       CatBoost (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv              CatBoost Baseline (All Features)         202506291821
# 26  39  2025-06-29 18:29:21                       CatBoost (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv              CatBoost Baseline (All Features)         202506291826
# 27  50  2025-06-29 18:36:43                       CatBoost (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv              CatBoost Baseline (All Features)         202506291834
# 28   1  2025-06-29 16:41:46              Linear Regression (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv              Linear Regression (All Features)         202506291641
# 29  12  2025-06-29 17:43:33              Linear Regression (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv              Linear Regression (All Features)         202506291742
# 30  23  2025-06-29 18:22:33              Linear Regression (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv              Linear Regression (All Features)         202506291821
# 31  32  2025-06-29 18:27:37              Linear Regression (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv              Linear Regression (All Features)         202506291826
# 32  43  2025-06-29 18:34:55              Linear Regression (All Features)  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv              Linear Regression (All Features)         202506291834
# 33  17  2025-06-29 17:45:32     XGBoost + Optuna CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv     XGBoost with Optuna (All Features) [TEST]         202506291742
# 34  28  2025-06-29 18:24:15     XGBoost + Optuna CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv     XGBoost with Optuna (All Features) [TEST]         202506291821
# 35   7  2025-06-29 16:43:26  XGBoost + Optuna CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv  XGBoost with Optuna (Top RF Features) [TEST]         202506291641
# 36   6  2025-06-29 16:43:26     XGBoost + Optuna CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv     XGBoost with Optuna (All Features) [TEST]         202506291641
# 37  48  2025-06-29 18:36:29     XGBoost + Optuna CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv     XGBoost with Optuna (All Features) [TEST]         202506291834
# 38  49  2025-06-29 18:36:29  XGBoost + Optuna CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv  XGBoost with Optuna (Top RF Features) [TEST]         202506291834
# 39  37  2025-06-29 18:29:07     XGBoost + Optuna CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv     XGBoost with Optuna (All Features) [TEST]         202506291826
# 40   4  2025-06-29 16:42:35              XGBoost CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv         XGBoost Untuned (All Features) [TEST]         202506291641
# 41  15  2025-06-29 17:44:19              XGBoost CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv         XGBoost Untuned (All Features) [TEST]         202506291742
# 42  26  2025-06-29 18:23:20              XGBoost CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv         XGBoost Untuned (All Features) [TEST]         202506291821
# 43  35  2025-06-29 18:28:23              XGBoost CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv         XGBoost Untuned (All Features) [TEST]         202506291826
# 44  46  2025-06-29 18:35:41              XGBoost CV (All Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv         XGBoost Untuned (All Features) [TEST]         202506291834
# 45   5  2025-06-29 16:42:35           XGBoost CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1641.csv      XGBoost Untuned (Top RF Features) [TEST]         202506291641
# 46  16  2025-06-29 17:44:19           XGBoost CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv      XGBoost Untuned (Top RF Features) [TEST]         202506291742
# 47  27  2025-06-29 18:23:20           XGBoost CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv      XGBoost Untuned (Top RF Features) [TEST]         202506291821
# 48  36  2025-06-29 18:28:23           XGBoost CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv      XGBoost Untuned (Top RF Features) [TEST]         202506291826
# 49  47  2025-06-29 18:35:41           XGBoost CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1834.csv      XGBoost Untuned (Top RF Features) [TEST]         202506291834
# 50  29  2025-06-29 18:24:15  XGBoost + Optuna CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1821.csv  XGBoost with Optuna (Top RF Features) [TEST]         202506291821
# 51  18  2025-06-29 17:45:32  XGBoost + Optuna CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1742.csv  XGBoost with Optuna (Top RF Features) [TEST]         202506291742
# 52  38  2025-06-29 18:29:07  XGBoost + Optuna CV (Top RF Features) [TEST]  immoweb_real_estate_cleaned_for_ml_20250629_1826.csv  XGBoost with Optuna (Top RF Features) [TEST]         202506291826
#
#              mae           rmse        r2  is_test
# 0   20867.176266   28876.028355  0.980897    False
# 1   21701.841801   30148.209880  0.979177    False
# 2   28785.609199   40088.000130  0.963182    False
# 3   35438.389057   49381.156058  0.944133    False
# 4   45214.335325   62794.750156  0.909661    False
# 5   44879.789454   63089.664714  0.908810    False
# 6   46390.435268   65021.643925  0.903140    False
# 7   46839.046978   65280.540746  0.902367    False
# 8   68324.023924  101428.245931  0.764228    False
# 9   68324.023924  101428.245931  0.764228    False
# 10  68324.023924  101428.245931  0.764228    False
# 11  68324.023924  101428.245931  0.764228    False
# 12  68324.023924  101428.245931  0.764228    False
# 13  71734.605568  106140.032744  0.741814    False
# 14  71734.605568  106140.032744  0.741814    False
# 15  71734.605568  106140.032744  0.741814    False
# 16  71734.605568  106140.032744  0.741814    False
# 17  71734.605568  106140.032744  0.741814    False
# 18  76318.952048  109084.883620  0.727379    False
# 19  76318.952048  109084.883620  0.727379    False
# 20  76318.952048  109084.883620  0.727379    False
# 21  76318.952048  109084.883620  0.727379    False
# 22  76318.952048  109084.883620  0.727379    False
# 23  76301.817532  109286.492979  0.726370    False
# 24  76301.817532  109286.492979  0.726370    False
# 25  76301.817532  109286.492979  0.726370    False
# 26  76301.817532  109286.492979  0.726370    False
# 27  76301.817532  109286.492979  0.726370    False
# 28  76898.762921  109935.457472  0.723019    False
# 29  76898.762921  109935.457472  0.723019    False
# 30  76898.762921  109935.457472  0.723019    False
# 31  76898.762921  109935.457472  0.723019    False
# 32  76898.762921  109935.457472  0.723019    False
# 33   5516.079624    9465.412383  0.997947     True
# 34  23900.783801   33763.858329  0.973882     True
# 35  26776.860489   37902.896511  0.967086     True
# 36  32267.833655   45190.139140  0.953214     True
# 37  37982.961081   53409.219298  0.934647     True
# 38  39383.223916   55373.837262  0.929751     True
# 39  42312.215077   59938.488200  0.917692     True
# 40  45377.908242   63950.861332  0.906304     True
# 41  45377.908242   63950.861332  0.906304     True
# 42  45377.908242   63950.861332  0.906304     True
# 43  45377.908242   63950.861332  0.906304     True
# 44  45377.908242   63950.861332  0.906304     True
# 45  46946.026506   66134.783111  0.899795     True
# 46  46946.026506   66134.783111  0.899795     True
# 47  46946.026506   66134.783111  0.899795     True
# 48  46946.026506   66134.783111  0.899795     True
# 49  46946.026506   66134.783111  0.899795     True
# 50  53960.244989   77117.824457  0.863749     True
# 51  59343.238821   85277.193532  0.833392     True
# 52  59671.681680   85668.350609  0.831860     True

# %%
import sys, os
# Add the project root to the Python path
project_root = os.path.abspath("../..")
sys.path.append(project_root)
from utils.train_test_metrics_logger import TrainTestMetricsLogger

# Show summary table
logger = TrainTestMetricsLogger()
logger.display_table()
# Out:
# <style type="text/css">
# #T_21478 th.col_heading.level0:nth-child(5) {
#   background-color: #fff9c4;
# }
# #T_21478 th.col_heading.level0:nth-child(6) {
#   background-color: #fff9c4;
# }
# #T_21478 th.col_heading.level0:nth-child(7) {
#   background-color: #fff9c4;
# }
# #T_21478 th.col_heading.level0:nth-child(8) {
#   background-color: #f9c5c0;
# }
# #T_21478 th.col_heading.level0:nth-child(9) {
#   background-color: #f9c5c0;
# }
# #T_21478 th.col_heading.level0:nth-child(10) {
#   background-color: #f9c5c0;
# }
# #T_21478_row0_col0, #T_21478_row0_col1, #T_21478_row0_col2, #T_21478_row0_col3, #T_21478_row0_col4, #T_21478_row0_col5, #T_21478_row0_col6, #T_21478_row0_col7, #T_21478_row0_col8, #T_21478_row0_col9, #T_21478_row0_col10, #T_21478_row0_col12, #T_21478_row0_col14 {
#   background-color: #4caf50;
#   color: white;
# }
# #T_21478_row0_col11 {
#   background-color: #4caf50;
#   color: white;
#   background-color: #ef9a9a;
#   color: black;
# }
# #T_21478_row0_col13 {
#   background-color: #4caf50;
#   color: white;
#   background-color: #1565c0;
#   color: white;
# }
# #T_21478_row1_col0, #T_21478_row1_col1, #T_21478_row1_col2, #T_21478_row1_col3, #T_21478_row1_col4, #T_21478_row1_col5, #T_21478_row1_col6, #T_21478_row1_col7, #T_21478_row1_col8, #T_21478_row1_col9, #T_21478_row1_col10, #T_21478_row1_col12, #T_21478_row1_col14 {
#   background-color: #81c784;
#   color: black;
# }
# #T_21478_row1_col11 {
#   background-color: #81c784;
#   color: black;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_21478_row1_col13 {
#   background-color: #81c784;
#   color: black;
#   background-color: #1565c0;
#   color: white;
# }
# </style>
# <table id="T_21478">
#   <thead>
#     <tr>
#       <th id="T_21478_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_21478_level0_col1" class="col_heading level0 col1" >Best</th>
#       <th id="T_21478_level0_col2" class="col_heading level0 col2" >timestamp</th>
#       <th id="T_21478_level0_col3" class="col_heading level0 col3" >model</th>
#       <th id="T_21478_level0_col4" class="col_heading level0 col4" >mae_train</th>
#       <th id="T_21478_level0_col5" class="col_heading level0 col5" >rmse_train</th>
#       <th id="T_21478_level0_col6" class="col_heading level0 col6" >r2_train</th>
#       <th id="T_21478_level0_col7" class="col_heading level0 col7" >mae_test</th>
#       <th id="T_21478_level0_col8" class="col_heading level0 col8" >rmse_test</th>
#       <th id="T_21478_level0_col9" class="col_heading level0 col9" >r2_test</th>
#       <th id="T_21478_level0_col10" class="col_heading level0 col10" >r2_gap</th>
#       <th id="T_21478_level0_col11" class="col_heading level0 col11" >r2_gap_diagnostic</th>
#       <th id="T_21478_level0_col12" class="col_heading level0 col12" >n_features</th>
#       <th id="T_21478_level0_col13" class="col_heading level0 col13" >interpretation (r2,mae_gap)</th>
#       <th id="T_21478_level0_col14" class="col_heading level0 col14" >ranking_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_21478_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_21478_row0_col1" class="data row0 col1" >✔</td>
#       <td id="T_21478_row0_col2" class="data row0 col2" >2025-07-03 09:14:29</td>
#       <td id="T_21478_row0_col3" class="data row0 col3" >CatBoost + Optuna CV (All Features – Post-Split Evaluation)</td>
#       <td id="T_21478_row0_col4" class="data row0 col4" >39.5 k€</td>
#       <td id="T_21478_row0_col5" class="data row0 col5" >54.4 k€</td>
#       <td id="T_21478_row0_col6" class="data row0 col6" >0.932174</td>
#       <td id="T_21478_row0_col7" class="data row0 col7" >60.9 k€</td>
#       <td id="T_21478_row0_col8" class="data row0 col8" >90.7 k€</td>
#       <td id="T_21478_row0_col9" class="data row0 col9" >0.811308</td>
#       <td id="T_21478_row0_col10" class="data row0 col10" >0.120866</td>
#       <td id="T_21478_row0_col11" class="data row0 col11" >Strong overfitting</td>
#       <td id="T_21478_row0_col12" class="data row0 col12" >72</td>
#       <td id="T_21478_row0_col13" class="data row0 col13" >overfitting</td>
#       <td id="T_21478_row0_col14" class="data row0 col14" >-151665.408321</td>
#     </tr>
#     <tr>
#       <td id="T_21478_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_21478_row1_col1" class="data row1 col1" ></td>
#       <td id="T_21478_row1_col2" class="data row1 col2" >2025-07-03 09:14:29</td>
#       <td id="T_21478_row1_col3" class="data row1 col3" >CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation)</td>
#       <td id="T_21478_row1_col4" class="data row1 col4" >48.4 k€</td>
#       <td id="T_21478_row1_col5" class="data row1 col5" >67.4 k€</td>
#       <td id="T_21478_row1_col6" class="data row1 col6" >0.896035</td>
#       <td id="T_21478_row1_col7" class="data row1 col7" >62.7 k€</td>
#       <td id="T_21478_row1_col8" class="data row1 col8" >93.1 k€</td>
#       <td id="T_21478_row1_col9" class="data row1 col9" >0.801501</td>
#       <td id="T_21478_row1_col10" class="data row1 col10" >0.094534</td>
#       <td id="T_21478_row1_col11" class="data row1 col11" >Moderate overfitting</td>
#       <td id="T_21478_row1_col12" class="data row1 col12" >30</td>
#       <td id="T_21478_row1_col13" class="data row1 col13" >overfitting</td>
#       <td id="T_21478_row1_col14" class="data row1 col14" >-155764.557211</td>
#     </tr>
#   </tbody>
# </table>
