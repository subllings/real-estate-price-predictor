# %% [markdown]
# ## Baseline CatBoost Regression (GPU Fallback Compatible)
#
# This notebook cell trains **two baseline CatBoost models** to predict real estate prices:
#
# - One with **all filtered features** (low-variance features removed)
# - One with **top 30 features** selected via Random Forest importance
#
# The goal is to quickly evaluate CatBoost performance **without Optuna tuning**, while ensuring **GPU compatibility with CPU fallback**.
#
#
# ###  Library Imports
#
# Includes:
# - `catboost` for gradient boosting on decision trees
# - `sklearn` for feature selection and evaluation
# - Custom modules:
#   - `DataLoader` to load the cleaned ML dataset
#   - `ModelEvaluator`, `ModelVisualizer`, `ExperimentTracker` for tracking, evaluation and plotting
#
#
#
# ### Data Preparation
#
# - Loads the cleaned dataset via `DataLoader`
# - Removes low-variance features with `VarianceThreshold`
# - Uses `RandomForestRegressor` to extract the **top 30 most important features**
#
#
# ### Model Training with GPU Fallback
#
# Defines a helper `train_with_fallback(...)` function that:
# - Tries to train CatBoost on GPU (`task_type="GPU"`)
# - If it fails (e.g., no GPU), it **automatically falls back to CPU**
#
# Models are trained on:
# - `X_reduced`: all filtered features
# - `X_top`: only the top 30 features
#
#
# ### Model Evaluation
#
# Each model is evaluated using:
# - **MAE** (Mean Absolute Error)
# - **RMSE** (Root Mean Squared Error)
# - **R<sup>2</sup>** (Coefficient of Determination)
#
# Results are logged using `ExperimentTracker`.
#
#
# ### Diagnostics & Visualization
#
# - Summary of model metrics is displayed in tables
# - Diagnostic plots generated with `ModelVisualizer`:
#   - Residuals
#   - Prediction distribution
#   - Error across price ranges
# - A **side-by-side residual plot** compares both models
#
#
# ### Test Mode Support
#
# If `TEST_MODE = True`:
# - Dataset size and number of iterations are reduced
# - Useful for debugging and fast iterations
#
# ### Summary
#
# This cell provides a **fast, robust, GPU-aware CatBoost baseline**, ideal for:
# - Comparing with tuned models (e.g., XGBoost + Optuna)
# - Benchmarking preprocessing strategies
# - Validating GPU/CPU execution paths

# %%
import sys, os
# Add the project root to the Python path
project_root = os.path.abspath("../..")
sys.path.append(project_root)

import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from utils.constants import ML_READY_DATA_FILE, TEST_MODE
from utils.data_loader import DataLoader
from utils.model_evaluator import ModelEvaluator

from utils.train_test_metrics_logger import TrainTestMetricsLogger

def root_mean_squared_error(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

if TEST_MODE:
    print("TEST_MODE is ON – using reduced dataset and fewer estimators.")
else:
    print("TEST_MODE is OFF – full training in progress.")

# Step 1: Load data
loader = DataLoader(ML_READY_DATA_FILE)
df = loader.load_data()
X = df.drop(columns=["price"])
y = df["price"]

# Step 2: Remove low-variance features
selector = VarianceThreshold(threshold=0.01)
X_reduced = X.loc[:, selector.fit(X).get_support()]

# Step 3: Extract top 30 features using RandomForest
rf_model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
rf_model.fit(X_reduced, y)
top_features = pd.Series(rf_model.feature_importances_, index=X_reduced.columns).nlargest(30).index.tolist()
X_top = X_reduced[top_features]

# === AJOUT : split train/test pour avoir X_train_all et X_train_top ===
X_train_all, X_test_all, y_train_all, y_test_all = train_test_split(
    X_reduced, y, test_size=0.2, random_state=42
)
X_train_top, X_test_top, y_train_top, y_test_top = train_test_split(
    X_top, y, test_size=0.2, random_state=42
)
# ===============================================================

# Step 4: Define baseline CatBoost parameters
default_params = {
    "iterations": 500 if not TEST_MODE else 50,
    "depth": 6,
    "learning_rate": 0.1,
    "loss_function": "RMSE",
    "verbose": 0,
    "random_seed": 42
}

# Step 5: Train models with fallback (GPU to CPU)
def train_with_fallback(X_train, y_train, model_name):
    try:
        print(f"Training {model_name} on GPU...")
        model = CatBoostRegressor(**default_params, task_type="GPU", devices="0")
        model.fit(
            X_train, y_train,
            eval_set=(X_train, y_train),
            early_stopping_rounds=50
        )
    except Exception as e:
        print(f"⚠️ GPU training failed for {model_name}. Falling back to CPU.\nReason: {e}")
        model = CatBoostRegressor(**default_params, task_type="CPU")
        model.fit(
            X_train, y_train,
            eval_set=(X_train, y_train),
            early_stopping_rounds=50
        )
    return model


# Train and predict using all features
model_all = train_with_fallback(X_train_all, y_train_all, "CatBoost (All Features)")
y_pred_all = model_all.predict(X_test_all)

# Train and predict using top features
model_top = train_with_fallback(X_train_top, y_train_top, "CatBoost (Top RF Features)")
y_pred_top = model_top.predict(X_test_top)

# Step 6: Evaluate CatBoost models on test set

# Define price bins for range-based evaluation
price_bins = [0, 100_000, 200_000, 300_000, 400_000, float('inf')]

# Evaluation – All Features
evaluator_all = ModelEvaluator("CatBoost (All Features)")
metrics_all, range_metrics_all = evaluator_all.evaluate(y_test_all, y_pred_all, bins=price_bins, dataset_type="Test")
evaluator_all.print_evaluation(y_test_all, y_pred_all, bins=price_bins);

# Extract global metrics
mae_all = metrics_all["mae"]
rmse_all = metrics_all["rmse"]
r2_all = metrics_all["r2"]

# Evaluation – Top RF Features
evaluator_top = ModelEvaluator("CatBoost (Top RF Features)")
metrics_top, range_metrics_top = evaluator_top.evaluate(y_test_top, y_pred_top, bins=price_bins, dataset_type="Test")
evaluator_top.print_evaluation(y_test_top, y_pred_top, bins=price_bins)

# Extract global metrics
mae_top = metrics_top["mae"]
rmse_top = metrics_top["rmse"]
r2_top = metrics_top["r2"]

# Step 7: Log metrics using TrainTestMetricsLogger

logger = TrainTestMetricsLogger()

logger.log(
    model_name=f"CatBoost (All Features){' [TEST]' if TEST_MODE else ''}",
    experiment_name=f"CatBoost Baseline (All Features){' [TEST]' if TEST_MODE else ''}",
    mae_train=mae_all,  # Here, test and train are equal due to baseline eval
    rmse_train=rmse_all,
    r2_train=r2_all,
    mae_test=mae_all,
    rmse_test=rmse_all,
    r2_test=r2_all,
    data_file=ML_READY_DATA_FILE,
    n_features=X_train_all.shape[1]
)

logger.log(
    model_name=f"CatBoost (Top RF Features){' [TEST]' if TEST_MODE else ''}",
    experiment_name=f"CatBoost Baseline (Top RF Features){' [TEST]' if TEST_MODE else ''}",
    mae_train=mae_top,
    rmse_train=rmse_top,
    r2_train=r2_top,
    mae_test=mae_top,
    rmse_test=rmse_top,
    r2_test=r2_top,
    data_file=ML_READY_DATA_FILE,
    n_features=X_train_top.shape[1]
)

# Step 8: Display summary table of all logged experiments
logger.display_table()
# Out:
# TEST_MODE is ON – using reduced dataset and fewer estimators.
# Training CatBoost (All Features) on GPU...
# Training CatBoost (Top RF Features) on GPU...
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# [CatBoost (All Features)] Evaluation on Test set
#   MAE:  76,657.45 €
#   RMSE: 110,619.51 €
#   R²:   0.7196
# ----------------------------------------
# [DEBUG] Call print_evaluation for CatBoost (All Features)
# [DEBUG] y_true: 4028, y_pred: 4028
#
# Evaluation – CatBoost (All Features)
#   MAE:  76,657.45 €
#   RMSE: 110,619.51 €
#   R²:   0.7196
# ----------------------------------------
# [DEBUG] Segments found: 5
#          Price Range    n    MAE (€)   RMSE (€)     R²
#      (0.0, 100000.0]   37  73,782.02  85,946.86 -62.24
# (100000.0, 200000.0]  518  66,448.02  82,011.24  -9.03
# (200000.0, 300000.0] 1080  50,161.31  70,182.41  -5.20
# (300000.0, 400000.0]  882  59,235.66  76,890.51  -6.28
#      (400000.0, inf] 1511 109,335.62 152,190.93   0.32
# ----------------------------------------
# [CatBoost (Top RF Features)] Evaluation on Test set
#   MAE:  76,890.03 €
#   RMSE: 110,809.20 €
#   R²:   0.7186
# ----------------------------------------
# [DEBUG] Call print_evaluation for CatBoost (Top RF Features)
# [DEBUG] y_true: 4028, y_pred: 4028
#
# Evaluation – CatBoost (Top RF Features)
#   MAE:  76,890.03 €
#   RMSE: 110,809.20 €
#   R²:   0.7186
# ----------------------------------------
# [DEBUG] Segments found: 5
#          Price Range    n    MAE (€)   RMSE (€)     R²
#      (0.0, 100000.0]   37  75,761.51  87,381.98 -64.37
# (100000.0, 200000.0]  518  65,977.65  82,021.24  -9.04
# (200000.0, 300000.0] 1080  50,355.45  70,718.87  -5.30
# (300000.0, 400000.0]  882  59,893.24  77,333.53  -6.37
#      (400000.0, inf] 1511 109,545.82 152,228.39   0.32
# ----------------------------------------
# <style type="text/css">
# #T_579a0 th.col_heading.level0:nth-child(5) {
#   background-color: #fff9c4;
# }
# #T_579a0 th.col_heading.level0:nth-child(6) {
#   background-color: #fff9c4;
# }
# #T_579a0 th.col_heading.level0:nth-child(7) {
#   background-color: #fff9c4;
# }
# #T_579a0 th.col_heading.level0:nth-child(8) {
#   background-color: #f9c5c0;
# }
# #T_579a0 th.col_heading.level0:nth-child(9) {
#   background-color: #f9c5c0;
# }
# #T_579a0 th.col_heading.level0:nth-child(10) {
#   background-color: #f9c5c0;
# }
# #T_579a0_row0_col0, #T_579a0_row0_col1, #T_579a0_row0_col2, #T_579a0_row0_col3, #T_579a0_row0_col4, #T_579a0_row0_col5, #T_579a0_row0_col6, #T_579a0_row0_col7, #T_579a0_row0_col8, #T_579a0_row0_col9, #T_579a0_row0_col10, #T_579a0_row0_col12, #T_579a0_row0_col14 {
#   background-color: #4caf50;
#   color: white;
# }
# #T_579a0_row0_col11 {
#   background-color: #4caf50;
#   color: white;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_579a0_row0_col13 {
#   background-color: #4caf50;
#   color: white;
#   background-color: #1565c0;
#   color: white;
# }
# #T_579a0_row1_col0, #T_579a0_row1_col1, #T_579a0_row1_col2, #T_579a0_row1_col3, #T_579a0_row1_col4, #T_579a0_row1_col5, #T_579a0_row1_col6, #T_579a0_row1_col7, #T_579a0_row1_col8, #T_579a0_row1_col9, #T_579a0_row1_col10, #T_579a0_row1_col12, #T_579a0_row1_col14, #T_579a0_row28_col11, #T_579a0_row29_col11, #T_579a0_row35_col11, #T_579a0_row39_col11, #T_579a0_row40_col11, #T_579a0_row41_col11, #T_579a0_row48_col11, #T_579a0_row49_col11, #T_579a0_row50_col11, #T_579a0_row51_col11, #T_579a0_row52_col11, #T_579a0_row53_col11, #T_579a0_row54_col11, #T_579a0_row55_col11 {
#   background-color: #81c784;
#   color: black;
# }
# #T_579a0_row1_col11 {
#   background-color: #81c784;
#   color: black;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_579a0_row1_col13 {
#   background-color: #81c784;
#   color: black;
#   background-color: #1565c0;
#   color: white;
# }
# #T_579a0_row2_col0, #T_579a0_row2_col1, #T_579a0_row2_col2, #T_579a0_row2_col3, #T_579a0_row2_col4, #T_579a0_row2_col5, #T_579a0_row2_col6, #T_579a0_row2_col7, #T_579a0_row2_col8, #T_579a0_row2_col9, #T_579a0_row2_col10, #T_579a0_row2_col12, #T_579a0_row2_col14 {
#   background-color: #c8e6c9;
#   color: black;
# }
# #T_579a0_row2_col11 {
#   background-color: #c8e6c9;
#   color: black;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_579a0_row2_col13 {
#   background-color: #c8e6c9;
#   color: black;
#   background-color: #1565c0;
#   color: white;
# }
# #T_579a0_row3_col11, #T_579a0_row7_col11, #T_579a0_row15_col11, #T_579a0_row16_col11, #T_579a0_row17_col11, #T_579a0_row18_col11, #T_579a0_row19_col11, #T_579a0_row20_col11, #T_579a0_row38_col11 {
#   background-color: #ffcc80;
#   color: black;
# }
# #T_579a0_row3_col13, #T_579a0_row5_col13, #T_579a0_row6_col13, #T_579a0_row7_col13, #T_579a0_row8_col13, #T_579a0_row9_col13, #T_579a0_row10_col13, #T_579a0_row11_col13, #T_579a0_row12_col13, #T_579a0_row13_col13, #T_579a0_row15_col13, #T_579a0_row16_col13, #T_579a0_row17_col13, #T_579a0_row18_col13, #T_579a0_row19_col13, #T_579a0_row20_col13, #T_579a0_row21_col13, #T_579a0_row36_col13, #T_579a0_row38_col13, #T_579a0_row42_col13, #T_579a0_row43_col13, #T_579a0_row44_col13, #T_579a0_row45_col13, #T_579a0_row46_col13, #T_579a0_row47_col13 {
#   background-color: #1565c0;
#   color: white;
# }
# #T_579a0_row4_col11, #T_579a0_row14_col11, #T_579a0_row21_col11, #T_579a0_row22_col11, #T_579a0_row23_col11, #T_579a0_row24_col11, #T_579a0_row25_col11, #T_579a0_row26_col11, #T_579a0_row27_col11, #T_579a0_row30_col11, #T_579a0_row31_col11, #T_579a0_row32_col11, #T_579a0_row33_col11, #T_579a0_row34_col11, #T_579a0_row36_col11, #T_579a0_row37_col11 {
#   background-color: #aed581;
#   color: black;
# }
# #T_579a0_row4_col13, #T_579a0_row14_col13, #T_579a0_row22_col13, #T_579a0_row23_col13, #T_579a0_row24_col13, #T_579a0_row25_col13, #T_579a0_row26_col13, #T_579a0_row27_col13, #T_579a0_row28_col13, #T_579a0_row29_col13, #T_579a0_row30_col13, #T_579a0_row31_col13, #T_579a0_row32_col13, #T_579a0_row33_col13, #T_579a0_row34_col13, #T_579a0_row35_col13, #T_579a0_row37_col13, #T_579a0_row39_col13, #T_579a0_row40_col13, #T_579a0_row41_col13, #T_579a0_row48_col13, #T_579a0_row49_col13, #T_579a0_row50_col13, #T_579a0_row51_col13, #T_579a0_row52_col13, #T_579a0_row53_col13, #T_579a0_row54_col13, #T_579a0_row55_col13 {
#   background-color: #1976d2;
#   color: white;
# }
# #T_579a0_row5_col11, #T_579a0_row6_col11, #T_579a0_row8_col11, #T_579a0_row9_col11, #T_579a0_row10_col11, #T_579a0_row11_col11, #T_579a0_row12_col11, #T_579a0_row13_col11, #T_579a0_row42_col11, #T_579a0_row43_col11, #T_579a0_row44_col11, #T_579a0_row45_col11, #T_579a0_row46_col11, #T_579a0_row47_col11 {
#   background-color: #ef9a9a;
#   color: black;
# }
# </style>
# <table id="T_579a0">
#   <thead>
#     <tr>
#       <th id="T_579a0_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_579a0_level0_col1" class="col_heading level0 col1" >Best</th>
#       <th id="T_579a0_level0_col2" class="col_heading level0 col2" >timestamp</th>
#       <th id="T_579a0_level0_col3" class="col_heading level0 col3" >model</th>
#       <th id="T_579a0_level0_col4" class="col_heading level0 col4" >mae_train</th>
#       <th id="T_579a0_level0_col5" class="col_heading level0 col5" >rmse_train</th>
#       <th id="T_579a0_level0_col6" class="col_heading level0 col6" >r2_train</th>
#       <th id="T_579a0_level0_col7" class="col_heading level0 col7" >mae_test</th>
#       <th id="T_579a0_level0_col8" class="col_heading level0 col8" >rmse_test</th>
#       <th id="T_579a0_level0_col9" class="col_heading level0 col9" >r2_test</th>
#       <th id="T_579a0_level0_col10" class="col_heading level0 col10" >r2_gap</th>
#       <th id="T_579a0_level0_col11" class="col_heading level0 col11" >r2_gap_diagnostic</th>
#       <th id="T_579a0_level0_col12" class="col_heading level0 col12" >n_features</th>
#       <th id="T_579a0_level0_col13" class="col_heading level0 col13" >interpretation (r2,mae_gap)</th>
#       <th id="T_579a0_level0_col14" class="col_heading level0 col14" >ranking_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_579a0_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_579a0_row0_col1" class="data row0 col1" >✔</td>
#       <td id="T_579a0_row0_col2" class="data row0 col2" >2025-07-12 00:18:51</td>
#       <td id="T_579a0_row0_col3" class="data row0 col3" >CatBoost + Optuna CV (All Features – Post-Split Evaluation) [TEST]</td>
#       <td id="T_579a0_row0_col4" class="data row0 col4" >48.4 k€</td>
#       <td id="T_579a0_row0_col5" class="data row0 col5" >67.6 k€</td>
#       <td id="T_579a0_row0_col6" class="data row0 col6" >0.895420</td>
#       <td id="T_579a0_row0_col7" class="data row0 col7" >61.9 k€</td>
#       <td id="T_579a0_row0_col8" class="data row0 col8" >91.9 k€</td>
#       <td id="T_579a0_row0_col9" class="data row0 col9" >0.806515</td>
#       <td id="T_579a0_row0_col10" class="data row0 col10" >0.088904</td>
#       <td id="T_579a0_row0_col11" class="data row0 col11" >Moderate overfitting</td>
#       <td id="T_579a0_row0_col12" class="data row0 col12" >72</td>
#       <td id="T_579a0_row0_col13" class="data row0 col13" >overfitting</td>
#       <td id="T_579a0_row0_col14" class="data row0 col14" >-153804.750918</td>
#     </tr>
#     <tr>
#       <td id="T_579a0_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_579a0_row1_col1" class="data row1 col1" ></td>
#       <td id="T_579a0_row1_col2" class="data row1 col2" >2025-07-12 00:14:19</td>
#       <td id="T_579a0_row1_col3" class="data row1 col3" >CatBoost + Optuna CV (All Features – Post-Split Evaluation) [TEST]</td>
#       <td id="T_579a0_row1_col4" class="data row1 col4" >45.7 k€</td>
#       <td id="T_579a0_row1_col5" class="data row1 col5" >63.7 k€</td>
#       <td id="T_579a0_row1_col6" class="data row1 col6" >0.906964</td>
#       <td id="T_579a0_row1_col7" class="data row1 col7" >62.1 k€</td>
#       <td id="T_579a0_row1_col8" class="data row1 col8" >92.5 k€</td>
#       <td id="T_579a0_row1_col9" class="data row1 col9" >0.804005</td>
#       <td id="T_579a0_row1_col10" class="data row1 col10" >0.10

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from utils.constants import PRICE_BINS, PRICE_BIN_LABELS

# === Prepare residuals and diagnostic DataFrames ===
# Après train/test split et entraînement
residuals_all = y_test_all - y_pred_all
residuals_top = y_test_top - y_pred_top

df_viz_all = pd.DataFrame({
    "y_true": y_test_all,
    "y_pred": y_pred_all,
    "residuals": residuals_all
})
df_viz_all["price_range"] = pd.cut(df_viz_all["y_true"], bins=PRICE_BINS, labels=PRICE_BIN_LABELS)

df_viz_top = pd.DataFrame({
    "y_true": y_test_top,
    "y_pred": y_pred_top,
    "residuals": residuals_top
})
df_viz_top["price_range"] = pd.cut(df_viz_top["y_true"], bins=PRICE_BINS, labels=PRICE_BIN_LABELS)


# === Plot 1–3: Standard diagnostics for "All Features" model ===
plt.figure(figsize=(14, 4))
plt.suptitle("Diagnostics – CatBoost (All Features)", fontsize=16)

# Plot 1: Residuals vs Predicted
plt.subplot(1, 3, 1)
plt.scatter(df_viz_all["y_pred"], df_viz_all["residuals"], alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted Price")
plt.ylabel("Residual")
plt.title("Residuals vs Predicted")

# Plot 2: Residual distribution
plt.subplot(1, 3, 2)
sns.histplot(df_viz_all["residuals"], kde=True, color="orange")
plt.xlabel("Residual")
plt.title("Residual Distribution")

# Plot 3: Predicted vs Actual prices
plt.subplot(1, 3, 3)
plt.scatter(df_viz_all["y_true"], df_viz_all["y_pred"], alpha=0.5)
plt.plot(
    [df_viz_all["y_true"].min(), df_viz_all["y_true"].max()],
    [df_viz_all["y_true"].min(), df_viz_all["y_true"].max()],
    color='red', linestyle='--'
)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Predicted vs Actual")

plt.tight_layout()
plt.show()

# === Boxplot: Residuals by price range (All Features) ===
plt.figure(figsize=(8, 4))
sns.boxplot(x="price_range", y="residuals", data=df_viz_all, palette="muted")
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Price Range")
plt.ylabel("Residual")
plt.title("Residuals by Price Range – All Features")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# === Boxplot: Residuals by price range (Top RF Features) ===
plt.figure(figsize=(8, 4))
sns.boxplot(x="price_range", y="residuals", data=df_viz_top, palette="coolwarm")
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Price Range")
plt.ylabel("Residual")
plt.title("Residuals by Price Range – Top RF Features")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Neo\AppData\Local\Temp\ipykernel_37200\8619048.py:60: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="price_range", y="residuals", data=df_viz_all, palette="muted")
# C:\Users\Neo\AppData\Local\Temp\ipykernel_37200\8619048.py:71: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="price_range", y="residuals", data=df_viz_top, palette="coolwarm")

# %% [markdown]
# # CatBoost + Optuna Hyperparameter Tuning Pipeline
#
#
# ## Data Preparation
#
# - Load the cleaned ML-ready dataset from a CSV file using `DataLoader`.
# - Drop the target variable `price` to separate `X` and `y`.
# - Apply `VarianceThreshold` to remove low-variance features (threshold = 0.01).
# - Use a `RandomForestRegressor` to rank feature importance.
# - Select the **top 30 most important features** for one of the models.
#
#
# ##  Hyperparameter Tuning (Optuna)
#
# Define the function `tune_catboost_with_optuna(...)` that:
#
# - Runs an Optuna optimization loop.
# - Evaluates model performance with **5-Fold Cross-Validation**.
# - Minimizes the **Root Mean Squared Error (RMSE)**.
#
# ### Tuned Hyperparameters:
#
# - `iterations`
# - `depth`
# - `learning_rate`
# - `l2_leaf_reg`
# - `bagging_temperature`
# - `random_strength`
#
#
#
# ## Train Final Models
#
# Two models are trained:
#
# - One using **all filtered features**
# - One using the **top 30 features**
#
# Each is trained using the **best parameters** found by Optuna.
#
#
#
# ##  Evaluation
#
# Models are evaluated using:
#
# - `MAE`: Mean Absolute Error
# - `RMSE`: Root Mean Squared Error
# - `R<sup>2</sup>`: Coefficient of determination
#
# Results are logged with `ExperimentTracker`.
#
#
#
# ##  Diagnostics
#
# - Summary tables displayed with `ModelEvaluator`
# - Residuals & diagnostic plots from `ModelVisualizer`
# - Optionally, **SHAP values** can be plotted to understand feature importance
#
#
#
# ## Test Mode (Optional)
#
# When `TEST_MODE = True`, the pipeline uses:
#
# - A smaller dataset
# - Fewer Optuna trials (`n_trials = 3`)
#
# To speed up execution and debugging.

# %%
import sys, os
# Add the project root to the Python path
project_root = os.path.abspath("../..")
sys.path.append(project_root)
from utils.model_saver import ModelSaver

import optuna
import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.model_selection import KFold, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import mean_squared_error
from utils.constants import ML_READY_DATA_FILE, TEST_MODE
from utils.data_loader import DataLoader
from utils.model_evaluator import ModelEvaluator
from utils.train_test_metrics_logger import TrainTestMetricsLogger
from utils.model_saver import ModelSaver  

def root_mean_squared_error(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

if TEST_MODE:
    print("TEST_MODE is ON – running in test mode (reduced data, fewer trials).")
else:
    print("TEST_MODE is OFF – full training is active.")

# Step 1: Load and clean dataset
loader = DataLoader(ML_READY_DATA_FILE)
df = loader.load_data()
X = df.drop(columns=["price"])
y = df["price"]

# Step 2: Remove low-variance features
selector = VarianceThreshold(threshold=0.01)
X_reduced = X.loc[:, selector.fit(X).get_support()]

# Step 3: Extract top 30 features using Random Forest
rf_model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
rf_model.fit(X_reduced, y)
top_features = pd.Series(rf_model.feature_importances_, index=X_reduced.columns).nlargest(30).index.tolist()
X_top = X_reduced[top_features]

# Step 4: Define Optuna objective for CatBoost
def tune_catboost_with_optuna(X_data, y_data, n_trials=50):
    def objective(trial):
        params = {
            "iterations": trial.suggest_int("iterations", 300, 1000),
            "depth": trial.suggest_int("depth", 4, 8),
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
            "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-3, 10.0, log=True),
            "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.0),
            "random_strength": trial.suggest_float("random_strength", 0.0, 1.0),
            "bootstrap_type": "Bayesian"
        }

        model = CatBoostRegressor(
            **params,
            verbose=0,
            loss_function="RMSE",
            random_state=42
        )

        cv = KFold(n_splits=5, shuffle=True, random_state=42)
        scores = []
        for train_idx, val_idx in cv.split(X_data):
            X_train, X_val = X_data.iloc[train_idx], X_data.iloc[val_idx]
            y_train, y_val = y_data.iloc[train_idx], y_data.iloc[val_idx]

            model.fit(X_train, y_train,eval_set=(X_val, y_val), early_stopping_rounds=50)
            preds = model.predict(X_val)
            scores.append(root_mean_squared_error(y_val, preds))
        return np.mean(scores)

    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=n_trials)
    return study

# Step 5: Split train/test sets for final evaluation
test_size = 0.2
random_state = 42

X_train_all, X_test_all, y_train_all, y_test_all = train_test_split(X_reduced, y, test_size=test_size, random_state=random_state)
X_train_top, X_test_top, y_train_top, y_test_top = train_test_split(X_top, y, test_size=test_size, random_state=random_state)

# Step 6: Tune and train both models on train data only
n_trials = 1 if TEST_MODE else 50

study_all = tune_catboost_with_optuna(X_train_all, y_train_all, n_trials)
model_all = CatBoostRegressor(**study_all.best_params, verbose=0, loss_function="RMSE", random_state=42)
model_all.fit(X_train_all, y_train_all)

study_top = tune_catboost_with_optuna(X_train_top, y_train_top, n_trials)
model_top = CatBoostRegressor(**study_top.best_params, verbose=0, loss_function="RMSE", random_state=42)
model_top.fit(X_train_top, y_train_top)

# Step 7: Predict on train and test sets
y_pred_train_all = model_all.predict(X_train_all)
y_pred_test_all = model_all.predict(X_test_all)

y_pred_train_top = model_top.predict(X_train_top)
y_pred_test_top = model_top.predict(X_test_top)

# Step 7: Evaluate

# Initialize evaluators for both model variants
evaluator_all = ModelEvaluator("CatBoost + Optuna CV (All Features)")
evaluator_top = ModelEvaluator("CatBoost + Optuna CV (Top RF Features)")

# Evaluate on training and test sets – All Features
metrics_train_all, range_train_all = evaluator_all.evaluate(y_train_all, y_pred_train_all, dataset_type="Train")
metrics_test_all,  range_test_all  = evaluator_all.evaluate(y_test_all,  y_pred_test_all,  dataset_type="Test")

# Extract individual global metrics – All Features
mae_train_all  = metrics_train_all["mae"]
rmse_train_all = metrics_train_all["rmse"]
r2_train_all   = metrics_train_all["r2"]

mae_test_all  = metrics_test_all["mae"]
rmse_test_all = metrics_test_all["rmse"]
r2_test_all   = metrics_test_all["r2"]

# Evaluate on training and test sets – Top 30 RF Features
metrics_train_top, range_train_top = evaluator_top.evaluate(y_train_top, y_pred_train_top, dataset_type="Train")
metrics_test_top,  range_test_top  = evaluator_top.evaluate(y_test_top,  y_pred_test_top,  dataset_type="Test")

# Extract individual global metrics – Top Features
mae_train_top  = metrics_train_top["mae"]
rmse_train_top = metrics_train_top["rmse"]
r2_train_top   = metrics_train_top["r2"]

mae_test_top  = metrics_test_top["mae"]
rmse_test_top = metrics_test_top["rmse"]
r2_test_top   = metrics_test_top["r2"]

# Define price ranges for segmented evaluation
bins=[0, 150000, 250000, 350000, 500000, 750000, 1_000_000, float("inf")]

# Print detailed evaluation by price range
print("\n[Evaluation by Price Range – All Features]")
evaluator_all.print_evaluation(y_test_all, y_pred_test_all, bins=bins)

print("\n[Evaluation by Price Range – Top RF Features]")
evaluator_top.print_evaluation(y_test_top, y_pred_test_top, bins=bins)




# Step 8: Logging with TrainTestMetricsLogger
logger = TrainTestMetricsLogger()

logger.log(
    model_name=f"CatBoost + Optuna CV (All Features – Post-Split Evaluation){' [TEST]' if TEST_MODE else ''}",
    experiment_name=f"CatBoost with Optuna (All Features){' [TEST]' if TEST_MODE else ''}",
    mae_train=mae_train_all,
    rmse_train=rmse_train_all,
    r2_train=r2_train_all,
    mae_test=mae_test_all,
    rmse_test=rmse_test_all,
    r2_test=r2_test_all,
    data_file=ML_READY_DATA_FILE,
    n_features=X_train_all.shape[1]
)

logger.log(
    model_name=f"CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation){' [TEST]' if TEST_MODE else ''}",
    experiment_name=f"CatBoost with Optuna (Top RF Features){' [TEST]' if TEST_MODE else ''}",
    mae_train=mae_train_top,
    rmse_train=rmse_train_top,
    r2_train=r2_train_top,
    mae_test=mae_test_top,
    rmse_test=rmse_test_top,
    r2_test=r2_test_top,
    data_file=ML_READY_DATA_FILE,
    n_features=X_train_top.shape[1]
)


# Step 9: Save models, features and metrics
saver = ModelSaver()

# Save CatBoost All Features
saver.save_model_and_features(
    model=model_all,
    features=X_train_all.columns.tolist(),
    model_name=f"CatBoost + Optuna CV (All Features – Post-Split Evaluation){' [TEST]' if TEST_MODE else ''}",
    metrics=metrics_test_all,
    metrics_by_price_range=evaluator_all._compute_metrics_by_price_range(
        y_test_all, y_pred_test_all, bins=[0, 100_000, 200_000, 300_000, 400_000, float("inf")]
    )
)

# Save CatBoost Top RF Features
saver.save_model_and_features(
    model=model_top,
    features=X_train_top.columns.tolist(),
    model_name=f"CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation){' [TEST]' if TEST_MODE else ''}",
    metrics=metrics_test_top,
    metrics_by_price_range=evaluator_top._compute_metrics_by_price_range(
        y_test_top, y_pred_test_top, bins=[0, 100_000, 200_000, 300_000, 400_000, float("inf")]
    )
)


# Step 10: Display summary
logger.display_table()
# Out:
# TEST_MODE is ON – running in test mode (reduced data, fewer trials).
# [I 2025-07-12 00:42:39,811] A new study created in memory with name: no-name-514eb153-7c54-451a-9bbb-0eeef703e8dd
# [I 2025-07-12 00:42:47,055] Trial 0 finished with value: 96824.65072794893 and parameters: {'iterations': 709, 'depth': 4, 'learning_rate': 0.22945470706680876, 'l2_leaf_reg': 0.2931011089057838, 'bagging_temperature': 0.7307063010556896, 'random_strength': 0.1780561869368631}. Best is trial 0 with value: 96824.65072794893.
# [I 2025-07-12 00:42:48,917] A new study created in memory with name: no-name-849a177f-8d02-40a1-a174-1bb85cd854cc
# [I 2025-07-12 00:43:00,233] Trial 0 finished with value: 97578.12417444758 and parameters: {'iterations': 657, 'depth': 7, 'learning_rate': 0.05699236673960621, 'l2_leaf_reg': 0.815869625677332, 'bagging_temperature': 0.2916415738792143, 'random_strength': 0.5708759277522433}. Best is trial 0 with value: 97578.12417444758.
# [CatBoost + Optuna CV (All Features)] Evaluation on Train set
#   MAE:  50,578.80 €
#   RMSE: 70,920.38 €
#   R²:   0.8848
# ----------------------------------------
# [CatBoost + Optuna CV (All Features)] Evaluation on Test set
#   MAE:  62,823.93 €
#   RMSE: 93,136.46 €
#   R²:   0.8012
# ----------------------------------------
# [CatBoost + Optuna CV (Top RF Features)] Evaluation on Train set
#   MAE:  54,155.70 €
#   RMSE: 76,395.50 €
#   R²:   0.8663
# ----------------------------------------
# [CatBoost + Optuna CV (Top RF Features)] Evaluation on Test set
#   MAE:  63,571.53 €
#   RMSE: 93,662.12 €
#   R²:   0.7990
# ----------------------------------------
#
# [Evaluation by Price Range – All Features]
# [DEBUG] Call print_evaluation for CatBoost + Optuna CV (All Features)
# [DEBUG] y_true: 4028, y_pred: 4028
#
# Evaluation – CatBoost + Optuna CV (All Features)
#   MAE:  62,823.93 €
#   RMSE: 93,136.46 €
#   R²:   0.8012
# ----------------------------------------
# [DEBUG] Segments found: 7
#           Price Range    n    MAE (€)   RMSE (€)     R²
#       (0.0, 150000.0]  179  39,584.75  53,303.01  -4.95
#  (150000.0, 250000.0]  865  40,873.11  56,901.62  -3.12
#  (250000.0, 350000.0] 1056  44,144.64  60,889.44  -3.42
#  (350000.0, 500000.0] 1030  60,700.35  81,830.15  -2.44
#  (500000.0, 750000.0]  605  89,889.12 112,911.70  -1.76
# (750000.0, 1000000.0]  232 138,026.73 180,277.28  -5.18
#      (1000000.0, inf]   61 247,059.76 302,065.57 -29.88
# ----------------------------------------
#
# [Evaluation by Price Range – Top RF Features]
# [DEBUG] Call print_evaluation for CatBoost + Optuna CV (Top RF Features)
# [DEBUG] y_true: 4028, y_pred: 4028
#
# Evaluation – CatBoost + Optuna CV (Top RF Features)
#   MAE:  63,571.53 €
#   RMSE: 93,662.12 €
#   R²:   0.7990
# ----------------------------------------
# [DEBUG] Segments found: 7
#           Price Range    n    MAE (€)   RMSE (€)     R²
#       (0.0, 150000.0]  179  40,442.04  52,245.37  -4.71
#  (150000.0, 250000.0]  865  41,987.21  57,046.70  -3.14
#  (250000.0, 350000.0] 1056  45,380.35  62,140.67  -3.60
#  (350000.0, 500000.0] 1030  58,352.59  78,224.25  -2.15
#  (500000.0, 750000.0]  605  90,434.68 113,547.32  -1.79
# (750000.0, 1000000.0]  232 144,341.20 183,775.85  -5.42
#      (1000000.0, inf]   61 266,935.99 314,052.88 -32.38
# ----------------------------------------
# [✔] Model saved: CatBoost + Optuna CV (All Features – Post-Split Evaluation) [TEST]_20250712_0043_TEST.pkl
# [✔] Features saved: CatBoost + Optuna CV (All Features – Post-Split Evaluation) [TEST]_20250712_0043_TEST.json
# [✔] Metrics saved: CatBoost + Optuna CV (All Features – Post-Split Evaluation) [TEST]_20250712_0043_TEST_metrics.json
# [✔] Price range metrics saved: CatBoost + Optuna CV (All Features – Post-Split Evaluation) [TEST]_20250712_0043_TEST_metrics_by_price_range.json
# [✔] Model saved: CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation) [TEST]_20250712_0043_TEST.pkl
# [✔] Features saved: CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation) [TEST]_20250712_0043_TEST.json
# [✔] Metrics saved: CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation) [TEST]_20250712_0043_TEST_metrics.json
# [✔] Price range metrics saved: CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation) [TEST]_20250712_0043_TEST_metrics_by_price_range.json
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# <style type="text/css">
# #T_a7ac4 th.col_heading.level0:nth-child(5) {
#   background-color: #fff9c4;
# }
# #T_a7ac4 th.col_heading.level0:nth-child(6) {
#   background-color: #fff9c4;
# }
# #T_a7ac4 th.col_heading.level0:nth-child(7) {
#   background-color: #fff9c4;
# }
# #T_a7ac4 th.col_heading.level0:nth-child(8) {
#   background-color: #f9c5c0;
# }
# #T_a7ac4 th.col_heading.level0:nth-child(9) {
#   background-color: #f9c5c0;
# }
# #T_a7ac4 th.col_heading.level0:nth-child(10) {
#   background-color: #f9c5c0;
# }
# #T_a7ac4_row0_col0, #T_a7ac4_row0_col1, #T_a7ac4_row0_col2, #T_a7ac4_row0_col3, #T_a7ac4_row0_col4, #T_a7ac4_row0_col5, #T_a7ac4_row0_col6, #T_a7ac4_row0_col7, #T_a7ac4_row0_col8, #T_a7ac4_row0_col9, #T_a7ac4_row0_col10, #T_a7ac4_row0_col12, #T_a7ac4_row0_col14 {
#   background-color: #4caf50;
#   color: white;
# }
# #T_a7ac4_row0_col11 {
#   background-color: #4caf50;
#   color: white;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_a7ac4_row0_col13 {
#   background-color: #4caf50;
#   color: white;
#   background-color: #1565c0;
#   color: white;
# }
# #T_a7ac4_row1_col0, #T_a7ac4_row1_col1, #T_a7ac4_row1_col2, #T_a7ac4_row1_col3, #T_a7ac4_row1_col4, #T_a7ac4_row1_col5, #T_a7ac4_row1_col6, #T_a7ac4_row1_col7, #T_a7ac4_row1_col8, #T_a7ac4_row1_col9, #T_a7ac4_row1_col10, #T_a7ac4_row1_col12, #T_a7ac4_row1_col14, #T_a7ac4_row30_col11, #T_a7ac4_row31_col11, #T_a7ac4_row37_col11, #T_a7ac4_row41_col11, #T_a7ac4_row42_col11, #T_a7ac4_row43_col11, #T_a7ac4_row50_col11, #T_a7ac4_row51_col11, #T_a7ac4_row52_col11, #T_a7ac4_row53_col11, #T_a7ac4_row54_col11, #T_a7ac4_row55_col11, #T_a7ac4_row56_col11, #T_a7ac4_row57_col11 {
#   background-color: #81c784;
#   color: black;
# }
# #T_a7ac4_row1_col11 {
#   background-color: #81c784;
#   color: black;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_a7ac4_row1_col13 {
#   background-color: #81c784;
#   color: black;
#   background-color: #1565c0;
#   color: white;
# }
# #T_a7ac4_row2_col0, #T_a7ac4_row2_col1, #T_a7ac4_row2_col2, #T_a7ac4_row2_col3, #T_a7ac4_row2_col4, #T_a7ac4_row2_col5, #T_a7ac4_row2_col6, #T_a7ac4_row2_col7, #T_a7ac4_row2_col8, #T_a7ac4_row2_col9, #T_a7ac4_row2_col10, #T_a7ac4_row2_col12, #T_a7ac4_row2_col14 {
#   background-color: #c8e6c9;
#   color: black;
# }
# #T_a7ac4_row2_col11 {
#   background-color: #c8e6c9;
#   color: black;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_a7ac4_row2_col13 {
#   background-color: #c8e6c9;
#   color: black;
#   background-color: #1565c0;
#   color: white;
# }
# #T_a7ac4_row3_col11, #T_a7ac4_row4_col11, #T_a7ac4_row9_col11, #T_a7ac4_row17_col11, #T_a7ac4_row18_col11, #T_a7ac4_row19_col11, #T_a7ac4_row20_col11, #T_a7ac4_row21_col11, #T_a7ac4_row22_col11, #T_a7ac4_row40_col11 {
#   background-color: #ffcc80;
#   color: black;
# }
# #T_a7ac4_row3_col13, #T_a7ac4_row4_col13, #T_a7ac4_row6_col13, #T_a7ac4_row7_col13, #T_a7ac4_row9_col13, #T_a7ac4_row10_col13, #T_a7ac4_row11_col13, #T_a7ac4_row12_col13, #T_a7ac4_row13_col13, #T_a7ac4_row14_col13, #T_a7ac4_row15_col13, #T_a7ac4_row17_col13, #T_a7ac4_row18_col13, #T_a7ac4_row19_col13, #T_a7ac4_row20_col13, #T_a7ac4_row21_col13, #T_a7ac4_row22_col13, #T_a7ac4_row23_col13, #T_a7ac4_row38_col13, #T_a7ac4_row40_col13, #T_a7ac4_row44_col13, #T_a7ac4_row45_col13, #T_a7ac4_row46_col13, #T_a7ac4_row47_col13, #T_a7ac4_row48_col13, #T_a7ac4_row49_col13 {
#   background-color: #1565c0;
#   color: white;
# }
# #T_a7ac4_row5_col11, #T_a7ac4_row8_col11, #T_a7ac4_row16_col11, #T_a7ac4_row23_col11, #T_a7ac4_row24_col11, #T_a7ac4_row25_col11, #T_a7ac4_row26_col11, #T_a7ac4_row27_col11, #T_a7ac4_row28_col11, #T_a7ac4_row29_col11, #T_a7ac4_row32_col11, #T_a7ac4_row33_col11, #T_a7ac4_row34_col11, #T_a7ac4_row35_col11, #T_a7ac4_row36_col11, #T_a7ac4_row38_col11, #T_a7ac4_row39_col11 {
#   background-color: #aed581;
#   color: black;
# }
# #T_a7ac4_row5_col13, #T_a7ac4_row8_col13, #T_a7ac4_row16_col13, #T_a7ac4_row24_col13, #T_a7ac4_row25_col13, #T_a7ac4_row26_col13, #T_a7ac4_row27_col13, #T_a7ac4_row28_col13, #T_a7ac4_row29_col13, #T_a7ac4_row30_col13, #T_a7ac4_row31_col13, #T_a7ac4_row32_col13, #T_a7ac4_row33_col13, #T_a7ac4_row34_col13, #T_a7ac4_row35_col13, #T_a7ac4_row36_col13, #T_a7ac4_row37_col13, #T_a7ac4_row39_col13, #T_a7ac4_row41_col13, #T_a7ac4_row42_col13, #T_a7ac4_row43_col13, #T_a7ac4_row50_col13, #T_a7ac4_row51_col13, #T_a7ac4_row52_col13, #T_a7ac4_row53_col13, #T_a7ac4_row54_col13, #T_a7ac4_row55_col13, #T_a7ac4_row56_col13, #T_a7ac4_row57_col13 {
#   background-color: #1976d2;
#   color: white;
# }
# #T_a7ac4_row6_col11, #T_a7ac4_row7_col11, #T_a7ac4_row10_col11, #T_a7ac4_row11_col11, #T_a7ac4_row12_col11, #T_a7ac4_row13_col11, #T_a7ac4_row14_col11, #T_a7ac4_row15_col11, #T_a7ac4_row44_col11, #T_a7ac4_row45_col11, #T_a7ac4_row46_col11, #T_a7ac4_row47_col11, #T_a7ac4_row48_col11, #T_a7ac4_row49_col11 {
#   background-color: #ef9a9a;
#   color: black;
# }
# </style>
# <table id="T_a7ac4">
#   <thead>
#     <tr>
#       <th id="T_a7ac4_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_a7ac4_level0_col1" class="col_heading level0 col1" >Best</th>
#       <th id="T_a7ac4_level0_col2" class="col_heading level0 col2" >timestamp</th>
#       <th id="T_a7ac4_level0_col3" class="col_heading level0 col3" >model</th>
#       <th id="T_a7ac4_level0_col4" class="col_heading level0 col4" >mae_train</th>
#       <th id="T_a7ac4_level0_col5" class="col_heading level0 col5" >rmse_train</th>
#       <th id="T_a7ac4_level0_col6" class="col_heading level0 col6" >r2_train</th>
#       <th id="T_a7ac4_level0_col7" class="col_heading level0 col7" >mae_test</th>
#       <th id="T_a7ac4_level0_col8" class="col_heading level0 col8" >rmse_test</th>
#       <th id="T_a7ac4_level0_col9" class="col_heading level0 col9" >r2_test</th>
#       <th id="T_a7ac4_level0_col10" class="col_heading level0 col10" >r2_gap</th>
#       <th id="T_a7ac4_level0_col11" class="col_heading level0 col11" >r2_gap_diagnostic</th>
#       <th id="T_a7ac4_level0_col12" class="col_heading level0 col12" >n_features</th>
#       <th id="T_a7ac4_level0_col13" class="col_heading level0 col13" >interpretation (r2,mae_gap)</th>
#       <th id="T_a7ac4_level0_col14" class="col_heading level0 col14" >ranking_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a7ac4_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a7ac4_row0_col1" class="data row0 col1" >✔</td>
#       <td id="T_a7ac4_row0_col2" class="data row0 col2" >2025-07-12 00:18:51</td>
#       <td id="T_a7ac4_row0_col3" class="data row0 col3" >CatBoost + Optuna CV (All Features – Post-Split Evaluation) [TEST]</td>
#       <td id="T_a7ac4_row0_col4" class="data row0 col4" >48.4 k€</td>
#       <td id="T_a7ac4_row0_col5" class="data row0 col5" >67.6 k€</td>
#       <td id="T_a7ac4_row0_col6" class="data row0 col6" >0.895420</td>
#       <td id="T_a7ac4_row0_col7" class="data row0 col7" >61.9 k€</td>
#       <td id="T_a7ac4_row0_col8" class="data row0 col8" >91.9 k€</td>
#       <td id="T_a7ac4_row0_col9" class="data row0 col9" >0.806515</td>
#       <td id="T_a7ac4_row0_col10" class="data row0 col10" >0.088904</td>
#       <td id="T_a7ac4_row0_col11" class="data row0 col11" >Moderate overfitting</td>
#       <td id="T_a7ac4_row0_col12" class="data row0 col12" >72</td>
#       <td id="T_a7ac4_row0_col13" class="data row0 col13" >overfitting</td>
#       <td id="T_a7ac4_row0_col14" class="data row0 col14" >-153804.750918</td>
#     </tr>
#     <tr>
#       <td id="T_a7ac4_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a7ac4_row1_col1" class="data row1 col1" ></td>
#       <td id="T_a7ac4_row1_col2" class="data row1 col2" >2025-07-12 00:14:19</td>
#       <td id="T_a7ac4_row1_col3" class="data row1 col3" >CatBoost + Optuna CV (All Features – Post-Split Evaluation) [TEST]</td>
#       <td id="T_a7ac4_row1_col4" class="data row1 col4" >45.7 k€</td>
#       <td id="T_a7ac4_row1_col5" class="data row1 col5" >63.7 k€</td>
#       <td id="T_a7ac4_row1_col6" class="data row1 col6" >0.906964</td>
#       <td id="T_a7ac4_row1_col7" class="data row1 col7" >62.1 k€</td>
#       <td id="T_a7ac4_row1_col8" class="data row1 col8" >92.5 k€</td>
#       <td id="T_a7ac4_row1_col9" class="data r

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from utils.constants import PRICE_BINS, PRICE_BIN_LABELS

# === Prepare diagnostic DataFrames ===
residuals_all = y_test_all - y_pred_test_all
residuals_top = y_test_top - y_pred_test_top

df_viz_all = pd.DataFrame({
    "y_true": y_test_all,
    "y_pred": y_pred_test_all,
    "residuals": residuals_all
})
df_viz_all["price_range"] = pd.cut(df_viz_all["y_true"], bins=PRICE_BINS, labels=PRICE_BIN_LABELS)

df_viz_top = pd.DataFrame({
    "y_true": y_test_top,
    "y_pred": y_pred_test_top,
    "residuals": residuals_top
})
df_viz_top["price_range"] = pd.cut(df_viz_top["y_true"], bins=PRICE_BINS, labels=PRICE_BIN_LABELS)

# === Plot diagnostics for CatBoost + Optuna (All Features) ===
plt.figure(figsize=(14, 4))
plt.suptitle("Diagnostics – CatBoost + Optuna (All Features)", fontsize=16)

# Plot 1: Residuals vs Predicted
plt.subplot(1, 3, 1)
plt.scatter(df_viz_all["y_pred"], df_viz_all["residuals"], alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted Price")
plt.ylabel("Residual")
plt.title("Residuals vs Predicted")

# Plot 2: Residual distribution
plt.subplot(1, 3, 2)
sns.histplot(df_viz_all["residuals"], kde=True, color="orange")
plt.xlabel("Residual")
plt.title("Residual Distribution")

# Plot 3: Predicted vs Actual
plt.subplot(1, 3, 3)
plt.scatter(df_viz_all["y_true"], df_viz_all["y_pred"], alpha=0.5)
plt.plot(
    [df_viz_all["y_true"].min(), df_viz_all["y_true"].max()],
    [df_viz_all["y_true"].min(), df_viz_all["y_true"].max()],
    color='red', linestyle='--'
)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Predicted vs Actual")

plt.tight_layout()
plt.show()

# === Residuals by price range – All Features ===
plt.figure(figsize=(8, 4))
sns.boxplot(x="price_range", y="residuals", data=df_viz_all, palette="muted")
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Price Range")
plt.ylabel("Residual")
plt.title("Residuals by Price Range – All Features")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# === Residuals by price range – Top RF Features ===
plt.figure(figsize=(8, 4))
sns.boxplot(x="price_range", y="residuals", data=df_viz_top, palette="coolwarm")
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Price Range")
plt.ylabel("Residual")
plt.title("Residuals by Price Range – Top RF Features")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Neo\AppData\Local\Temp\ipykernel_37200\2044133409.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="price_range", y="residuals", data=df_viz_all, palette="muted")
# C:\Users\Neo\AppData\Local\Temp\ipykernel_37200\2044133409.py:69: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="price_range", y="residuals", data=df_viz_top, palette="coolwarm")

# %%
import sys, os
# Add the project root to the Python path
project_root = os.path.abspath("../..")
sys.path.append(project_root)

import optuna
import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split, KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import mean_squared_error
from utils.constants import ML_READY_DATA_FILE, TEST_MODE
from utils.data_loader import DataLoader
from utils.model_evaluator import ModelEvaluator
from utils.train_test_metrics_logger import TrainTestMetricsLogger
from optuna.samplers import TPESampler
from utils.model_saver import ModelSaver

def root_mean_squared_error(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

if TEST_MODE:
    print("TEST_MODE is ON – reduced data, fewer trials.")
else:
    print("TEST_MODE is OFF – full run.")

# Step 1: Load data
loader = DataLoader(ML_READY_DATA_FILE)
df = loader.load_data()
X = df.drop(columns=["price"])
y = df["price"]

# Remove leakage
leakage_columns = ["price_per_m2", "building_age"]
X = X.drop(columns=[col for col in leakage_columns if col in X.columns], errors="ignore")

# Remove low-variance features
selector = VarianceThreshold(threshold=0.01)
X_reduced = X.loc[:, selector.fit(X).get_support()]

# Feature selection with RF
rf_model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
rf_model.fit(X_reduced, y)
top_features = pd.Series(rf_model.feature_importances_, index=X_reduced.columns).nlargest(30).index.tolist()
X_top = X_reduced[top_features]

# Define tuning function
def tune_catboost_with_optuna(X_data, y_data, n_trials=50):
    def objective(trial):
        params = {
            "iterations": trial.suggest_int("iterations", 300, 500),
            "depth": trial.suggest_int("depth", 4, 7),
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1, log=True),
            "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-3, 10.0, log=True),
            "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.0),
            "random_strength": trial.suggest_float("random_strength", 0.0, 1.0),
            "bootstrap_type": "Bayesian"
        }
        model = CatBoostRegressor(**params, verbose=0, loss_function="RMSE", random_state=42)
        cv = KFold(n_splits=5, shuffle=True, random_state=42)
        scores = []
        for train_idx, val_idx in cv.split(X_data):
            X_train, X_val = X_data.iloc[train_idx], X_data.iloc[val_idx]
            y_train, y_val = y_data.iloc[train_idx], y_data.iloc[val_idx]
            model.fit(X_train, y_train, eval_set=(X_val, y_val), early_stopping_rounds=50)
            preds = model.predict(X_val)
            scores.append(root_mean_squared_error(y_val, preds))
        return np.mean(scores)

    study = optuna.create_study(direction="minimize", sampler=TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)
    return study

# Split data into train+dev / test
X_dev_all, X_test_all, y_dev_all, y_test_all = train_test_split(X_reduced, y, test_size=0.2, random_state=42)
X_dev_top, X_test_top, y_dev_top, y_test_top = train_test_split(X_top, y, test_size=0.2, random_state=42)

n_trials = 3 if TEST_MODE else 50

# Tune and train
study_all = tune_catboost_with_optuna(X_dev_all, y_dev_all, n_trials)
model_all = CatBoostRegressor(**study_all.best_params, verbose=0, loss_function="RMSE", random_state=42)
model_all.fit(X_dev_all, y_dev_all)
y_pred_train_all = model_all.predict(X_dev_all)
y_pred_test_all = model_all.predict(X_test_all)

study_top = tune_catboost_with_optuna(X_dev_top, y_dev_top, n_trials)
model_top = CatBoostRegressor(**study_top.best_params, verbose=0, loss_function="RMSE", random_state=42)
model_top.fit(X_dev_top, y_dev_top)
y_pred_train_top = model_top.predict(X_dev_top)
y_pred_test_top = model_top.predict(X_test_top)

# Step 7: Evaluate models using ModelEvaluator
# All Features Evaluation
evaluator_all = ModelEvaluator("CatBoost + Optuna CV (All Features)")
metrics_train_all, range_train_all = evaluator_all.evaluate(y_dev_all, y_pred_train_all, dataset_type="Train")
metrics_test_all, range_test_all = evaluator_all.evaluate(y_test_all, y_pred_test_all, dataset_type="Test")

# Top RF Features Evaluation
evaluator_top = ModelEvaluator("CatBoost + Optuna CV (Top RF Features)")
metrics_train_top, range_train_top = evaluator_top.evaluate(y_dev_top, y_pred_train_top, dataset_type="Train")
metrics_test_top, range_test_top = evaluator_top.evaluate(y_test_top, y_pred_test_top, dataset_type="Test")

# Extract R² values to compute overfitting gap
r2_train_all = metrics_train_all["r2"]
r2_test_all = metrics_test_all["r2"]
r2_train_top = metrics_train_top["r2"]
r2_test_top = metrics_test_top["r2"]

# Step 8: Log all metrics using TrainTestMetricsLogger
logger = TrainTestMetricsLogger()

logger.log(
    model_name=f"CatBoost + Optuna CV (All Features – R² gap evaluated){' [TEST]' if TEST_MODE else ''}",
    experiment_name="CatBoost Optuna – All Features",
    mae_train=metrics_train_all["mae"], rmse_train=metrics_train_all["rmse"], r2_train=r2_train_all,
    mae_test=metrics_test_all["mae"], rmse_test=metrics_test_all["rmse"], r2_test=r2_test_all,
    data_file=ML_READY_DATA_FILE, n_features=X_dev_all.shape[1]
)

logger.log(
    model_name=f"CatBoost + Optuna CV (Top RF Features – R² gap evaluated){' [TEST]' if TEST_MODE else ''}",
    experiment_name="CatBoost Optuna – Top 30 RF Features",
    mae_train=metrics_train_top["mae"], rmse_train=metrics_train_top["rmse"], r2_train=r2_train_top,
    mae_test=metrics_test_top["mae"], rmse_test=metrics_test_top["rmse"], r2_test=r2_test_top,
    data_file=ML_READY_DATA_FILE, n_features=X_dev_top.shape[1]
)

# Step 9: Print R² gaps to assess overfitting
print(f"\nR² Gap (All Features): {r2_train_all - r2_test_all:.4f}")
print(f"R² Gap (Top RF Features): {r2_train_top - r2_test_top:.4f}")

# Step 10: Detailed performance by price range
price_bins = [0, 100_000, 200_000, 300_000, 400_000, float("inf")]

print("\n[Evaluation by Price Range – All Features]")
evaluator_all.print_evaluation(y_test_all, y_pred_test_all, bins=price_bins)

print("\n[Evaluation by Price Range – Top RF Features]")
evaluator_top.print_evaluation(y_test_top, y_pred_test_top, bins=price_bins)


# Step 9: Save models, features and metrics
saver = ModelSaver()

# Save CatBoost All Features
saver.save_model_and_features(
    model=model_all,
    features=X_train_all.columns.tolist(),
    model_name=f"CatBoost + Optuna CV (All Features – R² gap evaluated){' [TEST]' if TEST_MODE else ''}",
    metrics=metrics_test_all,
    metrics_by_price_range=evaluator_all._compute_metrics_by_price_range(
        y_test_all, y_pred_test_all, bins=[0, 100_000, 200_000, 300_000, 400_000, float("inf")]
    )
)

# Save CatBoost Top RF Features
saver.save_model_and_features(
    model=model_top,
    features=X_train_top.columns.tolist(),
    model_name=f"CatBoost + Optuna CV (Top RF Features – R² gap evaluated){' [TEST]' if TEST_MODE else ''}",
    metrics=metrics_test_top,
    metrics_by_price_range=evaluator_top._compute_metrics_by_price_range(
        y_test_top, y_pred_test_top, bins=[0, 100_000, 200_000, 300_000, 400_000, float("inf")]
    )
)

# Step 11: Display summary table of all logged experiments
logger.display_table()
# Out:
# TEST_MODE is ON – reduced data, fewer trials.
# [I 2025-07-12 00:32:51,011] A new study created in memory with name: no-name-898fc5fc-76e3-4984-aee9-c83deeafffa9
# [I 2025-07-12 00:32:58,674] Trial 0 finished with value: 98127.55255925466 and parameters: {'iterations': 375, 'depth': 7, 'learning_rate': 0.05395030966670229, 'l2_leaf_reg': 0.24810409748678125, 'bagging_temperature': 0.15601864044243652, 'random_strength': 0.15599452033620265}. Best is trial 0 with value: 98127.55255925466.
# [W 2025-07-12 00:33:00,492] Trial 1 failed with parameters: {'iterations': 311, 'depth': 7, 'learning_rate': 0.039913058785616795, 'l2_leaf_reg': 0.679657809075816, 'bagging_temperature': 0.020584494295802447, 'random_strength': 0.9699098521619943} because of the following error: KeyboardInterrupt('').
# Traceback (most recent call last):
#   File "e:\_SoftEng\_BeCode\real-estate-price-predictor\.venv\Lib\site-packages\optuna\study\_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\Neo\AppData\Local\Temp\ipykernel_40276\3323827096.py", line 67, in objective
#     model.fit(X_train, y_train, eval_set=(X_val, y_val), early_stopping_rounds=50)
#   File "e:\_SoftEng\_BeCode\real-estate-price-predictor\.venv\Lib\site-packages\catboost\core.py", line 5807, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\_SoftEng\_BeCode\real-estate-price-predictor\.venv\Lib\site-packages\catboost\core.py", line 2396, in _fit
#     self._train(
#   File "e:\_SoftEng\_BeCode\real-estate-price-predictor\.venv\Lib\site-packages\catboost\core.py", line 1776, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4833, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4882, in _catboost._CatBoost._train
# KeyboardInterrupt
# [W 2025-07-12 00:33:00,508] Trial 1 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 83
#      80 n_trials = 3 if TEST_MODE else 50
#      82 # Tune and train
# ---> 83 study_all = tune_catboost_with_optuna(X_dev_all, y_dev_all, n_trials)
#      84 model_all = CatBoostRegressor(**study_all.best_params, verbose=0, loss_function="RMSE", random_state=42)
#      85 model_all.fit(X_dev_all, y_dev_all)
#
# Cell In[3], line 73, in tune_catboost_with_optuna(X_data, y_data, n_trials)
#      70     return np.mean(scores)
#      72 study = optuna.create_study(direction="minimize", sampler=TPESampler(seed=42))
# ---> 73 study.optimize(objective, n_trials=n_trials)
#      74 return study
#
# File e:\_SoftEng\_BeCode\real-estate-price-predictor\.venv\Lib\site-packages\optuna\study\study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)    357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File e:\_SoftEng\_BeCode\real-estate-price-predictor\.venv\Lib\site-packages\optuna\study\_optimize.py:62, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      60 try:
#      61     if n_jobs == 1:
# ---> 62         _optimize_sequential(
#      63             study,
#      64             func,
#      65             n_trials,
#      66             timeout,
#      67             catch,
#      68             callbacks,
#      69             gc_after_trial,
#      70             reseed_sampler_rng=False,
#      71             time_start=None,
#      72             progress_bar=progress_bar,
#      73         )
#      74     else:
#      75         if n_jobs == -1:
#
# File e:\_SoftEng\_BeCode\real-estate-price-predictor\.venv\Lib\site-packages\optuna\study\_optimize.py:159, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     156         break
#     158 try:
# --> 159     frozen_trial = _run_trial(study, func, catch)
#     160 finally:
#     161     # The following line mitigates memory problems that can be occurred in some
#     162     # environments (e.g., services that use computing containers such as GitHub Actions).
#     163     # Please refer to the following PR for further details:
#     164     # https://github.com/optuna/optuna/pull/325.
#     165     if gc_after_trial:
#
# File e:\_SoftEng\_BeCode\real-estate-price-predictor\.venv\Lib\site-packages\optuna\study\_optimize.py:247, in _run_trial(study, func, catch)
#     240         assert False, "Should not reach."
#     242 if (
#     243     frozen_trial.state == TrialState.FAIL
#     244     and func_err is not None
#     245     and not isinstance(func_err, catch)
#     246 ):
# --> 247     raise func_err
#     248 return frozen_trial
#
# File e:\_SoftEng\_BeCode\real-estate-price-predictor\.venv\Lib\site-packages\optuna\study\_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# Cell In[3], line 67, in tune_catboost_with_optuna.<locals>.objective(trial)
#      65 X_train, X_val = X_data.iloc[train_idx], X_data.iloc[val_idx]
#      66 y_train, y_val = y_data.iloc[train_idx], y_data.iloc[val_idx]
# ---> 67 model.fit(X_train, y_train, eval_set=(X_val, y_val), early_stopping_rounds=50)
#      68 preds = model.predict(X_val)
#      69 scores.append(root_mean_squared_error(y_val, preds))
#
# File e:\_SoftEng\_BeCode\real-estate-price-predictor\.venv\Lib\site-packages\catboost\core.py:5807, in CatBoostRegressor.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5804 if 'loss_function' in params:
#    5805     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> 5807 return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#    5808                  use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    5809                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    5810                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File e:\_SoftEng\_BeCode\real-estate-price-predictor\.venv\Lib\site-packages\catboost\core.py:2396, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2393 allow_clear_pool = train_params["allow_clear_pool"]
#    2395 with plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2396     self._train(
#    2397         train_pool,
#    2398         train_params["eval_sets"],
#    2399         params,
#    2400         allow_clear_pool,
#    2401         train_params["init_model"]
#    2402     )
#    2404 # Have property feature_importance possibly set
#    2405 loss = self._object._get_loss_function_name()
#
# File e:\_SoftEng\_BeCode\real-estate-price-predictor\.venv\Lib\site-packages\catboost\core.py:1776, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1775 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1776     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1777     self._set_trained_model_attributes()
#
# File _catboost.pyx:4833, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4882, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %% [markdown]
# # Saving CatBoost + Optuna Hyperparameter Tuning Models (`.pkl`) After Training
#
# After training CatBoost models with Optuna tuning, it is essential to persist the trained models using `.pkl` files. The following script handles this process by creating timestamped filenames and saving them to the appropriate directory.
#
#
# ## What the Script Does
#
# 1. **Appends the project root** to the Python path (for relative imports).
# 2. **Generates a timestamped filename**, with an optional `_TEST` suffix if `TEST_MODE` is enabled.
# 3. **Ensures the target directory exists** and removes any conflicting file with the same name.
# 4. **Saves both models**:
#    - One trained with **all features**.
#    - One trained with the **top 30 features** (selected via Random Forest).

# %%
import sys, os

# Add the project root to the Python path
project_root = os.path.abspath("../..")
sys.path.append(project_root)

import joblib
from datetime import datetime
from utils.constants import TEST_MODE, MODELS_DIR

# Create timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M")

# Add suffix if in TEST mode
suffix = "_TEST" if TEST_MODE else ""

# Define subdirectory for .pkl files
PKL_DIR = os.path.join(MODELS_DIR, "pkl")
if os.path.isfile(PKL_DIR):
    os.remove(PKL_DIR)  # Remove conflicting file if it exists
os.makedirs(PKL_DIR, exist_ok=True)

# Build filenames
filename_all = f"catboost_optuna_all_{timestamp}{suffix}.pkl"
filename_top = f"catboost_optuna_top30_{timestamp}{suffix}.pkl"

# Save models
joblib.dump(model_all, os.path.join(PKL_DIR, filename_all))
joblib.dump(model_top, os.path.join(PKL_DIR, filename_top))

print(f"[✔] CatBoost models saved to '{PKL_DIR}' as:\n - {filename_all}\n - {filename_top}")
# Out:
# [✔] CatBoost models saved to 'e:\_SoftEng\_BeCode\real-estate-price-predictor\models\pkl' as:
#  - catboost_optuna_all_20250711_2342_TEST.pkl
#  - catboost_optuna_top30_20250711_2342_TEST.pkl

# %% [markdown]
# # Saving CatBoost Models and Their Feature Lists
#
# After training CatBoost models using **all features** and **top 30 features**, it is important to save both the models (`.pkl`) and their associated feature lists (`.json`). This ensures proper inference and avoids feature mismatch errors.
#
#
# ## Directory Structure
#
# All model files are stored under the `models/` directory:
#
# ## Why Save JSON Feature Files
#
# Each `.pkl` model is trained with a specific list of input features:
#
# - **All features model** uses all selected input columns (after variance threshold)
# - **Top30 model** uses only the top 30 features selected by Random Forest
#
# Saving these lists in `.json` format allows:
#
# - Correct feature alignment during inference
# - Avoiding runtime errors (e.g., feature mismatch)
# - Easier model reproducibility
#
#
#
# ## Naming Convention
#
# Each `.json` file has the same base name as the `.pkl` model it corresponds to.
#
# | Model file (`.pkl`)                              | Feature file (`.json`)                             |
# |--------------------------------------------------|----------------------------------------------------|
# | `catboost_optuna_all_20250629_1030_TEST.pkl`     | `catboost_optuna_all_20250629_1030_TEST.json`     |
# | `catboost_optuna_top30_20250629_1030_TEST.pkl`   | `catboost_optuna_top30_20250629_1030_TEST.json`   |
#
# ---

# %%
import json

# Define subdirectory for JSON feature files
FEATURES_DIR = os.path.join(MODELS_DIR, "features")
os.makedirs(FEATURES_DIR, exist_ok=True)

# Save features used for each model (All Features and Top30)
feature_file_all = filename_all.replace(".pkl", ".json")
feature_file_top = filename_top.replace(".pkl", ".json")

with open(os.path.join(FEATURES_DIR, feature_file_all), "w") as f:
    json.dump(list(X_reduced.columns), f, indent=2)

with open(os.path.join(FEATURES_DIR, feature_file_top), "w") as f:
    json.dump(top_features, f, indent=2)

print(f"[✔] Associated feature JSON files saved to '{FEATURES_DIR}' as:\n - {feature_file_all}\n - {feature_file_top}")
# Out:
# [✔] Associated feature JSON files saved to 'e:\_SoftEng\_BeCode\real-estate-price-predictor\models\features' as:
#  - catboost_optuna_all_20250711_2342_TEST.json
#  - catboost_optuna_top30_20250711_2342_TEST.json
