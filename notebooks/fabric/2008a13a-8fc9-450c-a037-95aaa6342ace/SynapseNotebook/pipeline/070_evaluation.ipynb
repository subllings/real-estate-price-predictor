# %%
import sys, os
# Add the project root to the Python path
project_root = os.path.abspath("../../..")
sys.path.append(project_root)
from utils.train_test_metrics_logger import TrainTestMetricsLogger

# Show summary table
logger = TrainTestMetricsLogger()
logger.display_table()
# Out:
# <style type="text/css">
# #T_4d6fb th.col_heading.level0:nth-child(5) {
#   background-color: #fff9c4;
# }
# #T_4d6fb th.col_heading.level0:nth-child(6) {
#   background-color: #fff9c4;
# }
# #T_4d6fb th.col_heading.level0:nth-child(7) {
#   background-color: #fff9c4;
# }
# #T_4d6fb th.col_heading.level0:nth-child(8) {
#   background-color: #f9c5c0;
# }
# #T_4d6fb th.col_heading.level0:nth-child(9) {
#   background-color: #f9c5c0;
# }
# #T_4d6fb th.col_heading.level0:nth-child(10) {
#   background-color: #f9c5c0;
# }
# #T_4d6fb_row0_col0, #T_4d6fb_row0_col1, #T_4d6fb_row0_col2, #T_4d6fb_row0_col3, #T_4d6fb_row0_col4, #T_4d6fb_row0_col5, #T_4d6fb_row0_col6, #T_4d6fb_row0_col7, #T_4d6fb_row0_col8, #T_4d6fb_row0_col9, #T_4d6fb_row0_col10, #T_4d6fb_row0_col12, #T_4d6fb_row0_col14 {
#   background-color: #4caf50;
#   color: white;
# }
# #T_4d6fb_row0_col11 {
#   background-color: #4caf50;
#   color: white;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_4d6fb_row0_col13 {
#   background-color: #4caf50;
#   color: white;
#   background-color: #1565c0;
#   color: white;
# }
# #T_4d6fb_row1_col0, #T_4d6fb_row1_col1, #T_4d6fb_row1_col2, #T_4d6fb_row1_col3, #T_4d6fb_row1_col4, #T_4d6fb_row1_col5, #T_4d6fb_row1_col6, #T_4d6fb_row1_col7, #T_4d6fb_row1_col8, #T_4d6fb_row1_col9, #T_4d6fb_row1_col10, #T_4d6fb_row1_col12, #T_4d6fb_row1_col14, #T_4d6fb_row15_col11, #T_4d6fb_row17_col11 {
#   background-color: #81c784;
#   color: black;
# }
# #T_4d6fb_row1_col11 {
#   background-color: #81c784;
#   color: black;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_4d6fb_row1_col13 {
#   background-color: #81c784;
#   color: black;
#   background-color: #1565c0;
#   color: white;
# }
# #T_4d6fb_row2_col0, #T_4d6fb_row2_col1, #T_4d6fb_row2_col2, #T_4d6fb_row2_col3, #T_4d6fb_row2_col4, #T_4d6fb_row2_col5, #T_4d6fb_row2_col6, #T_4d6fb_row2_col7, #T_4d6fb_row2_col8, #T_4d6fb_row2_col9, #T_4d6fb_row2_col10, #T_4d6fb_row2_col12, #T_4d6fb_row2_col14 {
#   background-color: #c8e6c9;
#   color: black;
# }
# #T_4d6fb_row2_col11 {
#   background-color: #c8e6c9;
#   color: black;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_4d6fb_row2_col13 {
#   background-color: #c8e6c9;
#   color: black;
#   background-color: #1565c0;
#   color: white;
# }
# #T_4d6fb_row3_col11, #T_4d6fb_row4_col11, #T_4d6fb_row5_col11, #T_4d6fb_row6_col11, #T_4d6fb_row7_col11 {
#   background-color: #ffcc80;
#   color: black;
# }
# #T_4d6fb_row3_col13, #T_4d6fb_row4_col13, #T_4d6fb_row5_col13, #T_4d6fb_row6_col13, #T_4d6fb_row7_col13, #T_4d6fb_row8_col13, #T_4d6fb_row9_col13, #T_4d6fb_row10_col13, #T_4d6fb_row11_col13, #T_4d6fb_row18_col13, #T_4d6fb_row19_col13, #T_4d6fb_row20_col13, #T_4d6fb_row21_col13 {
#   background-color: #1565c0;
#   color: white;
# }
# #T_4d6fb_row8_col11, #T_4d6fb_row9_col11, #T_4d6fb_row10_col11, #T_4d6fb_row11_col11, #T_4d6fb_row18_col11, #T_4d6fb_row19_col11, #T_4d6fb_row20_col11, #T_4d6fb_row21_col11 {
#   background-color: #ef9a9a;
#   color: black;
# }
# #T_4d6fb_row12_col11, #T_4d6fb_row13_col11, #T_4d6fb_row14_col11, #T_4d6fb_row16_col11 {
#   background-color: #aed581;
#   color: black;
# }
# #T_4d6fb_row12_col13, #T_4d6fb_row13_col13, #T_4d6fb_row14_col13, #T_4d6fb_row15_col13, #T_4d6fb_row16_col13, #T_4d6fb_row17_col13 {
#   background-color: #1976d2;
#   color: white;
# }
# </style>
# <table id="T_4d6fb">
#   <thead>
#     <tr>
#       <th id="T_4d6fb_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_4d6fb_level0_col1" class="col_heading level0 col1" >Best</th>
#       <th id="T_4d6fb_level0_col2" class="col_heading level0 col2" >timestamp</th>
#       <th id="T_4d6fb_level0_col3" class="col_heading level0 col3" >model</th>
#       <th id="T_4d6fb_level0_col4" class="col_heading level0 col4" >mae_train</th>
#       <th id="T_4d6fb_level0_col5" class="col_heading level0 col5" >rmse_train</th>
#       <th id="T_4d6fb_level0_col6" class="col_heading level0 col6" >r2_train</th>
#       <th id="T_4d6fb_level0_col7" class="col_heading level0 col7" >mae_test</th>
#       <th id="T_4d6fb_level0_col8" class="col_heading level0 col8" >rmse_test</th>
#       <th id="T_4d6fb_level0_col9" class="col_heading level0 col9" >r2_test</th>
#       <th id="T_4d6fb_level0_col10" class="col_heading level0 col10" >r2_gap</th>
#       <th id="T_4d6fb_level0_col11" class="col_heading level0 col11" >r2_gap_diagnostic</th>
#       <th id="T_4d6fb_level0_col12" class="col_heading level0 col12" >n_features</th>
#       <th id="T_4d6fb_level0_col13" class="col_heading level0 col13" >interpretation (r2,mae_gap)</th>
#       <th id="T_4d6fb_level0_col14" class="col_heading level0 col14" >ranking_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4d6fb_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_4d6fb_row0_col1" class="data row0 col1" >✔</td>
#       <td id="T_4d6fb_row0_col2" class="data row0 col2" >2025-07-12 02:26:07</td>
#       <td id="T_4d6fb_row0_col3" class="data row0 col3" >CatBoost + Optuna CV (All Features – Post-Split Evaluation)</td>
#       <td id="T_4d6fb_row0_col4" class="data row0 col4" >41.2 k€</td>
#       <td id="T_4d6fb_row0_col5" class="data row0 col5" >56.8 k€</td>
#       <td id="T_4d6fb_row0_col6" class="data row0 col6" >0.926001</td>
#       <td id="T_4d6fb_row0_col7" class="data row0 col7" >61.1 k€</td>
#       <td id="T_4d6fb_row0_col8" class="data row0 col8" >91.4 k€</td>
#       <td id="T_4d6fb_row0_col9" class="data row0 col9" >0.808525</td>
#       <td id="T_4d6fb_row0_col10" class="data row0 col10" >0.117476</td>
#       <td id="T_4d6fb_row0_col11" class="data row0 col11" >Moderate overfitting</td>
#       <td id="T_4d6fb_row0_col12" class="data row0 col12" >72</td>
#       <td id="T_4d6fb_row0_col13" class="data row0 col13" >overfitting</td>
#       <td id="T_4d6fb_row0_col14" class="data row0 col14" >-152492.956535</td>
#     </tr>
#     <tr>
#       <td id="T_4d6fb_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_4d6fb_row1_col1" class="data row1 col1" ></td>
#       <td id="T_4d6fb_row1_col2" class="data row1 col2" >2025-07-12 02:26:07</td>
#       <td id="T_4d6fb_row1_col3" class="data row1 col3" >CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation)</td>
#       <td id="T_4d6fb_row1_col4" class="data row1 col4" >44.6 k€</td>
#       <td id="T_4d6fb_row1_col5" class="data row1 col5" >61.6 k€</td>
#       <td id="T_4d6fb_row1_col6" class="data row1 col6" >0.912976</td>
#       <td id="T_4d6fb_row1_col7" class="data row1 col7" >61.9 k€</td>
#       <td id="T_4d6fb_row1_col8" class="data row1 col8" >91.6 k€</td>
#       <td id="T_4d6fb_row1_col9" class="data row1 col9" >0.807559</td>
#       <td id="T_4d6fb_row1_col10" class="data row1 col10" >0.105417</td>
#       <td id="T_4d6fb_row1_col11" class="data row1 col11" >Moderate overfitting</td>
#       <td id="T_4d6fb_row1_col12" class="data row1 col12" >30</td>
#       <td id="T_4d6fb_row1_col13" class="data row1 col13" >overfitting</td>
#       <td id="T_4d6fb_row1_col14" class="data row1 col14" >-153485.115075</td>
#     </tr>
#     <tr>
#       <td id="T_4d6fb_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_4d6fb_row2_col1" class="data row2 col1" ></td>
#       <td id="T_4d6fb_row2_col2" class="data row2 col2" >2025-07-12 02:38:07</td>
#       <td id="T_4d6fb_row2_col3" class="data row2 col3" >CatBoost + Optuna CV (Top RF Features – R² gap evaluated)</td>
#       <td id="T_4d6fb_row2_col4" class="data row2 col4" >49.7 k€</td>
#       <td id="T_4d6fb_row2_col5" class="data row2 col5" >69.4 k€</td>
#       <td id="T_4d6fb_row2_col6" class="data row2 col6" >0.889556</td>
#       <td id="T_4d6fb_row2_col7" class="data row2 col7" >62.6 k€</td>
#       <td id="T_4d6fb_row2_col8" class="data row2 col8" >92.6 k€</td>
#       <td id="T_4d6fb_row2_col9" class="data row2 col9" >0.803436</td>
#       <td id="T_4d6fb_row2_col10" class="data row2 col10" >0.086120</td>
#       <td id="T_4d6fb_row2_col11" class="data row2 col11" >Moderate overfitting</td>
#       <td id="T_4d6fb_row2_col12" class="data row2 col12" >30</td>
#       <td id="T_4d6fb_row2_col13" class="data row2 col13" >overfitting</td>
#       <td id="T_4d6fb_row2_col14" class="data row2 col14" >-155187.169580</td>
#     </tr>
#     <tr>
#       <td id="T_4d6fb_
