# %% [markdown]
# ## Baseline CatBoost Regression (GPU Fallback Compatible)
#
# This notebook cell trains **two baseline CatBoost models** to predict real estate prices:
#
# - One with **all filtered features** (low-variance features removed)
# - One with **top 30 features** selected via Random Forest importance
#
# The goal is to quickly evaluate CatBoost performance **without Optuna tuning**, while ensuring **GPU compatibility with CPU fallback**.
#
#
# ###  Library Imports
#
# Includes:
# - `catboost` for gradient boosting on decision trees
# - `sklearn` for feature selection and evaluation
# - Custom modules:
#   - `DataLoader` to load the cleaned ML dataset
#   - `ModelEvaluator`, `ModelVisualizer`, `ExperimentTracker` for tracking, evaluation and plotting
#
#
#
# ### Data Preparation
#
# - Loads the cleaned dataset via `DataLoader`
# - Removes low-variance features with `VarianceThreshold`
# - Uses `RandomForestRegressor` to extract the **top 30 most important features**
#
#
# ### Model Training with GPU Fallback
#
# Defines a helper `train_with_fallback(...)` function that:
# - Tries to train CatBoost on GPU (`task_type="GPU"`)
# - If it fails (e.g., no GPU), it **automatically falls back to CPU**
#
# Models are trained on:
# - `X_reduced`: all filtered features
# - `X_top`: only the top 30 features
#
#
# ### Model Evaluation
#
# Each model is evaluated using:
# - **MAE** (Mean Absolute Error)
# - **RMSE** (Root Mean Squared Error)
# - **R<sup>2</sup>** (Coefficient of Determination)
#
# Results are logged using `ExperimentTracker`.
#
#
# ### Diagnostics & Visualization
#
# - Summary of model metrics is displayed in tables
# - Diagnostic plots generated with `ModelVisualizer`:
#   - Residuals
#   - Prediction distribution
#   - Error across price ranges
# - A **side-by-side residual plot** compares both models
#
#
# ### Test Mode Support
#
# If `TEST_MODE = True`:
# - Dataset size and number of iterations are reduced
# - Useful for debugging and fast iterations
#
# ### Summary
#
# This cell provides a **fast, robust, GPU-aware CatBoost baseline**, ideal for:
# - Comparing with tuned models (e.g., XGBoost + Optuna)
# - Benchmarking preprocessing strategies
# - Validating GPU/CPU execution paths

# %%
import sys, os
# Add the project root to the Python path
project_root = os.path.abspath("../../..")
sys.path.append(project_root)

import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from utils.constants import ML_READY_DATA_FILE, TEST_MODE
from utils.data_loader import DataLoader
from utils.model_evaluator import ModelEvaluator

from utils.train_test_metrics_logger import TrainTestMetricsLogger

def root_mean_squared_error(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

if TEST_MODE:
    print("TEST_MODE is ON – using reduced dataset and fewer estimators.")
else:
    print("TEST_MODE is OFF – full training in progress.")

# Step 1: Load data
loader = DataLoader(ML_READY_DATA_FILE)
df = loader.load_data()
X = df.drop(columns=["price"])
y = df["price"]

# Step 2: Remove low-variance features
selector = VarianceThreshold(threshold=0.01)
X_reduced = X.loc[:, selector.fit(X).get_support()]

# Step 3: Extract top 30 features using RandomForest
rf_model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
rf_model.fit(X_reduced, y)
top_features = pd.Series(rf_model.feature_importances_, index=X_reduced.columns).nlargest(30).index.tolist()
X_top = X_reduced[top_features]

# === AJOUT : split train/test pour avoir X_train_all et X_train_top ===
X_train_all, X_test_all, y_train_all, y_test_all = train_test_split(
    X_reduced, y, test_size=0.2, random_state=42
)
X_train_top, X_test_top, y_train_top, y_test_top = train_test_split(
    X_top, y, test_size=0.2, random_state=42
)
# ===============================================================

# Step 4: Define baseline CatBoost parameters
default_params = {
    "iterations": 500 if not TEST_MODE else 50,
    "depth": 6,
    "learning_rate": 0.1,
    "loss_function": "RMSE",
    "verbose": 0,
    "random_seed": 42
}

# Step 5: Train models with fallback (GPU to CPU)
def train_with_fallback(X_train, y_train, model_name):
    try:
        print(f"Training {model_name} on GPU...")
        model = CatBoostRegressor(**default_params, task_type="GPU", devices="0")
        model.fit(
            X_train, y_train,
            eval_set=(X_train, y_train),
            early_stopping_rounds=50
        )
    except Exception as e:
        print(f"⚠️ GPU training failed for {model_name}. Falling back to CPU.\nReason: {e}")
        model = CatBoostRegressor(**default_params, task_type="CPU")
        model.fit(
            X_train, y_train,
            eval_set=(X_train, y_train),
            early_stopping_rounds=50
        )
    return model


# Train and predict using all features
model_all = train_with_fallback(X_train_all, y_train_all, "CatBoost (All Features)")
y_pred_all = model_all.predict(X_test_all)

# Train and predict using top features
model_top = train_with_fallback(X_train_top, y_train_top, "CatBoost (Top RF Features)")
y_pred_top = model_top.predict(X_test_top)

# Step 6: Evaluate CatBoost models on test set

# Define price bins for range-based evaluation
price_bins = [0, 250_000, 500_000, 750_000, 1_000_000, float("inf")]

# Evaluation – All Features
evaluator_all = ModelEvaluator("CatBoost (All Features)")
metrics_all, range_metrics_all = evaluator_all.evaluate(y_test_all, y_pred_all, bins=price_bins, dataset_type="Test")
evaluator_all.print_evaluation(y_test_all, y_pred_all, bins=price_bins);

# Extract global metrics
mae_all = metrics_all["mae"]
rmse_all = metrics_all["rmse"]
r2_all = metrics_all["r2"]

# Evaluation – Top RF Features
evaluator_top = ModelEvaluator("CatBoost (Top RF Features)")
metrics_top, range_metrics_top = evaluator_top.evaluate(y_test_top, y_pred_top, bins=price_bins, dataset_type="Test")
evaluator_top.print_evaluation(y_test_top, y_pred_top, bins=price_bins)

# Extract global metrics
mae_top = metrics_top["mae"]
rmse_top = metrics_top["rmse"]
r2_top = metrics_top["r2"]

# Step 7: Log metrics using TrainTestMetricsLogger

logger = TrainTestMetricsLogger()

logger.log(
    model_name=f"CatBoost (All Features){' [TEST]' if TEST_MODE else ''}",
    experiment_name=f"CatBoost Baseline (All Features){' [TEST]' if TEST_MODE else ''}",
    mae_train=mae_all,  # Here, test and train are equal due to baseline eval
    rmse_train=rmse_all,
    r2_train=r2_all,
    mae_test=mae_all,
    rmse_test=rmse_all,
    r2_test=r2_all,
    data_file=ML_READY_DATA_FILE,
    n_features=X_train_all.shape[1]
)

logger.log(
    model_name=f"CatBoost (Top RF Features){' [TEST]' if TEST_MODE else ''}",
    experiment_name=f"CatBoost Baseline (Top RF Features){' [TEST]' if TEST_MODE else ''}",
    mae_train=mae_top,
    rmse_train=rmse_top,
    r2_train=r2_top,
    mae_test=mae_top,
    rmse_test=rmse_top,
    r2_test=r2_top,
    data_file=ML_READY_DATA_FILE,
    n_features=X_train_top.shape[1]
)

# Step 8: Display summary table of all logged experiments
logger.display_table()
# Out:
# TEST_MODE is OFF – full training in progress.
# Training CatBoost (All Features) on GPU...
# Training CatBoost (Top RF Features) on GPU...
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:98: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:98: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:98: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:98: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# [CatBoost (All Features)] Evaluation on Test set
#   MAE:  65,182.13 €
#   RMSE: 96,415.06 €
#   R²:   0.7870
# ----------------------------------------
# [DEBUG] Call print_evaluation for CatBoost (All Features)
# [DEBUG] y_true: 4028, y_pred: 4028
#
# Evaluation – CatBoost (All Features)
#   MAE:  65,182.13 €
#   RMSE: 96,415.06 €
#   R²:   0.7870
# ----------------------------------------
# [DEBUG] Segments found: 5
# [Evaluation by Price Range – All Features]
#           Price Range    n    MAE (€)   RMSE (€)     R²
#       (0.0, 250000.0] 1044  41,868.17  57,033.50  -0.82
#  (250000.0, 500000.0] 2086  53,787.97  72,954.70  -0.03
#  (500000.0, 750000.0]  605  91,104.26 114,444.66  -1.83
# (750000.0, 1000000.0]  232 147,477.18 189,723.89  -5.85
#      (1000000.0, inf]   61 283,750.30 330,681.92 -36.01
# ----------------------------------------
# [CatBoost (Top RF Features)] Evaluation on Test set
#   MAE:  66,212.33 €
#   RMSE: 97,215.29 €
#   R²:   0.7834
# ----------------------------------------
# [DEBUG] Call print_evaluation for CatBoost (Top RF Features)
# [DEBUG] y_true: 4028, y_pred: 4028
#
# Evaluation – CatBoost (Top RF Features)
#   MAE:  66,212.33 €
#   RMSE: 97,215.29 €
#   R²:   0.7834
# ----------------------------------------
# [DEBUG] Segments found: 5
# [Evaluation by Price Range – All Features]
#           Price Range    n    MAE (€)   RMSE (€)     R²
#       (0.0, 250000.0] 1044  43,347.22  58,371.61  -0.91
#  (250000.0, 500000.0] 2086  54,555.92  73,868.00  -0.06
#  (500000.0, 750000.0]  605  92,181.97 115,638.90  -1.89
# (750000.0, 1000000.0]  232 149,325.40 190,619.28  -5.91
#      (1000000.0, inf]   61 282,484.34 329,140.30 -35.67
# ----------------------------------------
# <style type="text/css">
# #T_46550 th.col_heading.level0:nth-child(5) {
#   background-color: #fff9c4;
# }
# #T_46550 th.col_heading.level0:nth-child(6) {
#   background-color: #fff9c4;
# }
# #T_46550 th.col_heading.level0:nth-child(7) {
#   background-color: #fff9c4;
# }
# #T_46550 th.col_heading.level0:nth-child(8) {
#   background-color: #f9c5c0;
# }
# #T_46550 th.col_heading.level0:nth-child(9) {
#   background-color: #f9c5c0;
# }
# #T_46550 th.col_heading.level0:nth-child(10) {
#   background-color: #f9c5c0;
# }
# #T_46550_row0_col0, #T_46550_row0_col1, #T_46550_row0_col2, #T_46550_row0_col3, #T_46550_row0_col4, #T_46550_row0_col5, #T_46550_row0_col6, #T_46550_row0_col7, #T_46550_row0_col8, #T_46550_row0_col9, #T_46550_row0_col10, #T_46550_row0_col12, #T_46550_row0_col14 {
#   background-color: #4caf50;
#   color: white;
# }
# #T_46550_row0_col11 {
#   background-color: #4caf50;
#   color: white;
#   background-color: #81c784;
#   color: black;
# }
# #T_46550_row0_col13 {
#   background-color: #4caf50;
#   color: white;
#   background-color: #1976d2;
#   color: white;
# }
# #T_46550_row1_col0, #T_46550_row1_col1, #T_46550_row1_col2, #T_46550_row1_col3, #T_46550_row1_col4, #T_46550_row1_col5, #T_46550_row1_col6, #T_46550_row1_col7, #T_46550_row1_col8, #T_46550_row1_col9, #T_46550_row1_col10, #T_46550_row1_col12, #T_46550_row1_col14 {
#   background-color: #81c784;
#   color: black;
# }
# #T_46550_row1_col11 {
#   background-color: #81c784;
#   color: black;
#   background-color: #81c784;
#   color: black;
# }
# #T_46550_row1_col13 {
#   background-color: #81c784;
#   color: black;
#   background-color: #1976d2;
#   color: white;
# }
# </style>
# <table id="T_46550">
#   <thead>
#     <tr>
#       <th id="T_46550_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_46550_level0_col1" class="col_heading level0 col1" >Best</th>
#       <th id="T_46550_level0_col2" class="col_heading level0 col2" >timestamp</th>
#       <th id="T_46550_level0_col3" class="col_heading level0 col3" >model</th>
#       <th id="T_46550_level0_col4" class="col_heading level0 col4" >mae_train</th>
#       <th id="T_46550_level0_col5" class="col_heading level0 col5" >rmse_train</th>
#       <th id="T_46550_level0_col6" class="col_heading level0 col6" >r2_train</th>
#       <th id="T_46550_level0_col7" class="col_heading level0 col7" >mae_test</th>
#       <th id="T_46550_level0_col8" class="col_heading level0 col8" >rmse_test</th>
#       <th id="T_46550_level0_col9" class="col_heading level0 col9" >r2_test</th>
#       <th id="T_46550_level0_col10" class="col_heading level0 col10" >r2_gap</th>
#       <th id="T_46550_level0_col11" class="col_heading level0 col11" >r2_gap_diagnostic</th>
#       <th id="T_46550_level0_col12" class="col_heading level0 col12" >n_features</th>
#       <th id="T_46550_level0_col13" class="col_heading level0 col13" >interpretation (r2,mae_gap)</th>
#       <th id="T_46550_level0_col14" class="col_heading level0 col14" >ranking_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_46550_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_46550_row0_col1" class="data row0 col1" >✔</td>
#       <td id="T_46550_row0_col2" class="data row0 col2" >2025-07-12 02:08:57</td>
#       <td id="T_46550_row0_col3" class="data row0 col3" >CatBoost (All Features)</td>
#       <td id="T_46550_row0_col4" class="data row0 col4" >65.2 k€</td>
#       <td id="T_46550_row0_col5" class="data row0 col5" >96.4 k€</td>
#       <td id="T_46550_row0_col6" class="data row0 col6" >0.786959</td>
#       <td id="T_46550_row0_col7" class="data row0 col7" >65.2 k€</td>
#       <td id="T_46550_row0_col8" class="data row0 col8" >96.4 k€</td>
#       <td id="T_46550_row0_col9" class="data row0 col9" >0.786959</td>
#       <td id="T_46550_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_46550_row0_col11" class="data row0 col11" >Excellent generalization</td>
#       <td id="T_46550_row0_col12" class="data row0 col12" >72</td>
#       <td id="T_46550_row0_col13" class="data row0 col13" >good generalization</td>
#       <td id="T_46550_row0_col14" class="data row0 col14" >-161595.619596</td>
#     </tr>
#     <tr>
#       <td id="T_46550_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_46550_row1_col1" class="data row1 col1" ></td>
#       <td id="T_46550_row1_col2" class="data row1 col2" >2025-07-12 02:08:57</td>
#       <td id="T_46550_row1_col3" class="data row1 col3" >CatBoost (Top RF Features)</td>
#       <td id="T_46550_row1_col4" class="data row1 col4" >66.2 k€</td>
#       <td id="T_46550_row1_col5" class="data row1 col5" >97.2 k€</td>
#       <td id="T_46550_row1_col6" class="data row1 col6" >0.783408</td>
#       <td id="T_46550_row1_col7" class="data row1 col7" >66.2 k€</td>
#       <td id="T_46550_row1_col8" class="data row1 col8" >97.2 k€</td>
#       <td id="T_46550_row1_col9" class="data row1 col9" >0.783408</td>
#       <td id="T_46550_row1_col10" class="data row1 col10" >0.000000</td>
#       <td id="T_46550_row1_col11" class="data row1 col11" >Excellent generalization</td>
#       <td id="T_46550_row1_col12" class="data row1 col12" >30</td>
#       <td id="T_46550_row1_col13" class="data row1 col13" >good generalization</td>
#       <td id="T_46550_row1_col14" class="data row1 col14" >-163426.060803</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from utils.constants import PRICE_BINS, PRICE_BIN_LABELS

# === Prepare residuals and diagnostic DataFrames ===
# Après train/test split et entraînement
residuals_all = y_test_all - y_pred_all
residuals_top = y_test_top - y_pred_top

df_viz_all = pd.DataFrame({
    "y_true": y_test_all,
    "y_pred": y_pred_all,
    "residuals": residuals_all
})
df_viz_all["price_range"] = pd.cut(df_viz_all["y_true"], bins=PRICE_BINS, labels=PRICE_BIN_LABELS)

df_viz_top = pd.DataFrame({
    "y_true": y_test_top,
    "y_pred": y_pred_top,
    "residuals": residuals_top
})
df_viz_top["price_range"] = pd.cut(df_viz_top["y_true"], bins=PRICE_BINS, labels=PRICE_BIN_LABELS)


# === Plot 1–3: Standard diagnostics for "All Features" model ===
plt.figure(figsize=(14, 4))
plt.suptitle("Diagnostics – CatBoost (All Features)", fontsize=16)

# Plot 1: Residuals vs Predicted
plt.subplot(1, 3, 1)
plt.scatter(df_viz_all["y_pred"], df_viz_all["residuals"], alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted Price")
plt.ylabel("Residual")
plt.title("Residuals vs Predicted")

# Plot 2: Residual distribution
plt.subplot(1, 3, 2)
sns.histplot(df_viz_all["residuals"], kde=True, color="orange")
plt.xlabel("Residual")
plt.title("Residual Distribution")

# Plot 3: Predicted vs Actual prices
plt.subplot(1, 3, 3)
plt.scatter(df_viz_all["y_true"], df_viz_all["y_pred"], alpha=0.5)
plt.plot(
    [df_viz_all["y_true"].min(), df_viz_all["y_true"].max()],
    [df_viz_all["y_true"].min(), df_viz_all["y_true"].max()],
    color='red', linestyle='--'
)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Predicted vs Actual")

plt.tight_layout()
plt.show()

# === Boxplot: Residuals by price range (All Features) ===
plt.figure(figsize=(8, 4))
sns.boxplot(x="price_range", y="residuals", data=df_viz_all, palette="muted")
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Price Range")
plt.ylabel("Residual")
plt.title("Residuals by Price Range – All Features")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# === Boxplot: Residuals by price range (Top RF Features) ===
plt.figure(figsize=(8, 4))
sns.boxplot(x="price_range", y="residuals", data=df_viz_top, palette="coolwarm")
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Price Range")
plt.ylabel("Residual")
plt.title("Residuals by Price Range – Top RF Features")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Neo\AppData\Local\Temp\ipykernel_14120\8619048.py:60: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="price_range", y="residuals", data=df_viz_all, palette="muted")
# C:\Users\Neo\AppData\Local\Temp\ipykernel_14120\8619048.py:71: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="price_range", y="residuals", data=df_viz_top, palette="coolwarm")

# %% [markdown]
# # CatBoost + Optuna Hyperparameter Tuning Pipeline
#
#
# ## Data Preparation
#
# - Load the cleaned ML-ready dataset from a CSV file using `DataLoader`.
# - Drop the target variable `price` to separate `X` and `y`.
# - Apply `VarianceThreshold` to remove low-variance features (threshold = 0.01).
# - Use a `RandomForestRegressor` to rank feature importance.
# - Select the **top 30 most important features** for one of the models.
#
#
# ##  Hyperparameter Tuning (Optuna)
#
# Define the function `tune_catboost_with_optuna(...)` that:
#
# - Runs an Optuna optimization loop.
# - Evaluates model performance with **5-Fold Cross-Validation**.
# - Minimizes the **Root Mean Squared Error (RMSE)**.
#
# ### Tuned Hyperparameters:
#
# - `iterations`
# - `depth`
# - `learning_rate`
# - `l2_leaf_reg`
# - `bagging_temperature`
# - `random_strength`
#
#
#
# ## Train Final Models
#
# Two models are trained:
#
# - One using **all filtered features**
# - One using the **top 30 features**
#
# Each is trained using the **best parameters** found by Optuna.
#
#
#
# ##  Evaluation
#
# Models are evaluated using:
#
# - `MAE`: Mean Absolute Error
# - `RMSE`: Root Mean Squared Error
# - `R<sup>2</sup>`: Coefficient of determination
#
# Results are logged with `ExperimentTracker`.
#
#
#
# ##  Diagnostics
#
# - Summary tables displayed with `ModelEvaluator`
# - Residuals & diagnostic plots from `ModelVisualizer`
# - Optionally, **SHAP values** can be plotted to understand feature importance
#
#
#
# ## Test Mode (Optional)
#
# When `TEST_MODE = True`, the pipeline uses:
#
# - A smaller dataset
# - Fewer Optuna trials (`n_trials = 3`)
#
# To speed up execution and debugging.

# %%
import sys, os
# Add the project root to the Python path
project_root = os.path.abspath("../../..")
sys.path.append(project_root)
from utils.model_saver import ModelSaver

import optuna
import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.model_selection import KFold, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import mean_squared_error
from utils.constants import ML_READY_DATA_FILE, TEST_MODE
from utils.data_loader import DataLoader
from utils.model_evaluator import ModelEvaluator
from utils.train_test_metrics_logger import TrainTestMetricsLogger
from utils.model_saver import ModelSaver  

def root_mean_squared_error(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

if TEST_MODE:
    print("TEST_MODE is ON – running in test mode (reduced data, fewer trials).")
else:
    print("TEST_MODE is OFF – full training is active.")

# Step 1: Load and clean dataset
loader = DataLoader(ML_READY_DATA_FILE)
df = loader.load_data()
X = df.drop(columns=["price"])
y = df["price"]

# Step 2: Remove low-variance features
selector = VarianceThreshold(threshold=0.01)
X_reduced = X.loc[:, selector.fit(X).get_support()]

# Step 3: Extract top 30 features using Random Forest
rf_model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
rf_model.fit(X_reduced, y)
top_features = pd.Series(rf_model.feature_importances_, index=X_reduced.columns).nlargest(30).index.tolist()
X_top = X_reduced[top_features]

# Step 4: Define Optuna objective for CatBoost
def tune_catboost_with_optuna(X_data, y_data, n_trials=50):
    def objective(trial):
        params = {
            "iterations": trial.suggest_int("iterations", 300, 1000),
            "depth": trial.suggest_int("depth", 4, 8),
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
            "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-3, 10.0, log=True),
            "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.0),
            "random_strength": trial.suggest_float("random_strength", 0.0, 1.0),
            "bootstrap_type": "Bayesian"
        }

        model = CatBoostRegressor(
            **params,
            verbose=0,
            loss_function="RMSE",
            random_state=42
        )

        cv = KFold(n_splits=5, shuffle=True, random_state=42)
        scores = []
        for train_idx, val_idx in cv.split(X_data):
            X_train, X_val = X_data.iloc[train_idx], X_data.iloc[val_idx]
            y_train, y_val = y_data.iloc[train_idx], y_data.iloc[val_idx]

            model.fit(X_train, y_train,eval_set=(X_val, y_val), early_stopping_rounds=50)
            preds = model.predict(X_val)
            scores.append(root_mean_squared_error(y_val, preds))
        return np.mean(scores)

    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=n_trials)
    return study

# Step 5: Split train/test sets for final evaluation
test_size = 0.2
random_state = 42

X_train_all, X_test_all, y_train_all, y_test_all = train_test_split(X_reduced, y, test_size=test_size, random_state=random_state)
X_train_top, X_test_top, y_train_top, y_test_top = train_test_split(X_top, y, test_size=test_size, random_state=random_state)

# Step 6: Tune and train both models on train data only
n_trials = 1 if TEST_MODE else 50

study_all = tune_catboost_with_optuna(X_train_all, y_train_all, n_trials)
model_all = CatBoostRegressor(**study_all.best_params, verbose=0, loss_function="RMSE", random_state=42)
model_all.fit(X_train_all, y_train_all)

study_top = tune_catboost_with_optuna(X_train_top, y_train_top, n_trials)
model_top = CatBoostRegressor(**study_top.best_params, verbose=0, loss_function="RMSE", random_state=42)
model_top.fit(X_train_top, y_train_top)

# Step 7: Predict on train and test sets
y_pred_train_all = model_all.predict(X_train_all)
y_pred_test_all = model_all.predict(X_test_all)

y_pred_train_top = model_top.predict(X_train_top)
y_pred_test_top = model_top.predict(X_test_top)

# Step 7: Evaluate

# Initialize evaluators for both model variants
evaluator_all = ModelEvaluator("CatBoost + Optuna CV (All Features)")
evaluator_top = ModelEvaluator("CatBoost + Optuna CV (Top RF Features)")

# Evaluate on training and test sets – All Features
metrics_train_all, range_train_all = evaluator_all.evaluate(y_train_all, y_pred_train_all, dataset_type="Train")
metrics_test_all,  range_test_all  = evaluator_all.evaluate(y_test_all,  y_pred_test_all,  dataset_type="Test")

# Extract individual global metrics – All Features
mae_train_all  = metrics_train_all["mae"]
rmse_train_all = metrics_train_all["rmse"]
r2_train_all   = metrics_train_all["r2"]

mae_test_all  = metrics_test_all["mae"]
rmse_test_all = metrics_test_all["rmse"]
r2_test_all   = metrics_test_all["r2"]

# Evaluate on training and test sets – Top 30 RF Features
metrics_train_top, range_train_top = evaluator_top.evaluate(y_train_top, y_pred_train_top, dataset_type="Train")
metrics_test_top,  range_test_top  = evaluator_top.evaluate(y_test_top,  y_pred_test_top,  dataset_type="Test")

# Extract individual global metrics – Top Features
mae_train_top  = metrics_train_top["mae"]
rmse_train_top = metrics_train_top["rmse"]
r2_train_top   = metrics_train_top["r2"]

mae_test_top  = metrics_test_top["mae"]
rmse_test_top = metrics_test_top["rmse"]
r2_test_top   = metrics_test_top["r2"]


# Define price ranges for segmented evaluation
bins=[0, 150000, 250000, 350000, 500000, 750000, 1_000_000, float("inf")]

# Print detailed evaluation by price range
print("\n[Evaluation by Price Range – All Features]")
evaluator_all.print_evaluation(y_test_all, y_pred_test_all, bins=bins)

print("\n[Evaluation by Price Range – Top RF Features]")
evaluator_top.print_evaluation(y_test_top, y_pred_test_top, bins=bins)




# Step 8: Logging with TrainTestMetricsLogger
logger = TrainTestMetricsLogger()

logger.log(
    model_name=f"CatBoost + Optuna CV (All Features – Post-Split Evaluation){' [TEST]' if TEST_MODE else ''}",
    experiment_name=f"CatBoost with Optuna (All Features){' [TEST]' if TEST_MODE else ''}",
    mae_train=mae_train_all,
    rmse_train=rmse_train_all,
    r2_train=r2_train_all,
    mae_test=mae_test_all,
    rmse_test=rmse_test_all,
    r2_test=r2_test_all,
    data_file=ML_READY_DATA_FILE,
    n_features=X_train_all.shape[1]
)

logger.log(
    model_name=f"CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation){' [TEST]' if TEST_MODE else ''}",
    experiment_name=f"CatBoost with Optuna (Top RF Features){' [TEST]' if TEST_MODE else ''}",
    mae_train=mae_train_top,
    rmse_train=rmse_train_top,
    r2_train=r2_train_top,
    mae_test=mae_test_top,
    rmse_test=rmse_test_top,
    r2_test=r2_test_top,
    data_file=ML_READY_DATA_FILE,
    n_features=X_train_top.shape[1]
)


# Step 9: Save models, features and metrics
saver = ModelSaver()

# Save CatBoost All Features
saver.save_model_and_features(
    model=model_all,
    features=X_train_all.columns.tolist(),
    model_name=f"CatBoost + Optuna CV (All Features – Post-Split Evaluation){' [TEST]' if TEST_MODE else ''}",
    metrics=metrics_test_all,
    metrics_by_price_range=evaluator_all._compute_metrics_by_price_range(
        y_test_all, y_pred_test_all, bins=[0, 250_000, 500_000, 750_000, 1_000_000, float("inf")]
    )
)

# Save CatBoost Top RF Features
saver.save_model_and_features(
    model=model_top,
    features=X_train_top.columns.tolist(),
    model_name=f"CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation){' [TEST]' if TEST_MODE else ''}",
    metrics=metrics_test_top,
    metrics_by_price_range=evaluator_top._compute_metrics_by_price_range(
        y_test_top, y_pred_test_top, bins=[0, 250_000, 500_000, 750_000, 1_000_000, float("inf")]
    )
)


# Step 10: Display summary
logger.display_table()
# Out:
# TEST_MODE is OFF – full training is active.
# [I 2025-07-12 02:09:06,992] A new study created in memory with name: no-name-f4e2655d-e3df-4454-a4da-8cd58f915ffc
# [I 2025-07-12 02:09:15,057] Trial 0 finished with value: 97773.05676168253 and parameters: {'iterations': 761, 'depth': 8, 'learning_rate': 0.23113426313549545, 'l2_leaf_reg': 0.19569569742816983, 'bagging_temperature': 0.27894251476371656, 'random_strength': 0.6766111253095064}. Best is trial 0 with value: 97773.05676168253.
# [I 2025-07-12 02:09:24,376] Trial 1 finished with value: 96759.01962044481 and parameters: {'iterations': 861, 'depth': 4, 'learning_rate': 0.09798398936359069, 'l2_leaf_reg': 0.004930483124463101, 'bagging_temperature': 0.6362897201536022, 'random_strength': 0.8111663666738335}. Best is trial 1 with value: 96759.01962044481.
# [I 2025-07-12 02:09:32,862] Trial 2 finished with value: 96408.3319886591 and parameters: {'iterations': 548, 'depth': 6, 'learning_rate': 0.14027868733701715, 'l2_leaf_reg': 0.5597578673489301, 'bagging_temperature': 0.8268381417594606, 'random_strength': 0.5946130484642258}. Best is trial 2 with value: 96408.3319886591.
# [I 2025-07-12 02:09:40,851] Trial 3 finished with value: 96217.78660005682 and parameters: {'iterations': 881, 'depth': 5, 'learning_rate': 0.1348033847091469, 'l2_leaf_reg': 0.2959899558403164, 'bagging_temperature': 0.3845807371202854, 'random_strength': 0.6606808524444813}. Best is trial 3 with value: 96217.78660005682.
# [I 2025-07-12 02:09:47,095] Trial 4 finished with value: 97015.0453295602 and parameters: {'iterations': 301, 'depth': 7, 'learning_rate': 0.13087050115071674, 'l2_leaf_reg': 0.07336284841436025, 'bagging_temperature': 0.6732150207215927, 'random_strength': 0.10443257972328635}. Best is trial 3 with value: 96217.78660005682.
# [I 2025-07-12 02:09:53,791] Trial 5 finished with value: 99157.78952710725 and parameters: {'iterations': 428, 'depth': 8, 'learning_rate': 0.26830403293943494, 'l2_leaf_reg': 0.0033420667091909714, 'bagging_temperature': 0.26464504538781486, 'random_strength': 0.9727982285493241}. Best is trial 3 with value: 96217.78660005682.
# [I 2025-07-12 02:10:01,609] Trial 6 finished with value: 97562.92269631758 and parameters: {'iterations': 499, 'depth': 8, 'learning_rate': 0.2038642466559198, 'l2_leaf_reg': 0.017008232122265918, 'bagging_temperature': 0.2409884370020664, 'random_strength': 0.1463940295316818}. Best is trial 3 with value: 96217.78660005682.
# [I 2025-07-12 02:10:10,098] Trial 7 finished with value: 96893.16260002801 and parameters: {'iterations': 773, 'depth': 4, 'learning_rate': 0.10946559350102043, 'l2_leaf_reg': 0.004919366194164521, 'bagging_temperature': 0.7126807628138774, 'random_strength': 0.21356356863248493}. Best is trial 3 with value: 96217.78660005682.
# [I 2025-07-12 02:10:29,665] Trial 8 finished with value: 97651.15781264429 and parameters: {'iterations': 965, 'depth': 7, 'learning_rate': 0.0260869075237287, 'l2_leaf_reg': 1.450107391436439, 'bagging_temperature': 0.21650132288177937, 'random_strength': 0.6790929264142476}. Best is trial 3 with value: 96217.78660005682.
# [I 2025-07-12 02:10:35,165] Trial 9 finished with value: 97592.24445271507 and parameters: {'iterations': 652, 'depth': 6, 'learning_rate': 0.28221074009638875, 'l2_leaf_reg': 1.0366193152750525, 'bagging_temperature': 0.6417064256758277, 'random_strength': 0.29036705649824224}. Best is trial 3 with value: 96217.78660005682.
# [I 2025-07-12 02:10:47,293] Trial 10 finished with value: 99764.53581137198 and parameters: {'iterations': 987, 'depth': 5, 'learning_rate': 0.0397834724585925, 'l2_leaf_reg': 9.191758849263877, 'bagging_temperature': 0.9916351768291298, 'random_strength': 0.4482158924799037}. Best is trial 3 with value: 96217.78660005682.
# [I 2025-07-12 02:10:54,298] Trial 11 finished with value: 96828.88686459302 and parameters: {'iterations': 572, 'depth': 5, 'learning_rate': 0.1776188047890496, 'l2_leaf_reg': 0.2766532646859769, 'bagging_temperature': 0.9713149098862418, 'random_strength': 0.5374420690565163}. Best is trial 3 with value: 96217.78660005682.
# [I 2025-07-12 02:11:04,198] Trial 12 finished with value: 95929.50482810913 and parameters: {'iterations': 661, 'depth': 6, 'learning_rate': 0.07153601805778997, 'l2_leaf_reg': 1.0607019370439295, 'bagging_temperature': 0.40717902312880905, 'random_strength': 0.4492969837069188}. Best is trial 12 with value: 95929.50482810913.
# [I 2025-07-12 02:11:12,873] Trial 13 finished with value: 97272.05565508865 and parameters: {'iterations': 706, 'depth': 5, 'learning_rate': 0.06955773116368615, 'l2_leaf_reg': 5.9411227099879, 'bagging_temperature': 0.4495185067457772, 'random_strength': 0.48880018944259856}. Best is trial 12 with value: 95929.50482810913.
# [I 2025-07-12 02:11:25,063] Trial 14 finished with value: 95620.75598993413 and parameters: {'iterations': 837, 'depth': 6, 'learning_rate': 0.06381593072030817, 'l2_leaf_reg': 0.048968757654744274, 'bagging_temperature': 0.44141231012035487, 'random_strength': 0.3604265815351694}. Best is trial 14 with value: 95620.75598993413.
# [I 2025-07-12 02:11:41,153] Trial 15 finished with value: 94797.88536090087 and parameters: {'iterations': 854, 'depth': 7, 'learning_rate': 0.07213620313423941, 'l2_leaf_reg': 0.04623779562588174, 'bagging_temperature': 0.08133715124314145, 'random_strength': 0.35165236530666066}. Best is trial 15 with value: 94797.88536090087.
# [I 2025-07-12 02:11:57,622] Trial 16 finished with value: 99292.08298034481 and parameters: {'iterations': 879, 'depth': 7, 'learning_rate': 0.018990456800588813, 'l2_leaf_reg': 0.04253332961965185, 'bagging_temperature': 0.00023001465134479815, 'random_strength': 0.3447001475051485}. Best is trial 15 with value: 94797.88536090087.
# [I 2025-07-12 02:12:12,543] Trial 17 finished with value: 94683.21620381562 and parameters: {'iterations': 805, 'depth': 7, 'learning_rate': 0.0685209239289272, 'l2_leaf_reg': 0.01795825840053126, 'bagging_temperature': 0.02524503370521238, 'random_strength': 0.3305588331034509}. Best is trial 17 with value: 94683.21620381562.
# [I 2025-07-12 02:12:26,211] Trial 18 finished with value: 94849.07376136168 and parameters: {'iterations': 771, 'depth': 7, 'learning_rate': 0.09803336318229737, 'l2_leaf_reg': 0.0010516585955470674, 'bagging_temperature': 0.03167009236873049, 'random_strength': 0.02014262339476458}. Best is trial 17 with value: 94683.21620381562.
# [I 2025-07-12 02:12:35,569] Trial 19 finished with value: 95739.22586289057 and parameters: {'iterations': 939, 'depth': 7, 'learning_rate': 0.16219739120852208, 'l2_leaf_reg': 0.013625526185608059, 'bagging_temperature': 0.11667771480733102, 'random_strength': 0.23794960631559708}. Best is trial 17 with value: 94683.21620381562.
# [I 2025-07-12 02:12:55,436] Trial 20 finished with value: 94945.40205479202 and parameters: {'iterations': 799, 'depth': 8, 'learning_rate': 0.054067867890821755, 'l2_leaf_reg': 0.02586023072488923, 'bagging_temperature': 0.11411044534037595, 'random_strength': 0.39476037311923073}. Best is trial 17 with value: 94683.21620381562.
# [I 2025-07-12 02:13:09,280] Trial 21 finished with value: 94679.92725765343 and parameters: {'iterations': 729, 'depth': 7, 'learning_rate': 0.09621576945184095, 'l2_leaf_reg': 0.0010264860205570917, 'bagging_temperature': 0.0157269875203715, 'random_strength': 0.0335297917772881}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:13:23,588] Trial 22 finished with value: 94815.06489069546 and parameters: {'iterations': 708, 'depth': 7, 'learning_rate': 0.0962796258622625, 'l2_leaf_reg': 0.0012384982628442893, 'bagging_temperature': 0.10264235237040897, 'random_strength': 0.0011846254881724139}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:13:37,051] Trial 23 finished with value: 104404.61861354948 and parameters: {'iterations': 708, 'depth': 7, 'learning_rate': 0.011331060703609758, 'l2_leaf_reg': 0.009575796673738111, 'bagging_temperature': 0.16525110616548766, 'random_strength': 0.17092301203684587}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:13:49,905] Trial 24 finished with value: 95071.86181608445 and parameters: {'iterations': 899, 'depth': 6, 'learning_rate': 0.08094342469352084, 'l2_leaf_reg': 0.08766114213402294, 'bagging_temperature': 0.0005201804189254536, 'random_strength': 0.07967489969005496}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:14:04,496] Trial 25 finished with value: 95734.04332482659 and parameters: {'iterations': 818, 'depth': 8, 'learning_rate': 0.11990180690492563, 'l2_leaf_reg': 0.002104181057168748, 'bagging_temperature': 0.34044983463101913, 'random_strength': 0.2982258708166855}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:14:17,561] Trial 26 finished with value: 97114.54223612025 and parameters: {'iterations': 609, 'depth': 7, 'learning_rate': 0.03918865147430458, 'l2_leaf_reg': 0.008608911674940396, 'bagging_temperature': 0.09555799516368146, 'random_strength': 0.2460253550380654}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:14:31,389] Trial 27 finished with value: 95891.2908905257 and parameters: {'iterations': 929, 'depth': 6, 'learning_rate': 0.04945111195807552, 'l2_leaf_reg': 0.024921541213299477, 'bagging_temperature': 0.16312044441771678, 'random_strength': 0.7992779123114939}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:14:44,437] Trial 28 finished with value: 95208.41051131007 and parameters: {'iterations': 742, 'depth': 7, 'learning_rate': 0.08888091605250528, 'l2_leaf_reg': 0.14391822179134128, 'bagging_temperature': 0.5252119878419496, 'random_strength': 0.08012140972421145}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:14:56,807] Trial 29 finished with value: 96272.4508826966 and parameters: {'iterations': 819, 'depth': 8, 'learning_rate': 0.15661219573450216, 'l2_leaf_reg': 0.002189427792271464, 'bagging_temperature': 0.3105612822453632, 'random_strength': 0.4034136010189299}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:15:12,624] Trial 30 finished with value: 95526.68580272347 and parameters: {'iterations': 733, 'depth': 8, 'learning_rate': 0.11765151618993558, 'l2_leaf_reg': 0.04060101691881507, 'bagging_temperature': 0.0667239088453927, 'random_strength': 0.5644227041934828}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:15:25,674] Trial 31 finished with value: 94938.13489759107 and parameters: {'iterations': 674, 'depth': 7, 'learning_rate': 0.08701860415376697, 'l2_leaf_reg': 0.0012671792718521972, 'bagging_temperature': 0.1709885986605778, 'random_strength': 0.03994211046801989}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:15:37,360] Trial 32 finished with value: 95136.0193851291 and parameters: {'iterations': 784, 'depth': 7, 'learning_rate': 0.10398613005081991, 'l2_leaf_reg': 0.0063243768852395, 'bagging_temperature': 0.057514659612428035, 'random_strength': 0.010448355307180574}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:15:44,199] Trial 33 finished with value: 96012.75092878472 and parameters: {'iterations': 705, 'depth': 6, 'learning_rate': 0.18947050282990496, 'l2_leaf_reg': 0.0022496245042529597, 'bagging_temperature': 0.19918614750774058, 'random_strength': 0.1614965410932879}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:15:53,915] Trial 34 finished with value: 95820.39341112826 and parameters: {'iterations': 853, 'depth': 7, 'learning_rate': 0.14442278570527622, 'l2_leaf_reg': 0.004027838407095117, 'bagging_temperature': 0.10345522111855396, 'random_strength': 0.30156839376552763}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:16:05,976] Trial 35 finished with value: 96008.64342595512 and parameters: {'iterations': 622, 'depth': 7, 'learning_rate': 0.058507539579810745, 'l2_leaf_reg': 0.0014923612803219508, 'bagging_temperature': 0.5526011754438535, 'random_strength': 0.11041965186850493}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:16:24,403] Trial 36 finished with value: 94802.57824225813 and parameters: {'iterations': 910, 'depth': 8, 'learning_rate': 0.08396026912532224, 'l2_leaf_reg': 0.0035016326113843066, 'bagging_temperature': 0.056085448786734285, 'random_strength': 0.20101285898228546}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:16:37,062] Trial 37 finished with value: 96264.97681533635 and parameters: {'iterations': 909, 'depth': 8, 'learning_rate': 0.1287962856030188, 'l2_leaf_reg': 0.017641804667131136, 'bagging_temperature': 0.2947121562935795, 'random_strength': 0.20473440684113509}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:16:43,516] Trial 38 finished with value: 97607.98306500146 and parameters: {'iterations': 865, 'depth': 8, 'learning_rate': 0.24282407622309637, 'l2_leaf_reg': 0.006893162757587271, 'bagging_temperature': 0.036940454432407566, 'random_strength': 0.6294716007432966}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:16:52,173] Trial 39 finished with value: 100262.89462329252 and parameters: {'iterations': 326, 'depth': 8, 'learning_rate': 0.037020328751848526, 'l2_leaf_reg': 0.0037398625527537716, 'bagging_temperature': 0.23340812014289958, 'random_strength': 0.26410150051159076}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:17:14,818] Trial 40 finished with value: 95620.0954976701 and parameters: {'iterations': 961, 'depth': 8, 'learning_rate': 0.08035338961478139, 'l2_leaf_reg': 0.011868954535456812, 'bagging_temperature': 0.8163088169593568, 'random_strength': 0.12673288880648925}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:17:28,856] Trial 41 finished with value: 95025.29976165229 and parameters: {'iterations': 755, 'depth': 7, 'learning_rate': 0.10152315970919915, 'l2_leaf_reg': 0.002185878487273455, 'bagging_temperature': 0.13403644791225924, 'random_strength': 0.056984960311145305}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:17:40,351] Trial 42 finished with value: 95557.24104848094 and parameters: {'iterations': 834, 'depth': 7, 'learning_rate': 0.11369388965578643, 'l2_leaf_reg': 0.0011308155459789084, 'bagging_temperature': 0.07479561384212571, 'random_strength': 0.19516991997872074}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:17:54,453] Trial 43 finished with value: 94879.27573883414 and parameters: {'iterations': 996, 'depth': 6, 'learning_rate': 0.0887530216182134, 'l2_leaf_reg': 0.0029076155109729763, 'bagging_temperature': 0.0056576248832644616, 'random_strength': 0.3284071175779083}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:18:04,574] Trial 44 finished with value: 95677.28577109586 and parameters: {'iterations': 492, 'depth': 7, 'learning_rate': 0.07278234973684472, 'l2_leaf_reg': 0.15020504317229985, 'bagging_temperature': 0.060528709856206425, 'random_strength': 0.13558847390824189}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:18:14,234] Trial 45 finished with value: 101462.8926570988 and parameters: {'iterations': 887, 'depth': 4, 'learning_rate': 0.030113006754301855, 'l2_leaf_reg': 0.005240381086536848, 'bagging_temperature': 0.19420729806587417, 'random_strength': 0.00627835993942122}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:18:24,084] Trial 46 finished with value: 95824.30802626231 and parameters: {'iterations': 797, 'depth': 6, 'learning_rate': 0.14211436660311644, 'l2_leaf_reg': 0.02523594605806981, 'bagging_temperature': 0.1467850152024284, 'random_strength': 0.4590871488536466}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:18:42,944] Trial 47 finished with value: 95423.69858398687 and parameters: {'iterations': 679, 'depth': 8, 'learning_rate': 0.05393634977356957, 'l2_leaf_reg': 0.0016223922255977424, 'bagging_temperature': 0.26047504699127894, 'random_strength': 0.39016701959655264}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:18:55,313] Trial 48 finished with value: 95578.44357661289 and parameters: {'iterations': 614, 'depth': 7, 'learning_rate': 0.06782826519175379, 'l2_leaf_reg': 0.056409388210533054, 'bagging_temperature': 0.08198271434953278, 'random_strength': 0.1002148537244148}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:19:04,745] Trial 49 finished with value: 95627.33904037756 and parameters: {'iterations': 731, 'depth': 6, 'learning_rate': 0.12975112794991897, 'l2_leaf_reg': 0.0033570533037443353, 'bagging_temperature': 0.03956859408812078, 'random_strength': 0.2649508701958817}. Best is trial 21 with value: 94679.92725765343.
# [I 2025-07-12 02:19:07,964] A new study created in memory with name: no-name-4db14bf2-e182-47d8-9598-5123cc90edf5
# [I 2025-07-12 02:19:17,730] Trial 0 finished with value: 103378.15286258493 and parameters: {'iterations': 915, 'depth': 4, 'learning_rate': 0.02852909998863861, 'l2_leaf_reg': 6.802211680782424, 'bagging_temperature': 0.4846543077201363, 'random_strength': 0.8122683672214275}. Best is trial 0 with value: 103378.15286258493.
# [I 2025-07-12 02:19:27,364] Trial 1 finished with value: 97805.23379821528 and parameters: {'iterations': 535, 'depth': 7, 'learning_rate': 0.10967510189493503, 'l2_leaf_reg': 0.6021992045629556, 'bagging_temperature': 0.605075596620106, 'random_strength': 0.8256609317936804}. Best is trial 1 with value: 97805.23379821528.
# [I 2025-07-12 02:19:33,622] Trial 2 finished with value: 98084.16356771979 and parameters: {'iterations': 325, 'depth': 7, 'learning_rate': 0.0972883106663661, 'l2_leaf_reg': 0.00774113018624654, 'bagging_temperature': 0.2888997796095314, 'random_strength': 0.5134331290183756}. Best is trial 1 with value: 97805.23379821528.
# [I 2025-07-12 02:19:38,530] Trial 3 finished with value: 98968.03758391559 and parameters: {'iterations': 806, 'depth': 7, 'learning_rate': 0.22927644484732773, 'l2_leaf_reg': 0.2785976976197905, 'bagging_temperature': 0.11593569062389786, 'random_strength': 0.3135967888717033}. Best is trial 1 with value: 97805.23379821528.
# [I 2025-07-12 02:19:44,340] Trial 4 finished with value: 98924.57472898116 and parameters: {'iterations': 367, 'depth': 7, 'learning_rate': 0.1975865772418284, 'l2_leaf_reg': 0.8607709801556827, 'bagging_temperature': 0.7557301127730439, 'random_strength': 0.7545525453936098}. Best is trial 1 with value: 97805.23379821528.
# [I 2025-07-12 02:19:49,218] Trial 5 finished with value: 99714.4685202234 and parameters: {'iterations': 630, 'depth': 4, 'learning_rate': 0.26635999945004124, 'l2_leaf_reg': 0.00556019521917049, 'bagging_temperature': 0.8945112928560204, 'random_strength': 0.6267182285645854}. Best is trial 1 with value: 97805.23379821528.
# [I 2025-07-12 02:20:10,066] Trial 6 finished with value: 98452.26460118912 and parameters: {'iterations': 919, 'depth': 8, 'learning_rate': 0.03632317531771793, 'l2_leaf_reg': 1.7662305713820166, 'bagging_temperature': 0.7035676161103004, 'random_strength': 0.9554838193907909}. Best is trial 1 with value: 97805.23379821528.
# [I 2025-07-12 02:20:18,425] Trial 7 finished with value: 97000.84133856244 and parameters: {'iterations': 642, 'depth': 6, 'learning_rate': 0.08746515113113956, 'l2_leaf_reg': 0.12692907041385165, 'bagging_temperature': 0.025554795143875708, 'random_strength': 0.38614092731187855}. Best is trial 7 with value: 97000.84133856244.
# [I 2025-07-12 02:20:32,236] Trial 8 finished with value: 96667.19726832802 and parameters: {'iterations': 978, 'depth': 7, 'learning_rate': 0.09958478598501667, 'l2_leaf_reg': 2.3790274391297332, 'bagging_temperature': 0.2869665948106903, 'random_strength': 0.8009165131275163}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:20:37,233] Trial 9 finished with value: 99452.18565664295 and parameters: {'iterations': 844, 'depth': 7, 'learning_rate': 0.23371918047768928, 'l2_leaf_reg': 0.0017500173674977375, 'bagging_temperature': 0.8814309380719267, 'random_strength': 0.3987234715089346}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:20:45,307] Trial 10 finished with value: 97378.15962432467 and parameters: {'iterations': 753, 'depth': 5, 'learning_rate': 0.1446324529102766, 'l2_leaf_reg': 6.972279060428705, 'bagging_temperature': 0.3350474883847836, 'random_strength': 0.999465383343499}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:20:53,259] Trial 11 finished with value: 96946.76564381164 and parameters: {'iterations': 582, 'depth': 6, 'learning_rate': 0.08650178913133162, 'l2_leaf_reg': 0.08140157489870539, 'bagging_temperature': 0.03683005600696837, 'random_strength': 0.04304636261931061}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:20:59,484] Trial 12 finished with value: 97020.07572443112 and parameters: {'iterations': 489, 'depth': 6, 'learning_rate': 0.15876848834505505, 'l2_leaf_reg': 0.03154201753721127, 'bagging_temperature': 0.20140113396916173, 'random_strength': 0.007745876568842389}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:21:09,941] Trial 13 finished with value: 97474.31763921755 and parameters: {'iterations': 980, 'depth': 5, 'learning_rate': 0.06135486294516986, 'l2_leaf_reg': 0.02814208862481941, 'bagging_temperature': 0.3979461488684501, 'random_strength': 0.052558603352326094}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:21:19,469] Trial 14 finished with value: 97745.45152626387 and parameters: {'iterations': 727, 'depth': 8, 'learning_rate': 0.14419732501123492, 'l2_leaf_reg': 0.08296912964343262, 'bagging_temperature': 0.0030257874491119857, 'random_strength': 0.14285088725390016}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:21:25,315] Trial 15 finished with value: 99591.71575869631 and parameters: {'iterations': 531, 'depth': 5, 'learning_rate': 0.06297372961432306, 'l2_leaf_reg': 2.463058415602854, 'bagging_temperature': 0.18206033002280556, 'random_strength': 0.23166876990604124}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:21:33,528] Trial 16 finished with value: 97146.37305886252 and parameters: {'iterations': 591, 'depth': 6, 'learning_rate': 0.12093149231816477, 'l2_leaf_reg': 0.16766382494526694, 'bagging_temperature': 0.24803864142997903, 'random_strength': 0.6421457009580418}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:21:40,464] Trial 17 finished with value: 98845.95276997608 and parameters: {'iterations': 416, 'depth': 8, 'learning_rate': 0.1841319621537316, 'l2_leaf_reg': 0.03042879562479077, 'bagging_temperature': 0.10947121303959466, 'random_strength': 0.5409441128376509}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:21:50,003] Trial 18 finished with value: 105482.74420955808 and parameters: {'iterations': 712, 'depth': 6, 'learning_rate': 0.015208335772949805, 'l2_leaf_reg': 0.511198091382924, 'bagging_temperature': 0.5071651162678852, 'random_strength': 0.7159948764660164}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:21:56,238] Trial 19 finished with value: 98647.37243643336 and parameters: {'iterations': 457, 'depth': 6, 'learning_rate': 0.07026784002387099, 'l2_leaf_reg': 0.05981780143158783, 'bagging_temperature': 0.3842174484180251, 'random_strength': 0.8912625986635438}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:22:04,498] Trial 20 finished with value: 97378.11671121363 and parameters: {'iterations': 995, 'depth': 5, 'learning_rate': 0.121879231240721, 'l2_leaf_reg': 2.2922586267109044, 'bagging_temperature': 0.09896986912061134, 'random_strength': 0.17969807138482732}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:22:13,860] Trial 21 finished with value: 97012.65058425613 and parameters: {'iterations': 645, 'depth': 6, 'learning_rate': 0.0900073765212413, 'l2_leaf_reg': 0.17673318730652088, 'bagging_temperature': 0.0905141181189157, 'random_strength': 0.419274044447577}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:22:23,550] Trial 22 finished with value: 96958.2750196913 and parameters: {'iterations': 575, 'depth': 7, 'learning_rate': 0.08582861760475687, 'l2_leaf_reg': 0.01089994156182684, 'bagging_temperature': 0.020330114111340846, 'random_strength': 0.2956980971021052}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:22:33,519] Trial 23 finished with value: 97881.3588910799 and parameters: {'iterations': 572, 'depth': 7, 'learning_rate': 0.048683683076548995, 'l2_leaf_reg': 0.012629636966346908, 'bagging_temperature': 0.19224863462600472, 'random_strength': 0.2720913648716191}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:22:44,236] Trial 24 finished with value: 97261.01794946117 and parameters: {'iterations': 703, 'depth': 8, 'learning_rate': 0.12995615762296447, 'l2_leaf_reg': 0.0029786897286857433, 'bagging_temperature': 0.0017000686695011827, 'random_strength': 0.10374253526431065}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:22:49,958] Trial 25 finished with value: 98178.56537177002 and parameters: {'iterations': 809, 'depth': 7, 'learning_rate': 0.17605921412344183, 'l2_leaf_reg': 0.01531312636042597, 'bagging_temperature': 0.25676939321055325, 'random_strength': 0.32464860939741885}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:22:58,129] Trial 26 finished with value: 97179.14712643696 and parameters: {'iterations': 480, 'depth': 7, 'learning_rate': 0.07965261197832425, 'l2_leaf_reg': 0.05610593327396451, 'bagging_temperature': 0.13875617839085758, 'random_strength': 0.2092527439528578}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:23:06,177] Trial 27 finished with value: 97477.26027989457 and parameters: {'iterations': 587, 'depth': 6, 'learning_rate': 0.09963960013506123, 'l2_leaf_reg': 0.31242051183172703, 'bagging_temperature': 0.44963433714258283, 'random_strength': 0.5873127991649906}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:23:15,544] Trial 28 finished with value: 98547.6340842989 and parameters: {'iterations': 408, 'depth': 8, 'learning_rate': 0.0465444466728453, 'l2_leaf_reg': 0.002996216551173956, 'bagging_temperature': 0.058648277195477716, 'random_strength': 0.10870231578726391}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:23:23,643] Trial 29 finished with value: 110319.07249280359 and parameters: {'iterations': 868, 'depth': 4, 'learning_rate': 0.011991166365574221, 'l2_leaf_reg': 4.722508140518177, 'bagging_temperature': 0.3228260963965863, 'random_strength': 0.45659016324797363}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:23:29,248] Trial 30 finished with value: 98666.42621340891 and parameters: {'iterations': 927, 'depth': 7, 'learning_rate': 0.16167045211958686, 'l2_leaf_reg': 0.012993722616499196, 'bagging_temperature': 0.5531426685442228, 'random_strength': 0.703605530883687}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:23:38,602] Trial 31 finished with value: 97045.32312147484 and parameters: {'iterations': 667, 'depth': 6, 'learning_rate': 0.08367319512833649, 'l2_leaf_reg': 1.0836070730695968, 'bagging_temperature': 0.03694308194600857, 'random_strength': 0.36273018286341013}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:23:45,962] Trial 32 finished with value: 96916.04709323849 and parameters: {'iterations': 539, 'depth': 6, 'learning_rate': 0.11294985989445962, 'l2_leaf_reg': 0.10339058823014141, 'bagging_temperature': 0.17197563713598663, 'random_strength': 0.48137658484725393}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:23:51,969] Trial 33 finished with value: 97874.14730697604 and parameters: {'iterations': 549, 'depth': 5, 'learning_rate': 0.10932184692601693, 'l2_leaf_reg': 0.001188142699335587, 'bagging_temperature': 0.16693645186770234, 'random_strength': 0.49284039469059293}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:23:59,172] Trial 34 finished with value: 97444.23504370218 and parameters: {'iterations': 527, 'depth': 6, 'learning_rate': 0.10556216700709556, 'l2_leaf_reg': 0.42737605697288933, 'bagging_temperature': 0.23519165836571548, 'random_strength': 0.8223252812610213}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:24:07,751] Trial 35 finished with value: 97190.48657015842 and parameters: {'iterations': 612, 'depth': 7, 'learning_rate': 0.1339033878505698, 'l2_leaf_reg': 0.00529962269744038, 'bagging_temperature': 0.07908501135487804, 'random_strength': 0.5617552384269773}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:24:13,079] Trial 36 finished with value: 98302.62701461131 and parameters: {'iterations': 322, 'depth': 7, 'learning_rate': 0.11490419089253268, 'l2_leaf_reg': 4.482159424551204, 'bagging_temperature': 0.2945990150371251, 'random_strength': 0.2987286458322509}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:24:19,169] Trial 37 finished with value: 100139.6391415742 and parameters: {'iterations': 434, 'depth': 6, 'learning_rate': 0.07166816990240764, 'l2_leaf_reg': 1.0419304561929208, 'bagging_temperature': 0.9882248598712713, 'random_strength': 0.6378985786673566}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:24:30,482] Trial 38 finished with value: 98383.75573933989 and parameters: {'iterations': 680, 'depth': 7, 'learning_rate': 0.044718684421412164, 'l2_leaf_reg': 0.2558775009964418, 'bagging_temperature': 0.6589589437100566, 'random_strength': 0.4619598853608106}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:24:35,371] Trial 39 finished with value: 98275.36853413489 and parameters: {'iterations': 367, 'depth': 6, 'learning_rate': 0.09456290856225891, 'l2_leaf_reg': 0.019047769754764146, 'bagging_temperature': 0.15620823379539672, 'random_strength': 0.7805818123498277}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:24:48,547] Trial 40 finished with value: 99289.15445371268 and parameters: {'iterations': 782, 'depth': 7, 'learning_rate': 0.02772920273892418, 'l2_leaf_reg': 0.05047560468609957, 'bagging_temperature': 0.36847478376128473, 'random_strength': 0.8771059754039096}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:24:55,352] Trial 41 finished with value: 97816.09733074585 and parameters: {'iterations': 611, 'depth': 5, 'learning_rate': 0.0849856770262264, 'l2_leaf_reg': 0.12896322463129886, 'bagging_temperature': 0.043499225352937265, 'random_strength': 0.3717851090440209}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:25:02,969] Trial 42 finished with value: 98462.87430520993 and parameters: {'iterations': 509, 'depth': 6, 'learning_rate': 0.05723732262361257, 'l2_leaf_reg': 0.072916624956949, 'bagging_temperature': 0.0011613693370044163, 'random_strength': 0.42248813623360604}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:25:06,895] Trial 43 finished with value: 99044.00643610807 and parameters: {'iterations': 561, 'depth': 6, 'learning_rate': 0.2809351667028527, 'l2_leaf_reg': 0.007371880541933848, 'bagging_temperature': 0.12245291626511787, 'random_strength': 0.5061178908663703}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:25:16,022] Trial 44 finished with value: 97116.7655792246 and parameters: {'iterations': 632, 'depth': 6, 'learning_rate': 0.13986013656954516, 'l2_leaf_reg': 0.1059070466760446, 'bagging_temperature': 0.06147339058363066, 'random_strength': 0.3380560322613911}. Best is trial 8 with value: 96667.19726832802.
# [I 2025-07-12 02:25:27,958] Trial 45 finished with value: 96584.80844626394 and parameters: {'iterations': 663, 'depth': 7, 'learning_rate': 0.10261817416418506, 'l2_leaf_reg': 0.023095136626793317, 'bagging_temperature': 0.21220828622837581, 'random_strength': 0.25690336784638246}. Best is trial 45 with value: 96584.80844626394.
# [I 2025-07-12 02:25:33,733] Trial 46 finished with value: 98024.48679455096 and parameters: {'iterations': 490, 'depth': 7, 'learning_rate': 0.21599180640029306, 'l2_leaf_reg': 0.04125685803157206, 'bagging_temperature': 0.21268204620076048, 'random_strength': 0.017629874855685693}. Best is trial 45 with value: 96584.80844626394.
# [I 2025-07-12 02:25:45,084] Trial 47 finished with value: 97178.5806823879 and parameters: {'iterations': 858, 'depth': 8, 'learning_rate': 0.10076653675639555, 'l2_leaf_reg': 0.008265209870951695, 'bagging_temperature': 0.27698173218828415, 'random_strength': 0.23370983874835088}. Best is trial 45 with value: 96584.80844626394.
# [I 2025-07-12 02:25:52,642] Trial 48 finished with value: 97249.02099201243 and parameters: {'iterations': 953, 'depth': 7, 'learning_rate': 0.15350169021858545, 'l2_leaf_reg': 0.025240688846509, 'bagging_temperature': 0.13441542766553283, 'random_strength': 0.07517842491271137}. Best is trial 45 with value: 96584.80844626394.
# [I 2025-07-12 02:26:05,315] Trial 49 finished with value: 97257.47507727929 and parameters: {'iterations': 749, 'depth': 7, 'learning_rate': 0.07200880062272867, 'l2_leaf_reg': 8.704267055577498, 'bagging_temperature': 0.3191207514956764, 'random_strength': 0.14583628064826618}. Best is trial 45 with value: 96584.80844626394.
# [CatBoost + Optuna CV (All Features)] Evaluation on Train set
#   MAE:  41,234.85 €
#   RMSE: 56,834.87 €
#   R²:   0.9260
# ----------------------------------------
# [CatBoost + Optuna CV (All Features)] Evaluation on Test set
#   MAE:  61,089.83 €
#   RMSE: 91,404.74 €
#   R²:   0.8085
# ----------------------------------------
# [CatBoost + Optuna CV (Top RF Features)] Evaluation on Train set
#   MAE:  44,586.38 €
#   RMSE: 61,634.18 €
#   R²:   0.9130
# ----------------------------------------
# [CatBoost + Optuna CV (Top RF Features)] Evaluation on Test set
#   MAE:  61,851.57 €
#   RMSE: 91,635.16 €
#   R²:   0.8076
# ----------------------------------------
#
# [Evaluation by Price Range – All Features]
# [DEBUG] Call print_evaluation for CatBoost + Optuna CV (All Features)
# [DEBUG] y_true: 4028, y_pred: 4028
#
# Evaluation – CatBoost + Optuna CV (All Features)
#   MAE:  61,089.83 €
#   RMSE: 91,404.74 €
#   R²:   0.8085
# ----------------------------------------
# [DEBUG] Segments found: 7
# [Evaluation by Price Range – All Features]
#           Price Range    n    MAE (€)   RMSE (€)     R²
#       (0.0, 150000.0]  179  39,846.56  52,871.89  -4.85
#  (150000.0, 250000.0]  865  38,884.56  54,349.35  -2.76
#  (250000.0, 350000.0] 1056  42,496.50  59,091.39  -3.16
#  (350000.0, 500000.0] 1030  58,274.93  78,485.33  -2.17
#  (500000.0, 750000.0]  605  88,450.03 110,796.85  -1.66
# (750000.0, 1000000.0]  232 136,405.29 179,690.60  -5.14
#      (1000000.0, inf]   61 249,907.87 304,280.23 -30.34
# ----------------------------------------
#
# [Evaluation by Price Range – Top RF Features]
# [DEBUG] Call print_evaluation for CatBoost + Optuna CV (Top RF Features)
# [DEBUG] y_true: 4028, y_pred: 4028
#
# Evaluation – CatBoost + Optuna CV (Top RF Features)
#   MAE:  61,851.57 €
#   RMSE: 91,635.16 €
#   R²:   0.8076
# ----------------------------------------
# [DEBUG] Segments found: 7
# [Evaluation by Price Range – All Features]
#           Price Range    n    MAE (€)   RMSE (€)     R²
#       (0.0, 150000.0]  179  39,618.02  50,840.69  -4.41
#  (150000.0, 250000.0]  865  40,016.05  55,918.66  -2.98
#  (250000.0, 350000.0] 1056  43,852.98  60,204.78  -3.32
#  (350000.0, 500000.0] 1030  58,258.32  79,059.26  -2.21
#  (500000.0, 750000.0]  605  89,775.03 113,095.67  -1.77
# (750000.0, 1000000.0]  232 137,197.19 177,793.05  -5.01
#      (1000000.0, inf]   61 245,478.16 295,270.78 -28.51
# ----------------------------------------
# [✔] Model saved: CatBoost + Optuna CV (All Features – Post-Split Evaluation)_20250712_0226.pkl
# [✔] Features saved: CatBoost + Optuna CV (All Features – Post-Split Evaluation)_20250712_0226.json
# [✔] Metrics saved: CatBoost + Optuna CV (All Features – Post-Split Evaluation)_20250712_0226_metrics.json
# [✔] Price range metrics saved: CatBoost + Optuna CV (All Features – Post-Split Evaluation)_20250712_0226_metrics_by_price_range.json
# [✔] Model saved: CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation)_20250712_0226.pkl
# [✔] Features saved: CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation)_20250712_0226.json
# [✔] Metrics saved: CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation)_20250712_0226_metrics.json
# [✔] Price range metrics saved: CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation)_20250712_0226_metrics_by_price_range.json
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:98: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:98: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:98: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:98: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# <style type="text/css">
# #T_34435 th.col_heading.level0:nth-child(5) {
#   background-color: #fff9c4;
# }
# #T_34435 th.col_heading.level0:nth-child(6) {
#   background-color: #fff9c4;
# }
# #T_34435 th.col_heading.level0:nth-child(7) {
#   background-color: #fff9c4;
# }
# #T_34435 th.col_heading.level0:nth-child(8) {
#   background-color: #f9c5c0;
# }
# #T_34435 th.col_heading.level0:nth-child(9) {
#   background-color: #f9c5c0;
# }
# #T_34435 th.col_heading.level0:nth-child(10) {
#   background-color: #f9c5c0;
# }
# #T_34435_row0_col0, #T_34435_row0_col1, #T_34435_row0_col2, #T_34435_row0_col3, #T_34435_row0_col4, #T_34435_row0_col5, #T_34435_row0_col6, #T_34435_row0_col7, #T_34435_row0_col8, #T_34435_row0_col9, #T_34435_row0_col10, #T_34435_row0_col12, #T_34435_row0_col14 {
#   background-color: #4caf50;
#   color: white;
# }
# #T_34435_row0_col11 {
#   background-color: #4caf50;
#   color: white;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_34435_row0_col13 {
#   background-color: #4caf50;
#   color: white;
#   background-color: #1565c0;
#   color: white;
# }
# #T_34435_row1_col0, #T_34435_row1_col1, #T_34435_row1_col2, #T_34435_row1_col3, #T_34435_row1_col4, #T_34435_row1_col5, #T_34435_row1_col6, #T_34435_row1_col7, #T_34435_row1_col8, #T_34435_row1_col9, #T_34435_row1_col10, #T_34435_row1_col12, #T_34435_row1_col14, #T_34435_row3_col11 {
#   background-color: #81c784;
#   color: black;
# }
# #T_34435_row1_col11 {
#   background-color: #81c784;
#   color: black;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_34435_row1_col13 {
#   background-color: #81c784;
#   color: black;
#   background-color: #1565c0;
#   color: white;
# }
# #T_34435_row2_col0, #T_34435_row2_col1, #T_34435_row2_col2, #T_34435_row2_col3, #T_34435_row2_col4, #T_34435_row2_col5, #T_34435_row2_col6, #T_34435_row2_col7, #T_34435_row2_col8, #T_34435_row2_col9, #T_34435_row2_col10, #T_34435_row2_col12, #T_34435_row2_col14 {
#   background-color: #c8e6c9;
#   color: black;
# }
# #T_34435_row2_col11 {
#   background-color: #c8e6c9;
#   color: black;
#   background-color: #81c784;
#   color: black;
# }
# #T_34435_row2_col13 {
#   background-color: #c8e6c9;
#   color: black;
#   background-color: #1976d2;
#   color: white;
# }
# #T_34435_row3_col13 {
#   background-color: #1976d2;
#   color: white;
# }
# </style>
# <table id="T_34435">
#   <thead>
#     <tr>
#       <th id="T_34435_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_34435_level0_col1" class="col_heading level0 col1" >Best</th>
#       <th id="T_34435_level0_col2" class="col_heading level0 col2" >timestamp</th>
#       <th id="T_34435_level0_col3" class="col_heading level0 col3" >model</th>
#       <th id="T_34435_level0_col4" class="col_heading level0 col4" >mae_train</th>
#       <th id="T_34435_level0_col5" class="col_heading level0 col5" >rmse_train</th>
#       <th id="T_34435_level0_col6" class="col_heading level0 col6" >r2_train</th>
#       <th id="T_34435_level0_col7" class="col_heading level0 col7" >mae_test</th>
#       <th id="T_34435_level0_col8" class="col_heading level0 col8" >rmse_test</th>
#       <th id="T_34435_level0_col9" class="col_heading level0 col9" >r2_test</th>
#       <th id="T_34435_level0_col10" class="col_heading level0 col10" >r2_gap</th>
#       <th id="T_34435_level0_col11" class="col_heading level0 col11" >r2_gap_diagnostic</th>
#       <th id="T_34435_level0_col12" class="col_heading level0 col12" >n_features</th>
#       <th id="T_34435_level0_col13" class="col_heading level0 col13" >interpretation (r2,mae_gap)</th>
#       <th id="T_34435_level0_col14" class="col_heading level0 col14" >ranking_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_34435_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_34435_row0_col1" class="data row0 col1" >✔</td>
#       <td id="T_34435_row0_col2" class="data row0 col2" >2025-07-12 02:26:07</td>
#       <td id="T_34435_row0_col3" class="data row0 col3" >CatBoost + Optuna CV (All Features – Post-Split Evaluation)</td>
#       <td id="T_34435_row0_col4" class="data row0 col4" >41.2 k€</td>
#       <td id="T_34435_row0_col5" class="data row0 col5" >56.8 k€</td>
#       <td id="T_34435_row0_col6" class="data row0 col6" >0.926001</td>
#       <td id="T_34435_row0_col7" class="data row0 col7" >61.1 k€</td>
#       <td id="T_34435_row0_col8" class="data row0 col8" >91.4 k€</td>
#       <td id="T_34435_row0_col9" class="data row0 col9" >0.808525</td>
#       <td id="T_34435_row0_col10" class="data row0 col10" >0.117476</td>
#       <td id="T_34435_row0_col11" class="data row0 col11" >Moderate overfitting</td>
#       <td id="T_34435_row0_col12" class="data row0 col12" >72</td>
#       <td id="T_34435_row0_col13" class="data row0 col13" >overfitting</td>
#       <td id="T_34435_row0_col14" class="data row0 col14" >-152492.956535</td>
#     </tr>
#     <tr>
#       <td id="T_34435_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_34435_row1_col1" class="data row1 col1" ></td>
#       <td id="T_34435_row1_col2" class="data row1 col2" >2025-07-12 02:26:07</td>
#       <td id="T_34435_row1_col3" class="data row1 col3" >CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation)</td>
#       <td id="T_34435_row1_col4" class="data row1 col4" >44.6 k€</td>
#       <td id="T_34435_row1_col5" class="data row1 col5" >61.6 k€</td>
#       <td id="T_34435_row1_col6" class="data row1 col6" >0.912976</td>
#       <td id="T_34435_row1_col7" class="data row1 col7" >61.9 k€</td>
#       <td id="T_34435_row1_col8" class="data row1 col8" >91.6 k€</td>
#       <td id="T_34435_row1_col9" class="data row1 col9" >0.807559</td>
#       <td id="T_34435_row1_col10" class="data row1 col10" >0.105417</td>
#       <td id="T_34435_row1_col11" class="data row1 col11" >Moderate overfitting</td>
#       <td id="T_34435_row1_col12" class="data row1 col12" >30</td>
#       <td id="T_34435_row1_col13" class="data row1 col13" >overfitting</td>
#       <td id="T_34435_row1_col14" class="data row1 col14" >-153485.115075</td>
#     </tr>
#     <tr>
#       <td id="T_34435_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_34435_row2_col1" class="data row2 col1" ></td>
#       <td id="T_34435_row2_col2" class="data row2 col2" >2025-07-12 02:08:57</td>
#       <td id="T_34435_row2_col3" class="data row2 col3" >CatBoost (All Features)</td>
#       <td id="T_34435_row2_col4" class="data row2 col4" >65.2 k€</td>
#       <td id="T_34435_row2_col5" class="data row2 col5" >96.4 k€</td>
#       <td id="T_34435_row2_col6" class="data row2 col6" >0.786959</td>
#       <td id="T_34435_row2_col7" class="data row2 col7" >65.2 k€</td>
#       <td id="T_34435_row2_col8" class="data row2 col8" >96.4 k€</td>
#       <td id="T_34435_row2_col9" class="data row2 col9" >0.786959</td>
#       <td id="T_34435_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_34435_row2_col11" class="data row2 col11" >Excellent generalization</td>
#       <td id="T_34435_row2_col12" class="data row2 col12" >72</td>
#       <td id="T_34435_row2_col13" class="data row2 col13" >good generalization</td>
#       <td id="T_34435_row2_col14" class="data row2 col14" >-161595.619596</td>
#     </tr>
#     <tr>
#       <td id="T_34435_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_34435_row3_col1" class="data row3 col1" ></td>
#       <td id="T_34435_row3_col2" class="data row3 col2" >2025-07-12 02:08:57</td>
#       <td id="T_34435_row3_col3" class="data row3 col3" >CatBoost (Top RF Features)</td>
#       <td id="T_34435_row3_col4" class="data row3 col4" >66.2 k€</td>
#       <td id="T_34435_row3_col5" class="data row3 col5" >97.2 k€</td>
#       <td id="T_34435_row3_col6" class="data row3 col6" >0.783408</td>
#       <td id="T_34435_row3_col7" class="data row3 col7" >66.2 k€</td>
#       <td id="T_34435_row3_col8" class="data row3 col8" >97.2 k€</td>
#       <td id="T_34435_row3_col9" class="data row3 col9" >0.783408</td>
#       <td id="T_34435_row3_col10" class="data row3 col10" >0.000000</td>
#       <td id="T_34435_row3_col11" class="data row3 col11" >Excellent generalization</td>
#       <td id="T_34435_row3_col12" class="data row3 col12" >30</td>
#       <td id="T_34435_row3_col13" class="data row3 col13" >good gen

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from utils.constants import PRICE_BINS, PRICE_BIN_LABELS

# === Prepare diagnostic DataFrames ===
residuals_all = y_test_all - y_pred_test_all
residuals_top = y_test_top - y_pred_test_top

df_viz_all = pd.DataFrame({
    "y_true": y_test_all,
    "y_pred": y_pred_test_all,
    "residuals": residuals_all
})
df_viz_all["price_range"] = pd.cut(df_viz_all["y_true"], bins=PRICE_BINS, labels=PRICE_BIN_LABELS)

df_viz_top = pd.DataFrame({
    "y_true": y_test_top,
    "y_pred": y_pred_test_top,
    "residuals": residuals_top
})
df_viz_top["price_range"] = pd.cut(df_viz_top["y_true"], bins=PRICE_BINS, labels=PRICE_BIN_LABELS)

# === Plot diagnostics for CatBoost + Optuna (All Features) ===
plt.figure(figsize=(14, 4))
plt.suptitle("Diagnostics – CatBoost + Optuna (All Features)", fontsize=16)

# Plot 1: Residuals vs Predicted
plt.subplot(1, 3, 1)
plt.scatter(df_viz_all["y_pred"], df_viz_all["residuals"], alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted Price")
plt.ylabel("Residual")
plt.title("Residuals vs Predicted")

# Plot 2: Residual distribution
plt.subplot(1, 3, 2)
sns.histplot(df_viz_all["residuals"], kde=True, color="orange")
plt.xlabel("Residual")
plt.title("Residual Distribution")

# Plot 3: Predicted vs Actual
plt.subplot(1, 3, 3)
plt.scatter(df_viz_all["y_true"], df_viz_all["y_pred"], alpha=0.5)
plt.plot(
    [df_viz_all["y_true"].min(), df_viz_all["y_true"].max()],
    [df_viz_all["y_true"].min(), df_viz_all["y_true"].max()],
    color='red', linestyle='--'
)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Predicted vs Actual")

plt.tight_layout()
plt.show()

# === Residuals by price range – All Features ===
plt.figure(figsize=(8, 4))
sns.boxplot(x="price_range", y="residuals", data=df_viz_all, palette="muted")
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Price Range")
plt.ylabel("Residual")
plt.title("Residuals by Price Range – All Features")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# === Residuals by price range – Top RF Features ===
plt.figure(figsize=(8, 4))
sns.boxplot(x="price_range", y="residuals", data=df_viz_top, palette="coolwarm")
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Price Range")
plt.ylabel("Residual")
plt.title("Residuals by Price Range – Top RF Features")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Neo\AppData\Local\Temp\ipykernel_14120\2044133409.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="price_range", y="residuals", data=df_viz_all, palette="muted")
# C:\Users\Neo\AppData\Local\Temp\ipykernel_14120\2044133409.py:69: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="price_range", y="residuals", data=df_viz_top, palette="coolwarm")

# %%
import sys, os
# Add the project root to the Python path
project_root = os.path.abspath("../../..")
sys.path.append(project_root)

import optuna
import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split, KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import mean_squared_error
from utils.constants import ML_READY_DATA_FILE, TEST_MODE
from utils.data_loader import DataLoader
from utils.model_evaluator import ModelEvaluator
from utils.train_test_metrics_logger import TrainTestMetricsLogger
from optuna.samplers import TPESampler
from utils.model_saver import ModelSaver

def root_mean_squared_error(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

if TEST_MODE:
    print("TEST_MODE is ON – reduced data, fewer trials.")
else:
    print("TEST_MODE is OFF – full run.")

# Step 1: Load data
loader = DataLoader(ML_READY_DATA_FILE)
df = loader.load_data()
X = df.drop(columns=["price"])
y = df["price"]

# Remove leakage
leakage_columns = ["price_per_m2", "building_age"]
X = X.drop(columns=[col for col in leakage_columns if col in X.columns], errors="ignore")

# Remove low-variance features
selector = VarianceThreshold(threshold=0.01)
X_reduced = X.loc[:, selector.fit(X).get_support()]

# Feature selection with RF
rf_model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
rf_model.fit(X_reduced, y)
top_features = pd.Series(rf_model.feature_importances_, index=X_reduced.columns).nlargest(30).index.tolist()
X_top = X_reduced[top_features]

# Define tuning function
def tune_catboost_with_optuna(X_data, y_data, n_trials=50):
    def objective(trial):
        params = {
            "iterations": trial.suggest_int("iterations", 300, 500),
            "depth": trial.suggest_int("depth", 4, 7),
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1, log=True),
            "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-3, 10.0, log=True),
            "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.0),
            "random_strength": trial.suggest_float("random_strength", 0.0, 1.0),
            "bootstrap_type": "Bayesian"
        }
        model = CatBoostRegressor(**params, verbose=0, loss_function="RMSE", random_state=42)
        cv = KFold(n_splits=5, shuffle=True, random_state=42)
        scores = []
        for train_idx, val_idx in cv.split(X_data):
            X_train, X_val = X_data.iloc[train_idx], X_data.iloc[val_idx]
            y_train, y_val = y_data.iloc[train_idx], y_data.iloc[val_idx]
            model.fit(X_train, y_train, eval_set=(X_val, y_val), early_stopping_rounds=50)
            preds = model.predict(X_val)
            scores.append(root_mean_squared_error(y_val, preds))
        return np.mean(scores)

    study = optuna.create_study(direction="minimize", sampler=TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)
    return study

# Split data into train+dev / test
X_dev_all, X_test_all, y_dev_all, y_test_all = train_test_split(X_reduced, y, test_size=0.2, random_state=42)
X_dev_top, X_test_top, y_dev_top, y_test_top = train_test_split(X_top, y, test_size=0.2, random_state=42)

n_trials = 3 if TEST_MODE else 50

# Tune and train
study_all = tune_catboost_with_optuna(X_dev_all, y_dev_all, n_trials)
model_all = CatBoostRegressor(**study_all.best_params, verbose=0, loss_function="RMSE", random_state=42)
model_all.fit(X_dev_all, y_dev_all)
y_pred_train_all = model_all.predict(X_dev_all)
y_pred_test_all = model_all.predict(X_test_all)

study_top = tune_catboost_with_optuna(X_dev_top, y_dev_top, n_trials)
model_top = CatBoostRegressor(**study_top.best_params, verbose=0, loss_function="RMSE", random_state=42)
model_top.fit(X_dev_top, y_dev_top)
y_pred_train_top = model_top.predict(X_dev_top)
y_pred_test_top = model_top.predict(X_test_top)

# Step 7: Evaluate models using ModelEvaluator
# All Features Evaluation
evaluator_all = ModelEvaluator("CatBoost + Optuna CV (All Features)")
metrics_train_all, range_train_all = evaluator_all.evaluate(y_dev_all, y_pred_train_all, dataset_type="Train")
metrics_test_all, range_test_all = evaluator_all.evaluate(y_test_all, y_pred_test_all, dataset_type="Test")

# Top RF Features Evaluation
evaluator_top = ModelEvaluator("CatBoost + Optuna CV (Top RF Features)")
metrics_train_top, range_train_top = evaluator_top.evaluate(y_dev_top, y_pred_train_top, dataset_type="Train")
metrics_test_top, range_test_top = evaluator_top.evaluate(y_test_top, y_pred_test_top, dataset_type="Test")

# Extract R² values to compute overfitting gap
r2_train_all = metrics_train_all["r2"]
r2_test_all = metrics_test_all["r2"]
r2_train_top = metrics_train_top["r2"]
r2_test_top = metrics_test_top["r2"]

# Step 8: Log all metrics using TrainTestMetricsLogger
logger = TrainTestMetricsLogger()

logger.log(
    model_name=f"CatBoost + Optuna CV (All Features – R² gap evaluated){' [TEST]' if TEST_MODE else ''}",
    experiment_name="CatBoost Optuna – All Features",
    mae_train=metrics_train_all["mae"], rmse_train=metrics_train_all["rmse"], r2_train=r2_train_all,
    mae_test=metrics_test_all["mae"], rmse_test=metrics_test_all["rmse"], r2_test=r2_test_all,
    data_file=ML_READY_DATA_FILE, n_features=X_dev_all.shape[1]
)

logger.log(
    model_name=f"CatBoost + Optuna CV (Top RF Features – R² gap evaluated){' [TEST]' if TEST_MODE else ''}",
    experiment_name="CatBoost Optuna – Top 30 RF Features",
    mae_train=metrics_train_top["mae"], rmse_train=metrics_train_top["rmse"], r2_train=r2_train_top,
    mae_test=metrics_test_top["mae"], rmse_test=metrics_test_top["rmse"], r2_test=r2_test_top,
    data_file=ML_READY_DATA_FILE, n_features=X_dev_top.shape[1]
)

# Step 9: Print R² gaps to assess overfitting
print(f"\nR² Gap (All Features): {r2_train_all - r2_test_all:.4f}")
print(f"R² Gap (Top RF Features): {r2_train_top - r2_test_top:.4f}")

# Step 10: Detailed performance by price range
price_bins = [0, 250_000, 500_000, 750_000, 1_000_000, float("inf")]

print("\n[Evaluation by Price Range – All Features]")
evaluator_all.print_evaluation(y_test_all, y_pred_test_all, bins=price_bins)

print("\n[Evaluation by Price Range – Top RF Features]")
evaluator_top.print_evaluation(y_test_top, y_pred_test_top, bins=price_bins)


# Step 9: Save models, features and metrics
saver = ModelSaver()

# Save CatBoost All Features
saver.save_model_and_features(
    model=model_all,
    features=X_train_all.columns.tolist(),
    model_name=f"CatBoost + Optuna CV (All Features – R² gap evaluated){' [TEST]' if TEST_MODE else ''}",
    metrics=metrics_test_all,
    metrics_by_price_range = evaluator_all._compute_metrics_by_price_range(
        y_test_all, y_pred_test_all, bins=[0, 250_000, 500_000, 750_000, 1_000_000, float("inf")]
    )
)

# Save CatBoost Top RF Features
saver.save_model_and_features(
    model=model_top,
    features=X_train_top.columns.tolist(),
    model_name=f"CatBoost + Optuna CV (Top RF Features – R² gap evaluated){' [TEST]' if TEST_MODE else ''}",
    metrics=metrics_test_top,
    metrics_by_price_range = evaluator_top._compute_metrics_by_price_range(
        y_test_top, y_pred_test_top, bins=[0, 250_000, 500_000, 750_000, 1_000_000, float("inf")]
    )
)

# Step 11: Display summary table of all logged experiments
logger.display_table()
# Out:
# TEST_MODE is OFF – full run.
# [I 2025-07-12 02:26:16,313] A new study created in memory with name: no-name-a10b2e3f-5e9c-42ed-bbe3-e85b1268640c
# [I 2025-07-12 02:26:23,180] Trial 0 finished with value: 98127.55255925466 and parameters: {'iterations': 375, 'depth': 7, 'learning_rate': 0.05395030966670229, 'l2_leaf_reg': 0.24810409748678125, 'bagging_temperature': 0.15601864044243652, 'random_strength': 0.15599452033620265}. Best is trial 0 with value: 98127.55255925466.
# [I 2025-07-12 02:26:28,836] Trial 1 finished with value: 102452.8934840012 and parameters: {'iterations': 311, 'depth': 7, 'learning_rate': 0.039913058785616795, 'l2_leaf_reg': 0.679657809075816, 'bagging_temperature': 0.020584494295802447, 'random_strength': 0.9699098521619943}. Best is trial 0 with value: 98127.55255925466.
# [I 2025-07-12 02:26:33,699] Trial 2 finished with value: 114192.57660984495 and parameters: {'iterations': 467, 'depth': 4, 'learning_rate': 0.015199348301309814, 'l2_leaf_reg': 0.00541524411940254, 'bagging_temperature': 0.3042422429595377, 'random_strength': 0.5247564316322378}. Best is trial 0 with value: 98127.55255925466.
# [I 2025-07-12 02:26:38,280] Trial 3 finished with value: 102988.44445535351 and parameters: {'iterations': 386, 'depth': 5, 'learning_rate': 0.04091220574443785, 'l2_leaf_reg': 0.003613894271216527, 'bagging_temperature': 0.29214464853521815, 'random_strength': 0.3663618432936917}. Best is trial 0 with value: 98127.55255925466.
# [I 2025-07-12 02:26:45,331] Trial 4 finished with value: 107025.27097660222 and parameters: {'iterations': 391, 'depth': 7, 'learning_rate': 0.015837031559118753, 'l2_leaf_reg': 0.11400863701127326, 'bagging_temperature': 0.5924145688620425, 'random_strength': 0.046450412719997725}. Best is trial 0 with value: 98127.55255925466.
# [I 2025-07-12 02:26:49,636] Trial 5 finished with value: 120250.28820800847 and parameters: {'iterations': 422, 'depth': 4, 'learning_rate': 0.011615865989246453, 'l2_leaf_reg': 6.245139574743075, 'bagging_temperature': 0.9656320330745594, 'random_strength': 0.8083973481164611}. Best is trial 0 with value: 98127.55255925466.
# [I 2025-07-12 02:26:53,392] Trial 6 finished with value: 105164.26975583145 and parameters: {'iterations': 361, 'depth': 4, 'learning_rate': 0.04833180632488466, 'l2_leaf_reg': 0.057624872164786026, 'bagging_temperature': 0.12203823484477883, 'random_strength': 0.4951769101112702}. Best is trial 0 with value: 98127.55255925466.
# [I 2025-07-12 02:26:59,202] Trial 7 finished with value: 108797.70563803853 and parameters: {'iterations': 306, 'depth': 7, 'learning_rate': 0.01814596135349025, 'l2_leaf_reg': 0.4467752817973907, 'bagging_temperature': 0.31171107608941095, 'random_strength': 0.5200680211778108}. Best is trial 0 with value: 98127.55255925466.
# [I 2025-07-12 02:27:03,608] Trial 8 finished with value: 100899.69130203802 and parameters: {'iterations': 409, 'depth': 4, 'learning_rate': 0.09323621351781479, 'l2_leaf_reg': 1.2604664585649468, 'bagging_temperature': 0.9394989415641891, 'random_strength': 0.8948273504276488}. Best is trial 0 with value: 98127.55255925466.
# [I 2025-07-12 02:27:11,170] Trial 9 finished with value: 108989.41067830581 and parameters: {'iterations': 420, 'depth': 7, 'learning_rate': 0.012260057359187526, 'l2_leaf_reg': 0.006080390190296602, 'bagging_temperature': 0.045227288910538066, 'random_strength': 0.32533033076326434}. Best is trial 0 with value: 98127.55255925466.
# [I 2025-07-12 02:27:18,442] Trial 10 finished with value: 96545.12932909963 and parameters: {'iterations': 489, 'depth': 6, 'learning_rate': 0.08226971121989857, 'l2_leaf_reg': 0.03293669426393943, 'bagging_temperature': 0.6400885024675564, 'random_strength': 0.038725199961182954}. Best is trial 10 with value: 96545.12932909963.
# [I 2025-07-12 02:27:25,525] Trial 11 finished with value: 96902.37606072011 and parameters: {'iterations': 496, 'depth': 6, 'learning_rate': 0.08222531609552017, 'l2_leaf_reg': 0.032992632816126174, 'bagging_temperature': 0.6725794991132612, 'random_strength': 0.00922737312841293}. Best is trial 10 with value: 96545.12932909963.
# [I 2025-07-12 02:27:32,623] Trial 12 finished with value: 96648.82594700903 and parameters: {'iterations': 495, 'depth': 6, 'learning_rate': 0.09903676880202796, 'l2_leaf_reg': 0.02083233848547307, 'bagging_temperature': 0.6806722560748432, 'random_strength': 0.0042251242455897675}. Best is trial 10 with value: 96545.12932909963.
# [I 2025-07-12 02:27:39,422] Trial 13 finished with value: 98018.45905009046 and parameters: {'iterations': 465, 'depth': 6, 'learning_rate': 0.06895026813605819, 'l2_leaf_reg': 0.019367283524941718, 'bagging_temperature': 0.771664143256938, 'random_strength': 0.20882527076262655}. Best is trial 10 with value: 96545.12932909963.
# [I 2025-07-12 02:27:46,658] Trial 14 finished with value: 101296.00792476741 and parameters: {'iterations': 499, 'depth': 6, 'learning_rate': 0.03028924812938631, 'l2_leaf_reg': 0.0014132462785196034, 'bagging_temperature': 0.4842973072101807, 'random_strength': 0.15578379319318547}. Best is trial 10 with value: 96545.12932909963.
# [I 2025-07-12 02:27:52,093] Trial 15 finished with value: 99625.71182758734 and parameters: {'iterations': 456, 'depth': 5, 'learning_rate': 0.06528053710862776, 'l2_leaf_reg': 0.020854013972837298, 'bagging_temperature': 0.7947223328767106, 'random_strength': 0.7017285898984922}. Best is trial 10 with value: 96545.12932909963.
# [I 2025-07-12 02:27:57,429] Trial 16 finished with value: 97513.15861499617 and parameters: {'iterations': 446, 'depth': 5, 'learning_rate': 0.09888542431973442, 'l2_leaf_reg': 0.1460535871425005, 'bagging_temperature': 0.47107801627635315, 'random_strength': 0.28938538230389976}. Best is trial 10 with value: 96545.12932909963.
# [I 2025-07-12 02:28:04,606] Trial 17 finished with value: 102929.87887042445 and parameters: {'iterations': 481, 'depth': 6, 'learning_rate': 0.025761954711555558, 'l2_leaf_reg': 0.011561992232586308, 'bagging_temperature': 0.6596209454701398, 'random_strength': 0.0024337625169372035}. Best is trial 10 with value: 96545.12932909963.
# [I 2025-07-12 02:28:11,250] Trial 18 finished with value: 98223.20566154664 and parameters: {'iterations': 433, 'depth': 6, 'learning_rate': 0.0708794443890939, 'l2_leaf_reg': 0.046634857060240446, 'bagging_temperature': 0.8264347993597301, 'random_strength': 0.10472814897590746}. Best is trial 10 with value: 96545.12932909963.
# [I 2025-07-12 02:28:17,336] Trial 19 finished with value: 99874.43126038053 and parameters: {'iterations': 482, 'depth': 5, 'learning_rate': 0.054796652993072056, 'l2_leaf_reg': 0.001099523705232939, 'bagging_temperature': 0.5659393911649604, 'random_strength': 0.4049563537168731}. Best is trial 10 with value: 96545.12932909963.
# [I 2025-07-12 02:28:22,544] Trial 20 finished with value: 107444.6077066438 and parameters: {'iterations': 337, 'depth': 6, 'learning_rate': 0.022823922542675037, 'l2_leaf_reg': 1.4789754920220004, 'bagging_temperature': 0.4362061710370352, 'random_strength': 0.24371672498802396}. Best is trial 10 with value: 96545.12932909963.
# [I 2025-07-12 02:28:29,877] Trial 21 finished with value: 97074.36620393168 and parameters: {'iterations': 493, 'depth': 6, 'learning_rate': 0.08083323826264993, 'l2_leaf_reg': 0.04709332549164846, 'bagging_temperature': 0.6872275983332036, 'random_strength': 0.013601484205066997}. Best is trial 10 with value: 96545.12932909963.
# [I 2025-07-12 02:28:37,284] Trial 22 finished with value: 97114.96147358007 and parameters: {'iterations': 500, 'depth': 6, 'learning_rate': 0.08253790594465035, 'l2_leaf_reg': 0.026718734153364773, 'bagging_temperature': 0.6980953459934975, 'random_strength': 0.09830564945061279}. Best is trial 10 with value: 96545.12932909963.
# [I 2025-07-12 02:28:44,370] Trial 23 finished with value: 96324.80951962151 and parameters: {'iterations': 477, 'depth': 6, 'learning_rate': 0.0962161159316219, 'l2_leaf_reg': 0.00924438086664587, 'bagging_temperature': 0.5809826632289876, 'random_strength': 0.09636595479124932}. Best is trial 23 with value: 96324.80951962151.
# [I 2025-07-12 02:28:50,029] Trial 24 finished with value: 97261.78729872286 and parameters: {'iterations': 476, 'depth': 5, 'learning_rate': 0.09938734184058018, 'l2_leaf_reg': 0.010872080352456482, 'bagging_temperature': 0.5589113984088391, 'random_strength': 0.16539013632174285}. Best is trial 23 with value: 96324.80951962151.
# [I 2025-07-12 02:28:56,543] Trial 25 finished with value: 97670.70390584767 and parameters: {'iterations': 448, 'depth': 6, 'learning_rate': 0.06255030962908323, 'l2_leaf_reg': 0.0037551948111980613, 'bagging_temperature': 0.39034210282217374, 'random_strength': 0.06976034942146027}. Best is trial 23 with value: 96324.80951962151.
# [I 2025-07-12 02:29:01,789] Trial 26 finished with value: 98362.77489618029 and parameters: {'iterations': 437, 'depth': 5, 'learning_rate': 0.07942245778596825, 'l2_leaf_reg': 0.010449845137027949, 'bagging_temperature': 0.6147147135589759, 'random_strength': 0.24858677338294188}. Best is trial 23 with value: 96324.80951962151.
# [I 2025-07-12 02:29:08,529] Trial 27 finished with value: 100511.58695404534 and parameters: {'iterations': 466, 'depth': 6, 'learning_rate': 0.04073501354463948, 'l2_leaf_reg': 0.002142971930336022, 'bagging_temperature': 0.8989669887289086, 'random_strength': 0.11417376511054012}. Best is trial 23 with value: 96324.80951962151.
# [I 2025-07-12 02:29:17,646] Trial 28 finished with value: 97563.8815213365 and parameters: {'iterations': 477, 'depth': 7, 'learning_rate': 0.05583368852891297, 'l2_leaf_reg': 0.08798334635653084, 'bagging_temperature': 0.7576967932132064, 'random_strength': 0.45856163599967775}. Best is trial 23 with value: 96324.80951962151.
# [I 2025-07-12 02:29:24,463] Trial 29 finished with value: 100466.79472610199 and parameters: {'iterations': 363, 'depth': 7, 'learning_rate': 0.04776086445221889, 'l2_leaf_reg': 0.2447197946713618, 'bagging_temperature': 0.8775323363399296, 'random_strength': 0.6680838764928433}. Best is trial 23 with value: 96324.80951962151.
# [I 2025-07-12 02:29:31,170] Trial 30 finished with value: 96274.79279356045 and parameters: {'iterations': 453, 'depth': 6, 'learning_rate': 0.08841270228554529, 'l2_leaf_reg': 0.014331154926716461, 'bagging_temperature': 0.3726294474356435, 'random_strength': 0.18360377857585083}. Best is trial 30 with value: 96274.79279356045.
# [I 2025-07-12 02:29:38,259] Trial 31 finished with value: 96476.58461232914 and parameters: {'iterations': 487, 'depth': 6, 'learning_rate': 0.09003488681720652, 'l2_leaf_reg': 0.01295276881838755, 'bagging_temperature': 0.40124274115865555, 'random_strength': 0.16883504799368898}. Best is trial 30 with value: 96274.79279356045.
# [I 2025-07-12 02:29:44,830] Trial 32 finished with value: 97030.46503841924 and parameters: {'iterations': 454, 'depth': 6, 'learning_rate': 0.07417598260774247, 'l2_leaf_reg': 0.007397744176796245, 'bagging_temperature': 0.3713005234129266, 'random_strength': 0.18446383236140962}. Best is trial 30 with value: 96274.79279356045.
# [I 2025-07-12 02:29:51,686] Trial 33 finished with value: 96149.6936592714 and parameters: {'iterations': 468, 'depth': 6, 'learning_rate': 0.08786331184639583, 'l2_leaf_reg': 0.0028694859514565192, 'bagging_temperature': 0.2346293399589321, 'random_strength': 0.14399049737114783}. Best is trial 33 with value: 96149.6936592714.
# [I 2025-07-12 02:30:00,159] Trial 34 finished with value: 96836.82142959989 and parameters: {'iterations': 470, 'depth': 7, 'learning_rate': 0.06091447587874877, 'l2_leaf_reg': 0.0024216893173836895, 'bagging_temperature': 0.2269847737644084, 'random_strength': 0.298274506173148}. Best is trial 33 with value: 96149.6936592714.
# [I 2025-07-12 02:30:06,216] Trial 35 finished with value: 103018.69512973516 and parameters: {'iterations': 461, 'depth': 5, 'learning_rate': 0.034062210427730666, 'l2_leaf_reg': 0.004118019979419801, 'bagging_temperature': 0.20900324170918022, 'random_strength': 0.3675437230161077}. Best is trial 33 with value: 96149.6936592714.
# [I 2025-07-12 02:30:12,869] Trial 36 finished with value: 96398.90670336432 and parameters: {'iterations': 438, 'depth': 6, 'learning_rate': 0.0917881497193822, 'l2_leaf_reg': 0.0029163263891632814, 'bagging_temperature': 0.34401223370585, 'random_strength': 0.13518283776138773}. Best is trial 33 with value: 96149.6936592714.
# [I 2025-07-12 02:30:21,562] Trial 37 finished with value: 98377.75977115396 and parameters: {'iterations': 439, 'depth': 7, 'learning_rate': 0.04722913046348905, 'l2_leaf_reg': 0.0018655534361969222, 'bagging_temperature': 0.3213291097403035, 'random_strength': 0.5933697340961738}. Best is trial 33 with value: 96149.6936592714.
# [I 2025-07-12 02:30:27,999] Trial 38 finished with value: 97254.74963528267 and parameters: {'iterations': 423, 'depth': 6, 'learning_rate': 0.07432611303983279, 'l2_leaf_reg': 0.0036003454312398316, 'bagging_temperature': 0.231838713013093, 'random_strength': 0.2466201378211494}. Best is trial 33 with value: 96149.6936592714.
# [I 2025-07-12 02:30:32,984] Trial 39 finished with value: 100380.77888721818 and parameters: {'iterations': 386, 'depth': 5, 'learning_rate': 0.05990055023629646, 'l2_leaf_reg': 0.007258482518937354, 'bagging_temperature': 0.11619388163079578, 'random_strength': 0.13507502420254153}. Best is trial 33 with value: 96149.6936592714.
# [I 2025-07-12 02:30:40,807] Trial 40 finished with value: 96214.77122987635 and parameters: {'iterations': 410, 'depth': 7, 'learning_rate': 0.08703131667038812, 'l2_leaf_reg': 0.0029157470265788682, 'bagging_temperature': 0.27799020941918773, 'random_strength': 0.06971976296499277}. Best is trial 33 with value: 96149.6936592714.
# [I 2025-07-12 02:30:48,402] Trial 41 finished with value: 96109.53674203205 and parameters: {'iterations': 404, 'depth': 7, 'learning_rate': 0.08829713610371605, 'l2_leaf_reg': 0.00259636244037152, 'bagging_temperature': 0.2585216641996319, 'random_strength': 0.06881511667973472}. Best is trial 41 with value: 96109.53674203205.
# [I 2025-07-12 02:30:56,118] Trial 42 finished with value: 96107.43734382893 and parameters: {'iterations': 408, 'depth': 7, 'learning_rate': 0.08780126813961589, 'l2_leaf_reg': 0.0010936117623735015, 'bagging_temperature': 0.2805626864619827, 'random_strength': 0.07227780266584649}. Best is trial 42 with value: 96107.43734382893.
# [I 2025-07-12 02:31:03,624] Trial 43 finished with value: 96060.19953940142 and parameters: {'iterations': 400, 'depth': 7, 'learning_rate': 0.08548553159835647, 'l2_leaf_reg': 0.0010874375198217652, 'bagging_temperature': 0.2718362569829563, 'random_strength': 0.06459306899661364}. Best is trial 43 with value: 96060.19953940142.
# [I 2025-07-12 02:31:11,135] Trial 44 finished with value: 96668.0199314177 and parameters: {'iterations': 400, 'depth': 7, 'learning_rate': 0.07277134632061673, 'l2_leaf_reg': 0.0012081052758073105, 'bagging_temperature': 0.26776811410409523, 'random_strength': 0.06981372897130778}. Best is trial 43 with value: 96060.19953940142.
# [I 2025-07-12 02:31:19,068] Trial 45 finished with value: 97040.6560238038 and parameters: {'iterations': 407, 'depth': 7, 'learning_rate': 0.06654347479139773, 'l2_leaf_reg': 0.0015569224533730028, 'bagging_temperature': 0.16676633237361038, 'random_strength': 0.06121679194826529}. Best is trial 43 with value: 96060.19953940142.
# [I 2025-07-12 02:31:26,667] Trial 46 finished with value: 96571.74369787083 and parameters: {'iterations': 375, 'depth': 7, 'learning_rate': 0.08540224905723098, 'l2_leaf_reg': 0.005027812578613399, 'bagging_temperature': 0.06784416095473864, 'random_strength': 0.9919564653632483}. Best is trial 43 with value: 96060.19953940142.
# [I 2025-07-12 02:31:34,469] Trial 47 finished with value: 97803.01076059966 and parameters: {'iterations': 400, 'depth': 7, 'learning_rate': 0.052204669824821796, 'l2_leaf_reg': 0.0010935944655918674, 'bagging_temperature': 0.2826794059336415, 'random_strength': 0.0505799812201107}. Best is trial 43 with value: 96060.19953940142.
# [I 2025-07-12 02:31:42,335] Trial 48 finished with value: 96675.67627665699 and parameters: {'iterations': 416, 'depth': 7, 'learning_rate': 0.07638245990402016, 'l2_leaf_reg': 0.0024363256946611962, 'bagging_temperature': 0.16690681699421103, 'random_strength': 0.22047404508755358}. Best is trial 43 with value: 96060.19953940142.
# [I 2025-07-12 02:31:49,687] Trial 49 finished with value: 108825.86499866491 and parameters: {'iterations': 374, 'depth': 7, 'learning_rate': 0.01309236404270686, 'l2_leaf_reg': 0.0015772541853739804, 'bagging_temperature': 0.12226553433935497, 'random_strength': 0.042590891322106944}. Best is trial 43 with value: 96060.19953940142.
# [I 2025-07-12 02:31:51,316] A new study created in memory with name: no-name-fadececc-a7df-436b-be26-c74a71f40434
# [I 2025-07-12 02:31:58,752] Trial 0 finished with value: 98539.31778672333 and parameters: {'iterations': 375, 'depth': 7, 'learning_rate': 0.05395030966670229, 'l2_leaf_reg': 0.24810409748678125, 'bagging_temperature': 0.15601864044243652, 'random_strength': 0.15599452033620265}. Best is trial 0 with value: 98539.31778672333.
# [I 2025-07-12 02:32:05,055] Trial 1 finished with value: 102574.41650382426 and parameters: {'iterations': 311, 'depth': 7, 'learning_rate': 0.039913058785616795, 'l2_leaf_reg': 0.679657809075816, 'bagging_temperature': 0.020584494295802447, 'random_strength': 0.9699098521619943}. Best is trial 0 with value: 98539.31778672333.
# [I 2025-07-12 02:32:09,953] Trial 2 finished with value: 114132.57455440103 and parameters: {'iterations': 467, 'depth': 4, 'learning_rate': 0.015199348301309814, 'l2_leaf_reg': 0.00541524411940254, 'bagging_temperature': 0.3042422429595377, 'random_strength': 0.5247564316322378}. Best is trial 0 with value: 98539.31778672333.
# [I 2025-07-12 02:32:15,159] Trial 3 finished with value: 103072.6137500911 and parameters: {'iterations': 386, 'depth': 5, 'learning_rate': 0.04091220574443785, 'l2_leaf_reg': 0.003613894271216527, 'bagging_temperature': 0.29214464853521815, 'random_strength': 0.3663618432936917}. Best is trial 0 with value: 98539.31778672333.
# [I 2025-07-12 02:32:23,084] Trial 4 finished with value: 107238.16750318499 and parameters: {'iterations': 391, 'depth': 7, 'learning_rate': 0.015837031559118753, 'l2_leaf_reg': 0.11400863701127326, 'bagging_temperature': 0.5924145688620425, 'random_strength': 0.046450412719997725}. Best is trial 0 with value: 98539.31778672333.
# [I 2025-07-12 02:32:27,471] Trial 5 finished with value: 120197.32144694605 and parameters: {'iterations': 422, 'depth': 4, 'learning_rate': 0.011615865989246453, 'l2_leaf_reg': 6.245139574743075, 'bagging_temperature': 0.9656320330745594, 'random_strength': 0.8083973481164611}. Best is trial 0 with value: 98539.31778672333.
# [I 2025-07-12 02:32:31,584] Trial 6 finished with value: 105238.23516693487 and parameters: {'iterations': 361, 'depth': 4, 'learning_rate': 0.04833180632488466, 'l2_leaf_reg': 0.057624872164786026, 'bagging_temperature': 0.12203823484477883, 'random_strength': 0.4951769101112702}. Best is trial 0 with value: 98539.31778672333.
# [I 2025-07-12 02:32:38,039] Trial 7 finished with value: 109167.75699096564 and parameters: {'iterations': 306, 'depth': 7, 'learning_rate': 0.01814596135349025, 'l2_leaf_reg': 0.4467752817973907, 'bagging_temperature': 0.31171107608941095, 'random_strength': 0.5200680211778108}. Best is trial 0 with value: 98539.31778672333.
# [I 2025-07-12 02:32:42,449] Trial 8 finished with value: 101793.3025370975 and parameters: {'iterations': 409, 'depth': 4, 'learning_rate': 0.09323621351781479, 'l2_leaf_reg': 1.2604664585649468, 'bagging_temperature': 0.9394989415641891, 'random_strength': 0.8948273504276488}. Best is trial 0 with value: 98539.31778672333.
# [I 2025-07-12 02:32:50,833] Trial 9 finished with value: 109123.84786840186 and parameters: {'iterations': 420, 'depth': 7, 'learning_rate': 0.012260057359187526, 'l2_leaf_reg': 0.006080390190296602, 'bagging_temperature': 0.045227288910538066, 'random_strength': 0.32533033076326434}. Best is trial 0 with value: 98539.31778672333.
# [I 2025-07-12 02:32:58,465] Trial 10 finished with value: 98064.2196339606 and parameters: {'iterations': 489, 'depth': 6, 'learning_rate': 0.08226971121989857, 'l2_leaf_reg': 0.03293669426393943, 'bagging_temperature': 0.6400885024675564, 'random_strength': 0.038725199961182954}. Best is trial 10 with value: 98064.2196339606.
# [I 2025-07-12 02:33:06,162] Trial 11 finished with value: 97801.43172641411 and parameters: {'iterations': 496, 'depth': 6, 'learning_rate': 0.08222531609552017, 'l2_leaf_reg': 0.032992632816126174, 'bagging_temperature': 0.6725794991132612, 'random_strength': 0.00922737312841293}. Best is trial 11 with value: 97801.43172641411.
# [I 2025-07-12 02:33:13,870] Trial 12 finished with value: 97548.86366449254 and parameters: {'iterations': 495, 'depth': 6, 'learning_rate': 0.09903676880202796, 'l2_leaf_reg': 0.02083233848547307, 'bagging_temperature': 0.6806722560748432, 'random_strength': 0.0042251242455897675}. Best is trial 12 with value: 97548.86366449254.
# [I 2025-07-12 02:33:21,059] Trial 13 finished with value: 98756.20748167005 and parameters: {'iterations': 458, 'depth': 6, 'learning_rate': 0.06895134139583076, 'l2_leaf_reg': 0.019367283524941718, 'bagging_temperature': 0.771664143256938, 'random_strength': 0.20882527076262655}. Best is trial 12 with value: 97548.86366449254.
# [I 2025-07-12 02:33:28,771] Trial 14 finished with value: 102385.69273482726 and parameters: {'iterations': 498, 'depth': 6, 'learning_rate': 0.03028924812938631, 'l2_leaf_reg': 0.0014132462785196034, 'bagging_temperature': 0.8091064851706717, 'random_strength': 0.002952296640552567}. Best is trial 12 with value: 97548.86366449254.
# [I 2025-07-12 02:33:34,812] Trial 15 finished with value: 99676.0763921119 and parameters: {'iterations': 456, 'depth': 5, 'learning_rate': 0.06528053710862776, 'l2_leaf_reg': 0.020854013972837298, 'bagging_temperature': 0.4970853936108525, 'random_strength': 0.22397372590468512}. Best is trial 12 with value: 97548.86366449254.
# [I 2025-07-12 02:33:41,322] Trial 16 finished with value: 98055.97080500846 and parameters: {'iterations': 477, 'depth': 5, 'learning_rate': 0.09888542431973442, 'l2_leaf_reg': 0.1460535871425005, 'bagging_temperature': 0.47107801627635315, 'random_strength': 0.6512279310422994}. Best is trial 12 with value: 97548.86366449254.
# [I 2025-07-12 02:33:48,374] Trial 17 finished with value: 104081.20558843548 and parameters: {'iterations': 443, 'depth': 6, 'learning_rate': 0.025768346134997195, 'l2_leaf_reg': 0.011576392213355621, 'bagging_temperature': 0.7402650864541223, 'random_strength': 0.12474853414942753}. Best is trial 12 with value: 97548.86366449254.
# [I 2025-07-12 02:33:53,937] Trial 18 finished with value: 99722.78030643413 and parameters: {'iterations': 344, 'depth': 6, 'learning_rate': 0.0708794443890939, 'l2_leaf_reg': 0.04670027699956221, 'bagging_temperature': 0.6092599562105127, 'random_strength': 0.3202438087781289}. Best is trial 12 with value: 97548.86366449254.
# [I 2025-07-12 02:33:59,610] Trial 19 finished with value: 101241.00547498946 and parameters: {'iterations': 441, 'depth': 5, 'learning_rate': 0.054796652993072056, 'l2_leaf_reg': 0.001099523705232939, 'bagging_temperature': 0.8405371917283122, 'random_strength': 0.11569056828712057}. Best is trial 12 with value: 97548.86366449254.
# [I 2025-07-12 02:34:07,255] Trial 20 finished with value: 104906.95145668436 and parameters: {'iterations': 499, 'depth': 6, 'learning_rate': 0.022823922542675037, 'l2_leaf_reg': 1.4789754920220004, 'bagging_temperature': 0.4362061710370352, 'random_strength': 0.6985077075972029}. Best is trial 12 with value: 97548.86366449254.
# [I 2025-07-12 02:34:13,442] Trial 21 finished with value: 98624.13527509353 and parameters: {'iterations': 482, 'depth': 5, 'learning_rate': 0.09983475236774345, 'l2_leaf_reg': 0.1274717848105173, 'bagging_temperature': 0.6723274409498226, 'random_strength': 0.6712369673505519}. Best is trial 12 with value: 97548.86366449254.
# [I 2025-07-12 02:34:19,732] Trial 22 finished with value: 99007.36841295674 and parameters: {'iterations': 475, 'depth': 5, 'learning_rate': 0.08153133556013933, 'l2_leaf_reg': 0.17611898649262583, 'bagging_temperature': 0.5050730458550792, 'random_strength': 0.6271776043923125}. Best is trial 12 with value: 97548.86366449254.
# [I 2025-07-12 02:34:27,082] Trial 23 finished with value: 97358.49094659954 and parameters: {'iterations': 481, 'depth': 6, 'learning_rate': 0.09757178944261735, 'l2_leaf_reg': 0.048337615098591816, 'bagging_temperature': 0.42902790135005986, 'random_strength': 0.429518735518488}. Best is trial 23 with value: 97358.49094659954.
# [I 2025-07-12 02:34:34,012] Trial 24 finished with value: 97871.17083770681 and parameters: {'iterations': 449, 'depth': 6, 'learning_rate': 0.0786801101766116, 'l2_leaf_reg': 0.010887763656865161, 'bagging_temperature': 0.39032516926237637, 'random_strength': 0.4105371236924177}. Best is trial 23 with value: 97358.49094659954.
# [I 2025-07-12 02:34:41,599] Trial 25 finished with value: 98391.65708719674 and parameters: {'iterations': 487, 'depth': 6, 'learning_rate': 0.06255030962908323, 'l2_leaf_reg': 0.051679994502920684, 'bagging_temperature': 0.5495136606105728, 'random_strength': 0.2400784928737374}. Best is trial 23 with value: 97358.49094659954.
# [I 2025-07-12 02:34:49,492] Trial 26 finished with value: 98049.5919109795 and parameters: {'iterations': 467, 'depth': 6, 'learning_rate': 0.08422004358083973, 'l2_leaf_reg': 0.0028353459605003715, 'bagging_temperature': 0.6846114912437021, 'random_strength': 0.08252566310143836}. Best is trial 23 with value: 97358.49094659954.
# [I 2025-07-12 02:34:56,497] Trial 27 finished with value: 101732.4223083976 and parameters: {'iterations': 432, 'depth': 6, 'learning_rate': 0.04073501354463948, 'l2_leaf_reg': 0.021710292269573564, 'bagging_temperature': 0.8989669887289086, 'random_strength': 0.16652275425948515}. Best is trial 23 with value: 97358.49094659954.
# [I 2025-07-12 02:35:06,428] Trial 28 finished with value: 97709.14053012633 and parameters: {'iterations': 494, 'depth': 7, 'learning_rate': 0.058784611568485454, 'l2_leaf_reg': 0.009255470174704064, 'bagging_temperature': 0.3758995778840988, 'random_strength': 0.2847972164238577}. Best is trial 23 with value: 97358.49094659954.
# [I 2025-07-12 02:35:15,856] Trial 29 finished with value: 97538.33800116494 and parameters: {'iterations': 473, 'depth': 7, 'learning_rate': 0.061913128991088216, 'l2_leaf_reg': 0.011968430967696763, 'bagging_temperature': 0.20296414094618356, 'random_strength': 0.451777469963457}. Best is trial 23 with value: 97358.49094659954.
# [I 2025-07-12 02:35:25,443] Trial 30 finished with value: 98384.4041449831 and parameters: {'iterations': 476, 'depth': 7, 'learning_rate': 0.04901226302063578, 'l2_leaf_reg': 0.07523293120446514, 'bagging_temperature': 0.21060077910535682, 'random_strength': 0.44862693703390255}. Best is trial 23 with value: 97358.49094659954.
# [I 2025-07-12 02:35:34,510] Trial 31 finished with value: 97833.8331544922 and parameters: {'iterations': 464, 'depth': 7, 'learning_rate': 0.05661328817913204, 'l2_leaf_reg': 0.008324704349135065, 'bagging_temperature': 0.3804945948461146, 'random_strength': 0.3154300286270223}. Best is trial 23 with value: 97358.49094659954.
# [I 2025-07-12 02:35:44,707] Trial 32 finished with value: 99990.19346817915 and parameters: {'iterations': 488, 'depth': 7, 'learning_rate': 0.03365500787647476, 'l2_leaf_reg': 0.01366945843205039, 'bagging_temperature': 0.1976063179014379, 'random_strength': 0.5554672270826347}. Best is trial 23 with value: 97358.49094659954.
# [I 2025-07-12 02:35:54,743] Trial 33 finished with value: 98586.22648738613 and parameters: {'iterations': 471, 'depth': 7, 'learning_rate': 0.047079806963585366, 'l2_leaf_reg': 0.0022177099177997737, 'bagging_temperature': 0.2337729095239902, 'random_strength': 0.4346447983082093}. Best is trial 23 with value: 97358.49094659954.
# [I 2025-07-12 02:36:04,319] Trial 34 finished with value: 98012.87076644794 and parameters: {'iterations': 456, 'depth': 7, 'learning_rate': 0.0594711159143727, 'l2_leaf_reg': 0.004188640832810135, 'bagging_temperature': 0.3547150401141969, 'random_strength': 0.5730369223446664}. Best is trial 23 with value: 97358.49094659954.
# [I 2025-07-12 02:36:11,014] Trial 35 finished with value: 98459.65914475992 and parameters: {'iterations': 325, 'depth': 7, 'learning_rate': 0.07195494179561787, 'l2_leaf_reg': 0.349472345111291, 'bagging_temperature': 0.14652177879107714, 'random_strength': 0.27733736954966476}. Best is trial 23 with value: 97358.49094659954.
# [I 2025-07-12 02:36:21,143] Trial 36 finished with value: 96674.83615575169 and parameters: {'iterations': 483, 'depth': 7, 'learning_rate': 0.09205290924209915, 'l2_leaf_reg': 0.00639371393329765, 'bagging_temperature': 0.08258514893929088, 'random_strength': 0.37904553044763345}. Best is trial 36 with value: 96674.83615575169.
# [I 2025-07-12 02:36:28,830] Trial 37 finished with value: 97783.90622939295 and parameters: {'iterations': 372, 'depth': 7, 'learning_rate': 0.09072370935081578, 'l2_leaf_reg': 0.005303994235050628, 'bagging_temperature': 0.0819865583856697, 'random_strength': 0.7433992288229565}. Best is trial 36 with value: 96674.83615575169.
# [I 2025-07-12 02:36:37,829] Trial 38 finished with value: 97486.5745094014 and parameters: {'iterations': 430, 'depth': 7, 'learning_rate': 0.07095154026937309, 'l2_leaf_reg': 0.030762298860493243, 'bagging_temperature': 0.018883507109018566, 'random_strength': 0.4809353349258392}. Best is trial 36 with value: 96674.83615575169.
# [I 2025-07-12 02:36:46,393] Trial 39 finished with value: 97373.65509962922 and parameters: {'iterations': 422, 'depth': 7, 'learning_rate': 0.07377232595490675, 'l2_leaf_reg': 0.07529626604552721, 'bagging_temperature': 0.010348438969096319, 'random_strength': 0.3824743504600329}. Best is trial 36 with value: 96674.83615575169.
# [I 2025-07-12 02:36:54,304] Trial 40 finished with value: 97612.8233864749 and parameters: {'iterations': 404, 'depth': 7, 'learning_rate': 0.07506777682880646, 'l2_leaf_reg': 0.2317793535021616, 'bagging_temperature': 0.0029209724939068815, 'random_strength': 0.39261567493599264}. Best is trial 36 with value: 96674.83615575169.
# [I 2025-07-12 02:37:04,304] Trial 41 finished with value: 97608.14578538341 and parameters: {'iterations': 426, 'depth': 7, 'learning_rate': 0.06886452730394162, 'l2_leaf_reg': 0.09707827917223613, 'bagging_temperature': 0.08150845873459404, 'random_strength': 0.47728731087300885}. Best is trial 36 with value: 96674.83615575169.
# [I 2025-07-12 02:37:12,593] Trial 42 finished with value: 97250.50817634902 and parameters: {'iterations': 410, 'depth': 7, 'learning_rate': 0.08579945239173628, 'l2_leaf_reg': 0.03476244131246893, 'bagging_temperature': 0.05805060810715879, 'random_strength': 0.36843335654369574}. Best is trial 36 with value: 96674.83615575169.
# [I 2025-07-12 02:37:20,654] Trial 43 finished with value: 97474.87710835047 and parameters: {'iterations': 386, 'depth': 7, 'learning_rate': 0.0864261007971578, 'l2_leaf_reg': 0.03970409663774892, 'bagging_temperature': 0.04971742109235735, 'random_strength': 0.3755226730167473}. Best is trial 36 with value: 96674.83615575169.
# [I 2025-07-12 02:37:28,491] Trial 44 finished with value: 97380.65123486434 and parameters: {'iterations': 389, 'depth': 7, 'learning_rate': 0.08621692226418229, 'l2_leaf_reg': 0.07179328992061543, 'bagging_temperature': 0.10105164444060692, 'random_strength': 0.3624348246102625}. Best is trial 36 with value: 96674.83615575169.
# [I 2025-07-12 02:37:36,977] Trial 45 finished with value: 97381.52979334959 and parameters: {'iterations': 399, 'depth': 7, 'learning_rate': 0.08979796479081448, 'l2_leaf_reg': 0.07569477941502561, 'bagging_temperature': 0.11511884086023726, 'random_strength': 0.35633974193398915}. Best is trial 36 with value: 96674.83615575169.
# [I 2025-07-12 02:37:45,466] Trial 46 finished with value: 97620.47236156391 and parameters: {'iterations': 413, 'depth': 7, 'learning_rate': 0.07801017913617148, 'l2_leaf_reg': 0.9159693832734531, 'bagging_temperature': 0.2543298642827811, 'random_strength': 0.5451713151529027}. Best is trial 36 with value: 96674.83615575169.
# [I 2025-07-12 02:37:53,308] Trial 47 finished with value: 97132.255988373 and parameters: {'iterations': 380, 'depth': 7, 'learning_rate': 0.09135896432905274, 'l2_leaf_reg': 0.36033341021197185, 'bagging_temperature': 0.15150739334325616, 'random_strength': 0.3649753897109288}. Best is trial 36 with value: 96674.83615575169.
# [I 2025-07-12 02:38:00,991] Trial 48 finished with value: 97340.29181948601 and parameters: {'iterations': 372, 'depth': 7, 'learning_rate': 0.09976008625299551, 'l2_leaf_reg': 0.33148238942714664, 'bagging_temperature': 0.15893883219919325, 'random_strength': 0.5908461244969792}. Best is trial 36 with value: 96674.83615575169.
# [I 2025-07-12 02:38:05,246] Trial 49 finished with value: 100905.59962612347 and parameters: {'iterations': 357, 'depth': 4, 'learning_rate': 0.09546524059057505, 'l2_leaf_reg': 2.292873477182287, 'bagging_temperature': 0.17290517119624738, 'random_strength': 0.5112769016320193}. Best is trial 36 with value: 96674.83615575169.
# [CatBoost + Optuna CV (All Features)] Evaluation on Train set
#   MAE:  51,661.34 €
#   RMSE: 72,450.50 €
#   R²:   0.8798
# ----------------------------------------
# [CatBoost + Optuna CV (All Features)] Evaluation on Test set
#   MAE:  62,942.52 €
#   RMSE: 93,481.00 €
#   R²:   0.7997
# ----------------------------------------
# [CatBoost + Optuna CV (Top RF Features)] Evaluation on Train set
#   MAE:  49,737.12 €
#   RMSE: 69,434.22 €
#   R²:   0.8896
# ----------------------------------------
# [CatBoost + Optuna CV (Top RF Features)] Evaluation on Test set
#   MAE:  62,577.32 €
#   RMSE: 92,611.45 €
#   R²:   0.8034
# ----------------------------------------
#
# R² Gap (All Features): 0.0800
# R² Gap (Top RF Features): 0.0861
#
# [Evaluation by Price Range – All Features]
# [DEBUG] Call print_evaluation for CatBoost + Optuna CV (All Features)
# [DEBUG] y_true: 4028, y_pred: 4028
#
# Evaluation – CatBoost + Optuna CV (All Features)
#   MAE:  62,942.52 €
#   RMSE: 93,481.00 €
#   R²:   0.7997
# ----------------------------------------
# [DEBUG] Segments found: 5
# [Evaluation by Price Range – All Features]
#           Price Range    n    MAE (€)   RMSE (€)     R²
#       (0.0, 250000.0] 1044  41,343.59  56,626.10  -0.80
#  (250000.0, 500000.0] 2086  51,749.48  71,020.27   0.02
#  (500000.0, 750000.0]  605  88,323.13 110,224.41  -1.63
# (750000.0, 1000000.0]  232 142,251.19 186,353.69  -5.60
#      (1000000.0, inf]   61 262,009.14 311,609.00 -31.87
# ----------------------------------------
#
# [Evaluation by Price Range – Top RF Features]
# [DEBUG] Call print_evaluation for CatBoost + Optuna CV (Top RF Features)
# [DEBUG] y_true: 4028, y_pred: 4028
#
# Evaluation – CatBoost + Optuna CV (Top RF Features)
#   MAE:  62,577.32 €
#   RMSE: 92,611.45 €
#   R²:   0.8034
# ----------------------------------------
# [DEBUG] Segments found: 5
# [Evaluation by Price Range – All Features]
#           Price Range    n    MAE (€)   RMSE (€)     R²
#       (0.0, 250000.0] 1044  41,311.66  56,993.85  -0.82
#  (250000.0, 500000.0] 2086  51,169.44  70,047.54   0.05
#  (500000.0, 750000.0]  605  89,660.67 112,358.60  -1.73
# (750000.0, 1000000.0]  232 138,115.20 179,300.27  -5.11
#      (1000000.0, inf]   61 260,741.05 309,014.79 -31.32
# ----------------------------------------
# [✔] Model saved: CatBoost + Optuna CV (All Features – R² gap evaluated)_20250712_0238.pkl
# [✔] Features saved: CatBoost + Optuna CV (All Features – R² gap evaluated)_20250712_0238.json
# [✔] Metrics saved: CatBoost + Optuna CV (All Features – R² gap evaluated)_20250712_0238_metrics.json
# [✔] Price range metrics saved: CatBoost + Optuna CV (All Features – R² gap evaluated)_20250712_0238_metrics_by_price_range.json
# [✔] Model saved: CatBoost + Optuna CV (Top RF Features – R² gap evaluated)_20250712_0238.pkl
# [✔] Features saved: CatBoost + Optuna CV (Top RF Features – R² gap evaluated)_20250712_0238.json
# [✔] Metrics saved: CatBoost + Optuna CV (Top RF Features – R² gap evaluated)_20250712_0238_metrics.json
# [✔] Price range metrics saved: CatBoost + Optuna CV (Top RF Features – R² gap evaluated)_20250712_0238_metrics_by_price_range.json
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:98: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:98: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:98: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# e:\_SoftEng\_BeCode\real-estate-price-predictor\utils\model_evaluator.py:98: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in df.groupby("price_range"):
# <style type="text/css">
# #T_6ecb7 th.col_heading.level0:nth-child(5) {
#   background-color: #fff9c4;
# }
# #T_6ecb7 th.col_heading.level0:nth-child(6) {
#   background-color: #fff9c4;
# }
# #T_6ecb7 th.col_heading.level0:nth-child(7) {
#   background-color: #fff9c4;
# }
# #T_6ecb7 th.col_heading.level0:nth-child(8) {
#   background-color: #f9c5c0;
# }
# #T_6ecb7 th.col_heading.level0:nth-child(9) {
#   background-color: #f9c5c0;
# }
# #T_6ecb7 th.col_heading.level0:nth-child(10) {
#   background-color: #f9c5c0;
# }
# #T_6ecb7_row0_col0, #T_6ecb7_row0_col1, #T_6ecb7_row0_col2, #T_6ecb7_row0_col3, #T_6ecb7_row0_col4, #T_6ecb7_row0_col5, #T_6ecb7_row0_col6, #T_6ecb7_row0_col7, #T_6ecb7_row0_col8, #T_6ecb7_row0_col9, #T_6ecb7_row0_col10, #T_6ecb7_row0_col12, #T_6ecb7_row0_col14 {
#   background-color: #4caf50;
#   color: white;
# }
# #T_6ecb7_row0_col11 {
#   background-color: #4caf50;
#   color: white;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_6ecb7_row0_col13 {
#   background-color: #4caf50;
#   color: white;
#   background-color: #1565c0;
#   color: white;
# }
# #T_6ecb7_row1_col0, #T_6ecb7_row1_col1, #T_6ecb7_row1_col2, #T_6ecb7_row1_col3, #T_6ecb7_row1_col4, #T_6ecb7_row1_col5, #T_6ecb7_row1_col6, #T_6ecb7_row1_col7, #T_6ecb7_row1_col8, #T_6ecb7_row1_col9, #T_6ecb7_row1_col10, #T_6ecb7_row1_col12, #T_6ecb7_row1_col14, #T_6ecb7_row4_col11, #T_6ecb7_row5_col11 {
#   background-color: #81c784;
#   color: black;
# }
# #T_6ecb7_row1_col11 {
#   background-color: #81c784;
#   color: black;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_6ecb7_row1_col13 {
#   background-color: #81c784;
#   color: black;
#   background-color: #1565c0;
#   color: white;
# }
# #T_6ecb7_row2_col0, #T_6ecb7_row2_col1, #T_6ecb7_row2_col2, #T_6ecb7_row2_col3, #T_6ecb7_row2_col4, #T_6ecb7_row2_col5, #T_6ecb7_row2_col6, #T_6ecb7_row2_col7, #T_6ecb7_row2_col8, #T_6ecb7_row2_col9, #T_6ecb7_row2_col10, #T_6ecb7_row2_col12, #T_6ecb7_row2_col14 {
#   background-color: #c8e6c9;
#   color: black;
# }
# #T_6ecb7_row2_col11 {
#   background-color: #c8e6c9;
#   color: black;
#   background-color: #ffcc80;
#   color: black;
# }
# #T_6ecb7_row2_col13 {
#   background-color: #c8e6c9;
#   color: black;
#   background-color: #1565c0;
#   color: white;
# }
# #T_6ecb7_row3_col11 {
#   background-color: #ffcc80;
#   color: black;
# }
# #T_6ecb7_row3_col13 {
#   background-color: #1565c0;
#   color: white;
# }
# #T_6ecb7_row4_col13, #T_6ecb7_row5_col13 {
#   background-color: #1976d2;
#   color: white;
# }
# </style>
# <table id="T_6ecb7">
#   <thead>
#     <tr>
#       <th id="T_6ecb7_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_6ecb7_level0_col1" class="col_heading level0 col1" >Best</th>
#       <th id="T_6ecb7_level0_col2" class="col_heading level0 col2" >timestamp</th>
#       <th id="T_6ecb7_level0_col3" class="col_heading level0 col3" >model</th>
#       <th id="T_6ecb7_level0_col4" class="col_heading level0 col4" >mae_train</th>
#       <th id="T_6ecb7_level0_col5" class="col_heading level0 col5" >rmse_train</th>
#       <th id="T_6ecb7_level0_col6" class="col_heading level0 col6" >r2_train</th>
#       <th id="T_6ecb7_level0_col7" class="col_heading level0 col7" >mae_test</th>
#       <th id="T_6ecb7_level0_col8" class="col_heading level0 col8" >rmse_test</th>
#       <th id="T_6ecb7_level0_col9" class="col_heading level0 col9" >r2_test</th>
#       <th id="T_6ecb7_level0_col10" class="col_heading level0 col10" >r2_gap</th>
#       <th id="T_6ecb7_level0_col11" class="col_heading level0 col11" >r2_gap_diagnostic</th>
#       <th id="T_6ecb7_level0_col12" class="col_heading level0 col12" >n_features</th>
#       <th id="T_6ecb7_level0_col13" class="col_heading level0 col13" >interpretation (r2,mae_gap)</th>
#       <th id="T_6ecb7_level0_col14" class="col_heading level0 col14" >ranking_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6ecb7_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6ecb7_row0_col1" class="data row0 col1" >✔</td>
#       <td id="T_6ecb7_row0_col2" class="data row0 col2" >2025-07-12 02:26:07</td>
#       <td id="T_6ecb7_row0_col3" class="data row0 col3" >CatBoost + Optuna CV (All Features – Post-Split Evaluation)</td>
#       <td id="T_6ecb7_row0_col4" class="data row0 col4" >41.2 k€</td>
#       <td id="T_6ecb7_row0_col5" class="data row0 col5" >56.8 k€</td>
#       <td id="T_6ecb7_row0_col6" class="data row0 col6" >0.926001</td>
#       <td id="T_6ecb7_row0_col7" class="data row0 col7" >61.1 k€</td>
#       <td id="T_6ecb7_row0_col8" class="data row0 col8" >91.4 k€</td>
#       <td id="T_6ecb7_row0_col9" class="data row0 col9" >0.808525</td>
#       <td id="T_6ecb7_row0_col10" class="data row0 col10" >0.117476</td>
#       <td id="T_6ecb7_row0_col11" class="data row0 col11" >Moderate overfitting</td>
#       <td id="T_6ecb7_row0_col12" class="data row0 col12" >72</td>
#       <td id="T_6ecb7_row0_col13" class="data row0 col13" >overfitting</td>
#       <td id="T_6ecb7_row0_col14" class="data row0 col14" >-152492.956535</td>
#     </tr>
#     <tr>
#       <td id="T_6ecb7_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_6ecb7_row1_col1" class="data row1 col1" ></td>
#       <td id="T_6ecb7_row1_col2" class="data row1 col2" >2025-07-12 02:26:07</td>
#       <td id="T_6ecb7_row1_col3" class="data row1 col3" >CatBoost + Optuna CV(Top RF Features – Post-Split Evaluation)</td>
#       <td id="T_6ecb7_row1_col4" class="data row1 col4" >44.6 k€</td>
#       <td id="T_6ecb7_row1_col5" class="data row1 col5" >61.6 k€</td>
#       <td id="T_6ecb7_row1_col6" class="data row1 col6" >0.912976</td>
#       <td id="T_6ecb7_row1_col7" class="data row1 col7" >61.9 k€</td>
#       <td id="T_6ecb7_row1_col8" class="data row1 col8" >91.6 k€</td>
#       <td id="T_6ecb7_row1_col9" class="data row1 col9" >0.807559</td>
#       <td id="T_6ecb7_row1_col10" class="data row1 col10" >0.105417</td>
#       <td id="T_6ecb7_row1_col11" class="data row1 col11" >Moderate overfitting</td>
#       <td id="T_6ecb7_row1_col12" class="data row1 col12" >30</td>
#       <td id="T_6ecb7_row1_col13" class="data row1 col13" >overfitting</td>
#       <td id="T_6ecb7_row1_col14" class="data row1 col14" >-153485.115075</td>
#     </tr>
#     <tr>
#       <td id="T_6ecb7_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_6ecb7_row2_col1" class="data row2 col1" ></td>
#       <td id="T_6ecb7_row2_col2" class="data row2 col2" >2025-07-12 02:38:07</td>
#       <td id="T_6ecb7_row2_col3" class="data row2 col3" >CatBoost + Optuna CV (Top RF Features – R² gap evaluated)</td>
#       <td id="T_6ecb7_row2_col4" class="data row2 col4" >49.7 k€</td>
#       <td id="T_6ecb7_row2_col5" class="data row2 col5" >69.4 k€</td>
#       <td id="T_6ecb7_row2_col6" class="data row2 col6" >0.889556</td>
#       <td id="T_6ecb7_row2_col7" class="data row2 col7" >62.6 k€</td>
#       <td id="T_6ecb7_row2_col8" class="data row2 col8" >92.6 k€</td>
#       <td id="T_6ecb7_row2_col9" class="data row2 col9" >0.803436</td>
#       <td id="T_6ecb7_row2_col10" class="data row2 col10" >0.086120</td>
#       <td id="T_6ecb7_row2_col11" class="data row2 col11" >Moderate overfitting</td>
#       <td id="T_6ecb7_row2_col12" class="data row2 col12" >30</td>
#       <td id="T_6ecb7_row2_col13" class="data row2 col13" >overfitting</td>
#       <td id="T_6ecb7_row2_col14" class="data row2 col14" >-155187.169580</td>
#     </tr>
#     <tr>
#       <td id="T_6ecb7_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_6ecb7_row3_col1" class="data row3 col1" ></td>
#       <td id="T_6ecb7_row3_col2" class="data row3 col2" >2025-07-12 02:38:07</td>
#       <td id="T_6ecb7_row3_col3" class="data row3 col3" >CatBoost + Optuna CV (All Features – R² gap evaluated)</td>
#       <td id="T_6ecb7_row3_col4" class="data row3 col4" >51.7 k€</td>
#       <td id="T_6ecb7_row3_col5" class="data row3 col5" >72.5 k€</td>
#       <td id="T_6ecb7_row3_col6" class="data row3 col6" >0.879752</td>
#       <td id="T_6ecb7_row3_col7" class="data row3 col7" >62.9 k€</td>
#       <td id="T_6ecb7_row3_col8" class="data row3 col8" >93.5 k€</td>
#       <td id="T_6ecb7_row3_col9" class="data row3 col9" >0.799728</td>
#       <td id="T_6ecb7_row3_col10" class="data row3 col10" >0.08002
